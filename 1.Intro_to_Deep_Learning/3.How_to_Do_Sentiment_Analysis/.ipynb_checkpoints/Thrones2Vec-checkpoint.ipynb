# %% [markdown]
# 上一篇文章中最后给出了每个中文词的weights向量，可以通过比较向量的相似性从而得出同义词的关系，本文会介绍另一种方法来怎么构建WordVector
#
# 视频地址：https://www.youtube.com/watch?v=pY9EwZ02sXU&index=6&list=PLweRi6d_1F-Lvlkb3g93aMnel-VAkGSRb
#
# 重要概念：word embedding
#
# 更具体可以查看https://github.com/zhuanxuhit/book/tree/develop/word2vec ，
# 知乎上的问题：https://www.zhihu.com/question/32275069
# 另外本人也会在今后多学习Paddle，为了更好的交流，创建了一个qq群576030972，欢迎大家加入的
#
# ## 1. imports

# %%
# 编解码
import codecs 
# 正则
import glob 
import logging
# 多线程
import multiprocessing 
import os
# pretty print
import pprint
# regular expression
import re

# %%
import nltk
# word 2 vec
import gensim.models.word2vec as w2v
import sklearn.manifold
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **Set up logging**

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
nltk.download("punkt",download_dir="./nltk_data")
nltk.download("stopwords",download_dir="./nltk_data")
# Out:
# [nltk_data] Downloading package punkt to ./nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to ./nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
book_filenames = sorted(glob.glob("data/*.txt"))

# %%
print("Found books:")
book_filenames
# Out:
# Found books:
# ['data/got1.txt',
#  'data/got2.txt',
#  'data/got3.txt',
#  'data/got4.txt',
#  'data/got5.txt']

# %% [markdown]
# **将所有书的内容读取出来**

# %%
corpus_raw = u""
# 只取一个，数据不然太大了
book_filenames = ['data/got1.txt']
for book_filename in book_filenames:
    print("Reading '{0}'...".format(book_filename))
    with codecs.open(book_filename, "r", "utf-8") as book_file:
        corpus_raw += book_file.read()
    print("Corpus is now {0} characters long".format(len(corpus_raw)))
    print()
# Out:
# Reading 'data/got1.txt'...
# Corpus is now 1770659 characters long

# %% [markdown]
# **将语料库分为语句**

# %%
tokenizer = nltk.data.load('./nltk_data/tokenizers/punkt/english.pickle')

# %%
raw_sentences = tokenizer.tokenize(corpus_raw)

# %%
#convert into a list of words
#rtemove unnnecessary,, split into words, no hyphens
#list of words
def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words

# %%
#sentence where each word is tokenized
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(sentence_to_wordlist(raw_sentence))

# %%
print(raw_sentences[5])
print(sentence_to_wordlist(raw_sentences[5]))
# Out:
# Heraldic crest by Virginia Norey.
# ['Heraldic', 'crest', 'by', 'Virginia', 'Norey']

# %%
token_count = sum([len(sentence) for sentence in sentences])
print("The book corpus contains {0:,} tokens".format(token_count))
# Out:
# The book corpus contains 331,572 tokens

# %%
#ONCE we have vectors
#step 3 - build model
#3 main tasks that vectors help with
#DISTANCE, SIMILARITY, RANKING
# 距离，相似性，ranking

# Dimensionality of the resulting word vectors.
#more dimensions, more computationally expensive to train
#but also more accurate
#more dimensions = more generalized
num_features = 300
# Minimum word count threshold.
min_word_count = 3

# Number of threads to run in parallel.
#more workers, faster we train
num_workers = multiprocessing.cpu_count()

# Context window length.
context_size = 7

# Downsample setting for frequent words.
#0 - 1e-5 is good for this
downsampling = 1e-3

# Seed for the RNG, to make the results reproducible.
#random number generator
#deterministic, good for debugging
seed = 1

# %%
thrones2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

# %%
thrones2vec.build_vocab(sentences)
# Out:
# 2017-02-12 16:03:52,893 : INFO : collecting all words and their counts
# 2017-02-12 16:03:52,896 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-02-12 16:03:52,942 : INFO : PROGRESS: at sentence #10000, processed 140984 words, keeping 10280 word types
# 2017-02-12 16:03:53,036 : INFO : PROGRESS: at sentence #20000, processed 279730 words, keeping 13558 word types
# 2017-02-12 16:03:53,121 : INFO : collected 15178 word types from a corpus of 331572 raw words and 23532 sentences
# 2017-02-12 16:03:53,122 : INFO : Loading a fresh vocabulary
# 2017-02-12 16:03:53,218 : INFO : min_count=3 retains 7234 unique words (47% of original 15178, drops 7944)
# 2017-02-12 16:03:53,219 : INFO : min_count=3 leaves 321389 word corpus (96% of original 331572, drops 10183)
# 2017-02-12 16:03:53,260 : INFO : deleting the raw counts dictionary of 15178 items
# 2017-02-12 16:03:53,263 : INFO : sample=0.001 downsamples 50 most-common words
# ...

# %%
print("Word2Vec vocabulary length:", len(thrones2vec.wv.vocab))
# Out:
# Word2Vec vocabulary length: 7234

# %%
thrones2vec.train(sentences)
# Out:
# 2017-02-10 17:18:17,809 : INFO : training model with 4 workers on 17277 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=7
# 2017-02-10 17:18:17,812 : INFO : expecting 128868 sentences, matching count from corpus used for vocabulary survey
# 2017-02-10 17:18:18,909 : INFO : PROGRESS: at 1.42% examples, 92942 words/s, in_qsize 6, out_qsize 1
# 2017-02-10 17:18:19,992 : INFO : PROGRESS: at 3.32% examples, 107039 words/s, in_qsize 8, out_qsize 0
# 2017-02-10 17:18:21,094 : INFO : PROGRESS: at 5.09% examples, 108668 words/s, in_qsize 6, out_qsize 1
# 2017-02-10 17:18:22,241 : INFO : PROGRESS: at 7.30% examples, 113794 words/s, in_qsize 7, out_qsize 0
# 2017-02-10 17:18:23,270 : INFO : PROGRESS: at 9.43% examples, 119255 words/s, in_qsize 7, out_qsize 0
# 2017-02-10 17:18:24,321 : INFO : PROGRESS: at 11.24% examples, 120254 words/s, in_qsize 8, out_qsize 0
# 2017-02-10 17:18:25,324 : INFO : PROGRESS: at 13.00% examples, 120715 words/s, in_qsize 7, out_qsize 0
# ...

# %% [markdown]
# 将训练好的数据存起来

# %%
if not os.path.exists("trained"):
    os.makedirs("trained")

# %%
thrones2vec.save(os.path.join("trained", "thrones2vec.w2v"))
# Out:
# 2017-02-12 16:04:04,330 : INFO : saving Word2Vec object under trained/thrones2vec.w2v, separately None
# 2017-02-12 16:04:04,331 : INFO : not storing attribute syn0norm
# 2017-02-12 16:04:04,333 : INFO : not storing attribute cum_table
# 2017-02-12 16:04:04,711 : INFO : saved trained/thrones2vec.w2v

# %%
thrones2vec = w2v.Word2Vec.load(os.path.join("trained", "thrones2vec.w2v"))
# Out:
# 2017-02-12 16:04:06,615 : INFO : loading Word2Vec object from trained/thrones2vec.w2v
# 2017-02-12 16:04:06,749 : INFO : loading wv recursively from trained/thrones2vec.w2v.wv.* with mmap=None
# 2017-02-12 16:04:06,750 : INFO : setting ignored attribute syn0norm to None
# 2017-02-12 16:04:06,752 : INFO : setting ignored attribute cum_table to None
# 2017-02-12 16:04:06,754 : INFO : loaded trained/thrones2vec.w2v

# %% [markdown]
# ## Compress the word vectors into 2D space and plot them

# %%
#my video - how to visualize a dataset easily
tsne = sklearn.manifold.TSNE(n_components=2, random_state=0)

# %%
all_word_vectors_matrix = thrones2vec.wv.syn0

# %%
all_word_vectors_matrix.shape
# Out:
# (7234, 300)

# %%
all_word_vectors_matrix_2d = tsne.fit_transform(all_word_vectors_matrix)

# %%
points = pd.DataFrame(
    [
        (word, coords[0], coords[1])
        for word, coords in [
            (word, all_word_vectors_matrix_2d[thrones2vec.wv.vocab[word].index])
            for word in thrones2vec.wv.vocab
        ]
    ],
    columns=["word", "x", "y"]
)

# %%
points.head(10)
# Out:
#        word         x         y
# 0      This  2.267853 -2.647404
# 1   edition -0.202929 -1.213269
# 2       the  2.674231 -1.495068
# 3  complete  0.636408  2.300682
# 4        of -2.403329 -2.049801
# 5         A  0.387773  3.736845
# 6        OF  0.649793 -0.570108
# 7     KINGS -0.154237  1.487938
# 8    Bantam  1.492296  1.448476
# 9   Spectra -0.032630  0.182396

# %%
sns.set_context("poster")

# %%
points.plot.scatter("x", "y", s=10, figsize=(20, 12))

# %%
def plot_region(x_bounds, y_bounds):
    slice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])
    ]
    
    ax = slice.plot.scatter("x", "y", s=35, figsize=(10, 8))
    for i, point in slice.iterrows():
        ax.text(point.x + 0.005, point.y + 0.005, point.word, fontsize=11)

# %%
plot_region(x_bounds=(0.5, 1.0), y_bounds=(-0.5, -0.1))

# %%
thrones2vec.most_similar("Stark")
# Out:
# 2017-02-12 16:14:11,690 : INFO : precomputing L2-norms of word weight vectors
# [('unsaid', 0.22172978520393372),
#  ('winesinks', 0.21668091416358948),
#  ('night', 0.21216458082199097),
#  ('barley', 0.21040557324886322),
#  ('foe', 0.2064133733510971),
#  ('stalked', 0.1907610446214676),
#  ('H', 0.18864157795906067),
#  ('hesitated', 0.1818513572216034),
#  ('LANNISTER', 0.17285853624343872),
#  ('pronounced', 0.17096541821956635)]

# %%
thrones2vec.most_similar("Aerys")
# Out:
# [('eat', 0.2115960717201233),
#  ('rattled', 0.2041129171848297),
#  ('throng', 0.18894675374031067),
#  ('marks', 0.1806076616048813),
#  ('spraying', 0.17790332436561584),
#  ('desires', 0.17454980313777924),
#  ('badges', 0.16895437240600586),
#  ('cobalt', 0.16868844628334045),
#  ('princes', 0.1674719899892807),
#  ('tending', 0.1662023663520813)]
