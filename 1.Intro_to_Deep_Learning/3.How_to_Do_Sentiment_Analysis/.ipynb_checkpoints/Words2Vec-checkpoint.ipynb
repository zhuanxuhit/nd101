# %% [markdown]
# # 神经网络实践之情感分类
# 最近报名了Udacity的深度学习基石，这是第二周的课程，主要是介绍了运用神经网络进行情感分类，课程中是对英文进行了分类，我这边改为了中文。
# 首先是中文切词，使用的是结巴。

# %%
import jieba

seg = "使用结巴来对中文进行分词"
seg_list = jieba.cut(seg)
print("/ ".join(seg_list)
# Out:
# 使用/ 结巴/ 来/ 对/ 中文/ 进行/ 分词

# %% [markdown]
# ## 1. 拿什么来做情感分类的依据
# 我们的一个思路是分别统计在 positive 和 negative 中词出现的次数，然后理论上应该某些词在 positive 和 negative 中出现的此处应该是有倾向的，下面来验证下吧

# %%
import pandas as pd
neg=pd.read_excel('data/neg.xls',header=None,index=None)
pos=pd.read_excel('data/pos.xls',header=None,index=None)

# %%
neg.head()
# Out:
#                                                    0
# 0  做为一本声名在外的流行书，说的还是广州的外企，按道理应该和我的生存环境差不多啊。但是一看之下...
# 1  作者有明显的自恋倾向，只有有老公养不上班的太太们才能像她那样生活。很多方法都不实用，还有抄袭...
# 2  作者完全是以一个过来的自认为是成功者的角度去写这个问题，感觉很不客观。虽然不是很喜欢，但是，...
# 3       作者提倡内调，不信任化妆品，这点赞同。但是所列举的方法太麻烦，配料也不好找。不是太实用。
# 4                  作者的文笔一般，观点也是和市面上的同类书大同小异，不推荐读者购买。

# %%
pos.head()
# Out:
#                                                    0
# 0  做父母一定要有刘墉这样的心态，不断地学习，不断地进步，不断地给自己补充新鲜血液，让自己保持一...
# 1  作者真有英国人严谨的风格，提出观点、进行论述论证，尽管本人对物理学了解不深，但是仍然能感受到...
# 2  作者长篇大论借用详细报告数据处理工作和计算结果支持其新观点。为什么荷兰曾经县有欧洲最高的生产...
# 3  作者在战几时之前用了＂拥抱＂令人叫绝．日本如果没有战败，就有会有美军的占领，没胡官僚主义的延...
# 4  作者在少年时即喜阅读，能看出他精读了无数经典，因而他有一个庞大的内心世界。他的作品最难能可贵...

# %%
pos['mark']=1
neg['mark']=0 #给训练语料贴上标签
pn=pd.concat([pos,neg],ignore_index=True) #合并语料
neglen=len(neg)
poslen=len(pos) #计算语料数目

# %%
cw = lambda x: list(jieba.cut(x)) #定义分词函数
pn['words'] = pn[0].apply(cw)

# %%
# 随机下
pn = pn.reindex(np.random.permutation(pn.index))

# %%
pn.head()
# Out:
#                                                        0  mark  \
# 5753   晚上航班晚点。22点以后酒店不提供，要去接机需要付费。预定的房间没有了。酒店给升级到了套间。...     1
# 2931   说起来，波特死而复活的那段很象圣斗士们，一被打倒，就迷迷糊糊地想起了女神，或是什么美好的回忆...     1
# 18269  vista系统不太习惯学习中，感觉键盘有的键比较松散轻轻一碰有点哗啦儿哗啦儿的响声，也可能太...     0
# 16653  酒店比较老旧,早餐种类很少,房间也比较老旧,没什么特色,而且餐饮已承包出去,与酒店财务分开不...     0
# 20334          这个机器待机时间超短~~也就可以用10个小时`可以接几个电话~~你说这个是电话吗~     0
#
#                                                    words
# 5753   [晚上, 航班, 晚点, 。, 22, 点, 以后, 酒店, 不, 提供, ，, 要, 去,...
# 2931   [说, 起来, ，, 波特, 死而复活, 的, 那段, 很, 象, 圣斗士, 们, ，, 一...
# 18269  [vista, 系统, 不太, 习惯, 学习, 中, ，, 感觉, 键盘, 有, 的, 键,...
# 16653  [酒店, 比较, 老旧, ,, 早餐, 种类, 很少, ,, 房间, 也, 比较, 老旧, ...
# 20334  [这个, 机器, 待机时间, 超短, ~, ~, 也, 就, 可以, 用, 10, 个, 小...

# %%
from collections import Counter
import numpy as np

positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %%
len(pn['words'])
# Out:
# 21105

# %%
pn['words'][1]
# Out:
# ['作者',
#  '真有',
#  '英国人',
#  '严谨',
#  '的',
#  '风格',
#  '，',
#  '提出',
#  '观点',
#  '、',
#  '进行',
#  '论述',
#  '论证',
#  '，',
#  '尽管',
#  '本人',
#  '对',
#  '物理学',
#  '了解',
#  '不深',
#  '，',
#  '但是',
#  '仍然',
#  '能',
#  '感受',
#  '到',
#  '真理',
#  '的',
#  '火花',
#  '。',
#  '整本书',
#  '的',
#  '结构',
#  '颇',
#  '有',
#  '特点',
#  '，',
#  '从',
#  '当时',
#  '（',
#  '本',
#  '书写',
#  '于',
#  '八十年代',
#  '）',
#  '流行',
#  '的',
#  '计算机',
#  '话题',
#  '引入',
#  '，',
#  '再用',
#  '数学',
#  '、',
#  '物理学',
#  '、',
#  '宇宙学',
#  '做',
#  '必要',
#  '的',
#  '铺垫',
#  '—',
#  '—',
#  '这些',
#  '内容',
#  '占据',
#  '了',
#  '大部分',
#  '篇幅',
#  '，',
#  '最后',
#  '回到',
#  '关键问题',
#  '：',
#  '电脑',
#  '能',
#  '不能',
#  '代替',
#  '人脑',
#  '。',
#  '和',
#  '现在',
#  '流行',
#  '的',
#  '观点',
#  '相反',
#  '，',
#  '作者',
#  '认为',
#  '人',
#  '的',
#  '某种',
#  '“',
#  '洞察',
#  '”',
#  '是',
#  '不能',
#  '被',
#  '算法',
#  '模拟',
#  '的',
#  '。',
#  '也许',
#  '作者',
#  '想',
#  '说',
#  '，',
#  '人',
#  '的',
#  '灵魂',
#  '是',
#  '无可取代',
#  '的',
#  '。']

# %%
pn['mark'][1]
# Out:
# 1

# %% [markdown]
# 我们先开始统计每个词的出现次数

# %%
for i in range(len(pn['words'])):
    if pn['mark'][i] == 1:
        for word in pn['words'][i]:
            positive_counts[word] += 1
            total_counts[word] += 1
    else:
        for word in pn['words'][i]:
            negative_counts[word] += 1
            total_counts[word] += 1

# %%
positive_counts.most_common()
# Out:
# [('，', 277248),
#  ('的', 204151),
#  ('。', 110695),
#  ('了', 69282),
#  ('是', 48313),
#  ('我', 44416),
#  (',', 36970),
#  (' ', 34118),
#  ('很', 31882),
#  ('！', 29273),
#  ('也', 27185),
#  ('在', 25125),
#  ('有', 21596),
#  ('不', 21350),
#  ('都', 21240),
#  ('就', 19217),
#  ('.', 18225),
#  ('这', 17771),
#  ('、', 16229),
#  ('和', 16008),
#  ('好', 15662),
#  ('还', 15045),
#  ('没有', 14006),
#  ('不错', 13145),
#  ('酒店', 12953),
#  ('看', 12928),
#  ('人', 12390),
#  ('本书', 11630),
#  ('可以', 11501),
#  ('说', 10153),
#  ('买', 9914),
#  ('我们', 9803),
#  ('一个', 9795),
#  ('书', 9290),
#  ('房间', 9067),
#  ('自己', 8956),
#  ('让', 8868),
#  ('感觉', 8863),
#  ('还是', 8853),
#  ('到', 8847),
#  ('对', 8635),
#  ('给', 8240),
#  ('喜欢', 8124),
#  ('但', 8016),
#  ('就是', 7948),
#  ('要', 7939),
#  ('比较', 7877),
#  ('他', 7633),
#  ('用', 7424),
#  ('上', 7267),
#  ('你', 6979),
#  ('去', 6964),
#  ('蒙牛', 6937),
#  ('会', 6864),
#  ('？', 6816),
#  ('：', 6690),
#  ('非常', 6675),
#  ('~', 6487),
#  ('但是', 6387),
#  ('这个', 6147),
#  ('孩子', 6110),
#  ('“', 6066),
#  ('”', 6043),
#  ('能', 6021),
#  ('她', 5963),
#  ('中', 5832),
#  ('不是', 5795),
#  ('；', 5794),
#  ('多', 5622),
#  ('觉得', 5605),
#  ('又', 5344),
#  ('!', 5268),
#  ('没', 5249),
#  ('服务', 5237),
#  ('时候', 5215),
#  ('什么', 5151),
#  ('很多', 5123),
#  ('2', 4985),
#  ('而且', 4766),
#  ('知道', 4699),
#  ('后', 4589),
#  ('想', 4518),
#  ('这样', 4513),
#  ('太', 4479),
#  ('住', 4452),
#  ('才', 4442),
#  ('问题', 4422),
#  ('因为', 4370),
#  ('3', 4313),
#  ('1', 4291),
#  ('小', 4287),
#  ('）', 4280),
#  ('把', 4240),
#  ('着', 4173),
#  ('《', 4173),
#  ('》', 4168),
#  ('与', 4116),
#  ('啊', 4113),
#  ('时', 4106),
#  ('…', 4078),
#  ('吧', 4061),
#  ('现在', 4031),
#  ('（', 4025),
#  ('大', 4012),
#  ('个', 4012),
#  ('有点', 3954),
#  ('还有', 3884),
#  ('不过', 3841),
#  ('所以', 3819),
#  ('如果', 3818),
#  ('更', 3779),
#  ('来', 3768),
#  ('一本', 3708),
#  ('从', 3696),
#  ('作者', 3688),
#  ('过', 3671),
#  ('一般', 3667),
#  ('看到', 3638),
#  ('再', 3623),
#  ('方便', 3590),
#  ('比', 3588),
#  ('入住', 3553),
#  ('内容', 3550),
#  ('它', 3536),
#  ('得', 3529),
#  ('虽然', 3518),
#  ('里', 3492),
#  ('已经', 3413),
#  ('做', 3400),
#  ('而', 3398),
#  ('最', 3388),
#  ('不能', 3353),
#  ('为', 3323),
#  ('功能', 3323),
#  ('价格', 3301),
#  ('朋友', 3270),
#  ('被', 3263),
#  ('一', 3225),
#  ('故事', 3194),
#  ('发现', 3192),
#  ('4', 3150),
#  ('一些', 3073),
#  ('月', 3073),
#  ('他们', 3069),
#  ('一样', 3047),
#  ('真的', 3038),
#  ('手机', 3021),
#  ('-', 3012),
#  ('东西', 2988),
#  ('应该', 2979),
#  ('呢', 2867),
#  ('屏幕', 2857),
#  ('却', 2850),
#  ('生活', 2829),
#  ('时间', 2801),
#  ('那', 2755),
#  ('等', 2750),
#  ('5', 2717),
#  ('下', 2715),
#  ('有些', 2714),
#  ('读', 2700),
#  ('支持', 2693),
#  ('系统', 2692),
#  ('希望', 2660),
#  ('可能', 2589),
#  ('那么', 2584),
#  ('写', 2573),
#  ('早餐', 2561),
#  ('高', 2555),
#  ('里面', 2475),
#  ('?', 2460),
#  ('大家', 2448),
#  ('一点', 2439),
#  ('推荐', 2437),
#  ('不好', 2434),
#  ('开始', 2423),
#  ('一直', 2412),
#  ('值得', 2398),
#  ('对于', 2379),
#  ('效果', 2373),
#  ('一下', 2366),
#  ('前台', 2363),
#  ('特别', 2340),
#  ('不会', 2336),
#  ('只是', 2329),
#  ('并', 2325),
#  ('完', 2321),
#  ('怎么', 2310),
#  ('需要', 2292),
#  ('爱', 2290),
#  ('以后', 2259),
#  ('差', 2250),
#  ('可', 2135),
#  ('起来', 2128),
#  ('只有', 2122),
#  ('挺', 2122),
#  ('中国', 2084),
#  ('使用', 2083),
#  ('性价比', 2083),
#  ('键盘', 2080),
#  ('外观', 2075),
#  ('地', 2071),
#  ('元', 2061),
#  ('携程', 2049),
#  ('质量', 2039),
#  ('像', 2033),
#  ('选择', 2032),
#  ('实在', 2023),
#  ('适合', 2022),
#  ('服务员', 2019),
#  ('宾馆', 2000),
#  ('其他', 1999),
#  ('来说', 1982),
#  ('速度', 1970),
#  ('晚上', 1968),
#  ('地方', 1957),
#  ('年', 1953),
#  ('点', 1951),
#  ('电池', 1917),
#  ('日', 1916),
#  ('这么', 1913),
#  ('设施', 1878),
#  ('只', 1841),
#  ('儿子', 1828),
#  ('装', 1822),
#  ('其实', 1807),
#  ('听', 1789),
#  ('讲', 1778),
#  ('阅读', 1776),
#  ('跟', 1771),
#  ('最后', 1754),
#  ('声音', 1750),
#  ('找', 1742),
#  ('送', 1739),
#  ('将', 1736),
#  ('设计', 1724),
#  ('建议', 1711),
#  ('一定', 1710),
#  ('真是', 1708),
#  ('环境', 1705),
#  ('6', 1703),
#  ('不要', 1698),
#  ('小时', 1689),
#  ('喝', 1664),
#  ('可是', 1658),
#  ('吃', 1641),
#  ('铃声', 1638),
#  ('文字', 1636),
#  ('客人', 1628),
#  ('结果', 1626),
#  ('只能', 1621),
#  ('您', 1621),
#  ('驱动', 1611),
#  ('—', 1602),
#  ('这种', 1602),
#  ('书中', 1587),
#  ('配置', 1582),
#  ('当', 1558),
#  ('安装', 1558),
#  ('小说', 1555),
#  ('内存', 1553),
#  ('了解', 1552),
#  ('很大', 1514),
#  ('女儿', 1507),
#  ('这是', 1499),
#  ('为什么', 1498),
#  ('那个', 1497),
#  ('简单', 1490),
#  ('拿', 1489),
#  ('之后', 1486),
#  ('．', 1485),
#  ('电话', 1472),
#  ('的话', 1471),
#  ('方面', 1469),
#  ('以前', 1469),
#  ('新', 1457),
#  ('呵呵', 1453),
#  ('本', 1447),
#  ('出来', 1445),
#  ('容易', 1443),
#  ('套书', 1440),
#  ('满意', 1436),
#  ('一种', 1435),
#  ('所', 1435),
#  ('一起', 1428),
#  ('作为', 1426),
#  ('出', 1419),
#  ('10', 1413),
#  ('这些', 1411),
#  ('后来', 1409),
#  ('另外', 1405),
#  ('舒服', 1398),
#  ('较', 1392),
#  ('居然', 1389),
#  ('确实', 1386),
#  ('吗', 1384),
#  ('不到', 1384),
#  ('快', 1380),
#  ('个人', 1379),
#  ('看看', 1376),
#  ('7', 1371),
#  ('一次', 1361),
#  ('XP', 1355),
#  ('介绍', 1349),
#  ('宝宝', 1347),
#  ('网上', 1336),
#  ('上网', 1332),
#  ('算', 1328),
#  ('总体', 1327),
#  ('该', 1323),
#  ('收到', 1322),
#  ('那些', 1321),
#  ('失望', 1319),
#  ('这里', 1316),
#  ('散热', 1310),
#  ('态度', 1305),
#  ('房', 1305),
#  ('工作', 1304),
#  ('当当', 1298),
#  ('们', 1290),
#  ('下次', 1288),
#  ('学习', 1287),
#  ('换', 1285),
#  (':', 1283),
#  ('通过', 1274),
#  ('所有', 1267),
#  ('也许', 1266),
#  ('历史', 1266),
#  ('此书', 1265),
#  ('干净', 1248),
#  ('相当', 1242),
#  ('岁', 1242),
#  ('好像', 1232),
#  ('拿到', 1231),
#  ('无法', 1227),
#  ('机器', 1224),
#  ('要求', 1221),
#  ('/', 1207),
#  ('带', 1205),
#  ('以', 1204),
#  ('世界', 1201),
#  ('之', 1199),
#  ('看过', 1196),
#  ('每个', 1188),
#  ('走', 1188),
#  ('评论', 1184),
#  (')', 1183),
#  ('最好', 1178),
#  (';', 1156),
#  ('尤其', 1154),
#  ('第一次', 1152),
#  ('完全', 1149),
#  ('做工', 1142),
#  ('这本', 1135),
#  ('连', 1130),
#  ('原来', 1121),
#  ('根本', 1120),
#  ('如何', 1119),
#  ('很快', 1119),
#  ('打', 1116),
#  ('真', 1109),
#  ('8', 1106),
#  ('当然', 1103),
#  ('不同', 1100),
#  ('基本', 1100),
#  ('认为', 1095),
#  ('位置', 1095),
#  ('机子', 1090),
#  ('叫', 1089),
#  ('为了', 1088),
#  ('天', 1088),
#  ('这次', 1084),
#  ('(', 1082),
#  ('免费', 1081),
#  ('之前', 1079),
#  ('两个', 1078),
#  ('显示', 1075),
#  ('然后', 1074),
#  ('...', 1073),
#  ('告诉', 1066),
#  ('竟然', 1065),
#  ('教育', 1058),
#  ('好书', 1058),
#  ('电脑', 1054),
#  ('问', 1049),
#  ('少', 1049),
#  ('今天', 1047),
#  ('理解', 1045),
#  ('事情', 1045),
#  ('前', 1040),
#  ('本来', 1032),
#  ('找到', 1026),
#  ('或', 1024),
#  ('摄像头', 1021),
#  ('便宜', 1016),
#  ('2008', 1016),
#  ('漂亮', 1009),
#  ('能够', 1008),
#  ('没什么', 1007),
#  ('短信', 1004),
#  ('同时', 1002),
#  ('实用', 1001),
#  ('别人', 1001),
#  ('购买', 1001),
#  ('原因', 991),
#  ('总是', 989),
#  ('出现', 984),
#  ('真正', 983),
#  ('按', 981),
#  ('京东', 980),
#  ('这家', 979),
#  ('离', 977),
#  ('手感', 976),
#  ('许多', 974),
#  ('麻烦', 972),
#  ('直接', 969),
#  ('其中', 967),
#  ('本人', 965),
#  ('一天', 965),
#  ('以为', 964),
#  ('如此', 963),
#  ('每', 957),
#  ('任何', 956),
#  ('～', 947),
#  ('装修', 946),
#  ('好看', 945),
#  ('语言', 941),
#  ('你们', 939),
#  ('已', 938),
#  ('除了', 938),
#  ('感受', 935),
#  ('刚', 934),
#  ('性能', 934),
#  ('作品', 930),
#  ('提供', 927),
#  ('情况', 925),
#  ('妈妈', 924),
#  ('看着', 924),
#  ('丰富', 923),
#  ('读者', 922),
#  ('相信', 922),
#  ('于', 921),
#  ('经历', 921),
#  ('当时', 920),
#  ('几个', 920),
#  ('帮', 916),
#  ('点评', 916),
#  ('关于', 915),
#  ('影响', 912),
#  ('哦', 912),
#  ('图片', 909),
#  ('不够', 907),
#  ('由于', 907),
#  ('谁', 907),
#  ('啦', 905),
#  ('如', 905),
#  ('味道', 905),
#  ('人生', 904),
#  ('软件', 902),
#  ('想象', 901),
#  ('字', 900),
#  ('不如', 891),
#  ('向', 891),
#  ('下载', 891),
#  ('打电话', 888),
#  ('接受', 882),
#  ('于是', 880),
#  ('那样', 879),
#  ('爱情', 877),
#  ('事', 877),
#  ('卫生间', 877),
#  ('父母', 874),
#  ('绝对', 874),
#  ('感动', 874),
#  ('老师', 872),
#  ('是不是', 861),
#  ('交通', 858),
#  ('人员', 857),
#  ('卡', 856),
#  ('不知', 853),
#  ('或者', 853),
#  ('帮助', 848),
#  ('评价', 847),
#  ('标准', 845),
#  ('每天', 845),
#  ('钱', 841),
#  ('十分', 840),
#  ('分钟', 840),
#  ('完美', 839),
#  ('30', 839),
#  ('社会', 832),
#  ('打开', 829),
#  ('及', 825),
#  ('第二天', 825),
#  ('方式', 823),
#  ('只要', 823),
#  ('经常', 821),
#  ('左右', 821),
#  ('无', 819),
#  ('还要', 819),
#  ('不少', 810),
#  ('清晰', 808),
#  ('那种', 806),
#  ('吸引', 805),
#  ('同事', 805),
#  ('知识', 804),
#  ('更好', 803),
#  ('部分', 803),
#  ('牛奶', 803),
#  ('重要', 801),
#  ('明白', 799),
#  ('屏', 799),
#  ('进行', 798),
#  ('其', 797),
#  ('才能', 797),
#  ('一套', 794),
#  ('方法', 787),
#  ('读完', 785),
#  ('大堂', 784),
#  ('以及', 780),
#  ('9', 780),
#  ('请', 774),
#  ('餐厅', 772),
#  ('硬盘', 771),
#  ('20', 770),
#  ('长', 768),
#  ('客服', 764),
#  ('主要', 763),
#  ('几乎', 763),
#  ('订', 761),
#  ('并且', 759),
#  ('幸福', 759),
#  ('比如', 759),
#  ('总之', 754),
#  ('倒', 753),
#  ('游戏', 752),
#  ('MP3', 751),
#  ('些', 749),
#  ('整体', 749),
#  ('当当网', 749),
#  ('成功', 748),
#  ('空调', 746),
#  ('还好', 745),
#  ('人物', 743),
#  ('算是', 743),
#  ('心情', 742),
#  ('女人', 740),
#  ('样子', 737),
#  ('感谢', 725),
#  ('贵', 725),
#  ('期待', 722),
#  ('包装', 719),
#  ('太小', 719),
#  ('更加', 715),
#  ('开', 715),
#  ('一切', 713),
#  ('终于', 710),
#  ('明显', 709),
#  ('行', 705),
#  ('唯一', 703),
#  ('待机时间', 702),
#  ('老', 699),
#  ('先', 699),
#  ('补充', 697),
#  ('呀', 696),
#  ('不太', 696),
#  ('能力', 695),
#  ('过程', 688),
#  ('再次', 687),
#  ('楼', 687),
#  ('按键', 687),
#  ('不用', 685),
#  ('每次', 684),
#  ('成长', 683),
#  ('简直', 683),
#  ('旧', 683),
#  ('习惯', 682),
#  ('服务态度', 681),
#  ('退房', 679),
#  ('颜色', 677),
#  ('多少', 677),
#  ('公司', 676),
#  ('生命', 676),
#  ('设置', 675),
#  ('预定', 675),
#  ('画面', 673),
#  ('情节', 670),
#  ('星', 669),
#  ('操作', 668),
#  ('目前', 665),
#  ('得到', 663),
#  ('快乐', 662),
#  ('"', 662),
#  ('商务', 661),
#  ('的确', 659),
#  ('强', 659),
#  ('兴趣', 656),
#  ('说明', 654),
#  ('三星', 653),
#  ('运行', 653),
#  ('系列', 652),
#  ('甚至', 647),
#  ('小孩', 647),
#  ('过去', 646),
#  ('最大', 646),
#  ('有时', 644),
#  ('书籍', 644),
#  ('大床', 643),
#  ('硬件', 642),
#  ('肯定', 641),
#  ('12', 641),
#  ('使', 640),
#  ('好多', 640),
#  ('优点', 640),
#  ('产品', 640),
#  ('可爱', 638),
#  ('不想', 637),
#  ('本本', 637),
#  ('伊利', 637),
#  ('总', 636),
#  ('号', 636),
#  ('送货', 636),
#  ('下去', 632),
#  ('回来', 627),
#  ('印刷', 626),
#  ('改变', 626),
#  ('机身', 625),
#  ('此', 622),
#  ('花', 622),
#  ('心里', 619),
#  ('准备', 619),
#  ('翻', 619),
#  ('似乎', 618),
#  ('专业', 616),
#  ('是因为', 616),
#  ('版本', 615),
#  ('内', 613),
#  ('继续', 612),
#  ('订单', 611),
#  ('很漂亮', 611),
#  ('电影', 609),
#  ('陈旧', 608),
#  ('遇到', 607),
#  ('文章', 606),
#  ('看起来', 604),
#  ('时尚', 604),
#  ('是否', 602),
#  ('正常', 602),
#  ('可惜', 601),
#  ('几天', 600),
#  ('来看', 600),
#  ('色彩', 600),
#  ('真实', 599),
#  ('话', 599),
#  ('家长', 599),
#  ('而是', 595),
#  ('考虑', 595),
#  ('所谓', 594),
#  ('发生', 594),
#  ('清楚', 594),
#  ('道理', 593),
#  ('缺点', 592),
#  ('地理位置', 591),
#  ('先生', 590),
#  ('不足', 588),
#  ('差不多', 587),
#  ('反馈', 587),
#  ('管理', 585),
#  ('提出', 583),
#  ('观点', 583),
#  ('早上', 582),
#  ('播放', 580),
#  ('隔音', 580),
#  ('经典', 578),
#  ('后面', 577),
#  ('不了', 577),
#  ('笔记本', 577),
#  ('认识', 576),
#  ('够', 576),
#  ('郁闷', 576),
#  ('怎样', 576),
#  ('升级', 576),
#  ('热情', 575),
#  ('实际', 574),
#  ('首先', 574),
#  ('感到', 573),
#  ('且', 573),
#  ('成为', 572),
#  ('毕竟', 572),
#  ('安静', 571),
#  ('客房', 570),
#  ('#', 570),
#  ('抵制', 569),
#  ('同样', 568),
#  ('加', 568),
#  ('深刻', 567),
#  ('遗憾', 566),
#  ('注意', 564),
#  ('还会', 563),
#  ('即使', 563),
#  ('慢', 561),
#  ('细节', 560),
#  ('风格', 557),
#  ('11', 557),
#  ('间', 555),
#  ('显卡', 555),
#  ('心理', 554),
#  ('正在', 554),
#  ('估计', 554),
#  ('家', 554),
#  ('电视', 554),
#  ('15', 553),
#  ('普通', 552),
#  ('看来', 550),
#  ('各种', 547),
#  ('坏', 545),
#  ('后悔', 545),
#  ('蓝牙', 545),
#  ('很差', 544),
#  ('睡觉', 543),
#  ('大概', 543),
#  ('款', 543),
#  ('来电', 543),
#  ('像素', 543),
#  ('品牌', 542),
#  ('好好', 541),
#  ('100', 541),
#  ('豪华', 541),
#  ('开心', 540),
#  ('结局', 540),
#  ('身边', 540),
#  ('健康', 539),
#  ('男人', 539),
#  ('处理', 537),
#  ('之间', 535),
#  ('买来', 534),
#  ('近', 533),
#  ('拥有', 533),
#  ('重新', 533),
#  ('分', 532),
#  ('开机', 532),
#  ('热', 531),
#  ('蛮', 530),
#  ('有人', 529),
#  ('搞', 529),
#  ('一句', 528),
#  ('水平', 528),
#  ('存在', 527),
#  ('很小', 527),
#  ('哈哈', 524),
#  ('下午', 522),
#  ('光盘', 522),
#  ('必须', 521),
#  ('解决', 521),
#  ('四星', 521),
#  ('文化', 520),
#  ('决定', 520),
#  ('安排', 520),
#  ('至少', 519),
#  ('价位', 519),
#  ('送给', 518),
#  ('价钱', 517),
#  ('不管', 515),
#  ('理论', 513),
#  ('饭店', 513),
#  ('谢谢', 511),
#  ('日本', 510),
#  ('拍照', 509),
#  ('企业', 508),
#  ('没想到', 507),
#  ('信号', 507),
#  ('......', 507),
#  ('一家', 507),
#  ('整个', 506),
#  ('货', 504),
#  ('跑', 504),
#  ('一看', 503),
#  ('拍摄', 503),
#  ('思想', 500),
#  ('两天', 500),
#  ('成', 499),
#  ('xp', 499),
#  ('一位', 498),
#  ('垃圾', 498),
#  ('要是', 498),
#  ('放', 498),
#  ('放在', 498),
#  ('本身', 498),
#  ('照片', 497),
#  ('象', 496),
#  ('一部', 495),
#  ('玩', 493),
#  ('流畅', 493),
#  ('音乐', 491),
#  ('一口气', 490),
#  ('不行', 490),
#  ('不仅', 489),
#  ('感情', 488),
#  ('死', 488),
#  ('机会', 487),
#  ('表现', 486),
#  ('收藏', 486),
#  ('起', 485),
#  ('办法', 485),
#  ('翻译', 484),
#  ('曾经', 483),
#  ('令人', 482),
#  ('万', 481),
#  ('其它', 480),
#  ('名字', 480),
#  ('记得', 478),
#  ('联系', 478),
#  ('别的', 476),
#  ('坚持', 474),
#  ('书里', 474),
#  ('水', 474),
#  ('快递', 474),
#  ('细腻', 473),
#  ('内置', 472),
#  ('意义', 470),
#  ('@', 470),
#  ('懂', 468),
#  ('马上', 467),
#  ('印象', 467),
#  ('包', 467),
#  ('死机', 467),
#  ('以上', 465),
#  ('反应', 465),
#  ('周围', 465),
#  ('最近', 464),
#  ('信息', 464),
#  ('联想', 464),
#  ('想要', 462),
#  ('一遍', 460),
#  ('香港', 460),
#  ('轻松', 459),
#  ('有趣', 459),
#  ('门口', 459),
#  ('床', 458),
#  ('客户', 456),
#  ('附近', 456),
#  ('鼠标', 456),
#  ('全', 452),
#  ('小巧', 452),
#  ('小朋友', 451),
#  ('上面', 451),
#  ('描写', 450),
#  ('英语', 450),
#  ('北京', 450),
#  ('那里', 448),
#  ('合适', 448),
#  ('买回来', 448),
#  ('意思', 448),
#  ('&#', 447),
#  ('小姐', 443),
#  ('定', 442),
#  ('实惠', 441),
#  ('下来', 440),
#  ('第一', 439),
#  ('关系', 438),
#  ('用户', 438),
#  ('键', 438),
#  ('*', 437),
#  ('另', 436),
#  ('采用', 436),
#  ('未', 435),
#  ('么', 434),
#  ('精致', 434),
#  ('慢慢', 433),
#  ('角度', 433),
#  ('满足', 433),
#  ('基本上', 433),
#  ('无线', 433),
#  ('显得', 432),
#  ('属于', 432),
#  ('VISTA', 431),
#  ('全部', 430),
#  ('外', 430),
#  ('外壳', 430),
#  ('自带', 430),
#  ('拉拉', 429),
#  ('人们', 429),
#  ('外面', 429),
#  ('笑', 428),
#  ('关注', 428),
#  ('远', 427),
#  ('努力', 426),
#  ('低', 426),
#  ('读书', 425),
#  ('提高', 425),
#  ('超级', 425),
#  ('页', 425),
#  ('进入', 424),
#  ('精彩', 423),
#  ('吃饭', 423),
#  ('发展', 422),
#  ('充满', 421),
#  ('反映', 421),
#  ('一生', 421),
#  ('具有', 421),
#  ('图画', 421),
#  ('价值', 420),
#  ('现实', 420),
#  ('享受', 420),
#  ('现象', 420),
#  ('发货', 420),
#  ('不断', 419),
#  ('思考', 419),
#  ('不敢', 419),
#  ('酸奶', 419),
#  ('研究', 418),
#  ('稍微', 418),
#  ('相对', 417),
#  ('单词', 417),
#  ('主人公', 415),
#  ('>', 415),
#  ('一张', 413),
#  ('解释', 413),
#  ('时代', 412),
#  ('更是', 412),
#  ('掉', 412),
#  ('短', 410),
#  ('学', 409),
#  ('合理', 409),
#  ('很少', 409),
#  ('这书', 409),
#  ('过来', 408),
#  ('因此', 408),
#  ('同学', 407),
#  ('一边', 407),
#  ('总的来说', 406),
#  ('耳机', 406),
#  ('卖', 405),
#  ('难', 404),
#  ('越', 404),
#  ('身体', 404),
#  ('突然', 404),
#  ('看书', 403),
#  ('房价', 403),
#  ('机场', 402),
#  ('国内', 401),
#  ('面对', 401),
#  ('等等', 400),
#  ('精美', 400),
#  ('上海', 400),
#  ('带来', 399),
#  ('久', 399),
#  ('温馨', 399),
#  ('特色', 399),
#  ('分区', 399),
#  ('楼层', 399),
#  ('不算', 398),
#  ('吵', 398),
#  ('200', 398),
#  ('接口', 398),
#  ('光驱', 398),
#  ('自然', 397),
#  ('永远', 397),
#  ('职场', 397),
#  ('认真', 397),
#  ('就算', 397),
#  ('前面', 396),
#  ('感谢您', 396),
#  ('告知', 395),
#  ('宽带', 395),
#  ('回家', 394),
#  ('弄', 393),
#  ('模式', 393),
#  ('靠', 393),
#  ('16', 393),
#  ('反正', 393),
#  ('经理', 392),
#  ('行李', 392),
#  ('电梯', 392),
#  ('版', 391),
#  ('心', 390),
#  ('音质', 390),
#  ('而已', 389),
#  ('无论', 388),
#  ('足够', 388),
#  ('选', 388),
#  ('经济', 387),
#  ('因', 387),
#  ('达到', 387),
#  ('这点', 387),
#  ('或许', 386),
#  ('舒适', 385),
#  ('相比', 384),
#  ('通话', 384),
#  ('vista', 384),
#  ('早', 382),
#  ('回复', 382),
#  ('描述', 381),
#  ('平时', 381),
#  ('一条', 379),
#  ('地毯', 379),
#  ('想法', 378),
#  ('收获', 377),
#  ('网络', 377),
#  ('改进', 377),
#  ...]

# %%
negative_counts.most_common()
# Out:
# [('，', 42831),
#  ('的', 28859),
#  ('。', 16847),
#  ('了', 13476),
#  (',', 8462),
#  ('是', 7994),
#  ('我', 7841),
#  (' ', 7528),
#  ('！', 7084),
#  ('不', 5821),
#  ('也', 4132),
#  ('.', 3873),
#  ('就', 3868),
#  ('没有', 3766),
#  ('在', 3684),
#  ('很', 3536),
#  ('都', 3432),
#  ('酒店', 3151),
#  ('有', 3112),
#  ('还', 2496),
#  ('这', 2440),
#  ('说', 2399),
#  ('房间', 2264),
#  ('买', 2086),
#  ('、', 2071),
#  ('和', 2037),
#  ('？', 2013),
#  ('看', 1979),
#  ('好', 1825),
#  ('人', 1686),
#  ('蒙牛', 1664),
#  ('到', 1653),
#  ('要', 1616),
#  ('书', 1612),
#  ('一个', 1584),
#  ('本书', 1501),
#  ('给', 1483),
#  ('感觉', 1475),
#  ('就是', 1430),
#  ('没', 1420),
#  ('用', 1417),
#  ('!', 1410),
#  ('我们', 1399),
#  ('还是', 1368),
#  ('太', 1359),
#  ('可以', 1321),
#  ('：', 1275),
#  ('2', 1264),
#  ('去', 1238),
#  ('但', 1227),
#  ('什么', 1206),
#  ('不是', 1198),
#  ('上', 1139),
#  ('让', 1137),
#  ('对', 1121),
#  ('~', 1112),
#  ('知道', 1079),
#  ('住', 1077),
#  ('自己', 1076),
#  ('；', 1052),
#  ('1', 1049),
#  ('不能', 1036),
#  ('这个', 1032),
#  ('才', 1030),
#  ('又', 1004),
#  ('一般', 998),
#  ('后', 988),
#  ('服务', 979),
#  ('3', 970),
#  ('比较', 967),
#  ('问题', 966),
#  ('而且', 964),
#  ('你', 935),
#  ('啊', 933),
#  ('但是', 933),
#  ('会', 930),
#  ('差', 897),
#  ('入住', 890),
#  ('有点', 882),
#  ('个', 869),
#  ('时候', 857),
#  ('喜欢', 852),
#  ('不好', 845),
#  ('）', 835),
#  ('这样', 833),
#  ('时', 826),
#  ('觉得', 818),
#  ('月', 815),
#  ('内容', 812),
#  ('多', 807),
#  ('非常', 804),
#  ('能', 801),
#  ('（', 796),
#  ('吧', 793),
#  ('“', 786),
#  ('”', 773),
#  ('再', 772),
#  ('把', 761),
#  ('小', 753),
#  ('前台', 745),
#  ('过', 727),
#  ('还有', 721),
#  ('想', 717),
#  ('发现', 693),
#  ('4', 690),
#  ('携程', 690),
#  ('系统', 683),
#  ('他', 674),
#  ('怎么', 666),
#  ('不错', 655),
#  ('大', 653),
#  ('很多', 646),
#  ('如果', 637),
#  ('因为', 637),
#  ('现在', 637),
#  ('被', 631),
#  ('?', 630),
#  ('-', 630),
#  ('来', 612),
#  ('得', 611),
#  ('实在', 608),
#  ('一', 591),
#  ('中', 585),
#  ('服务员', 585),
#  ('价格', 575),
#  ('喝', 571),
#  ('不过', 569),
#  ('…', 569),
#  ('里', 564),
#  ('不会', 556),
#  ('5', 553),
#  ('呢', 547),
#  ('已经', 547),
#  ('东西', 537),
#  ('元', 534),
#  ('日', 532),
#  ('失望', 526),
#  ('一点', 525),
#  ('手机', 525),
#  ('她', 523),
#  ('下', 522),
#  ('只有', 518),
#  ('所以', 516),
#  ('孩子', 511),
#  ('只能', 509),
#  ('可能', 504),
#  ('时间', 502),
#  ('大家', 498),
#  ('从', 495),
#  ('以后', 492),
#  ('他们', 489),
#  ('着', 489),
#  ('比', 489),
#  ('驱动', 483),
#  ('等', 478),
#  ('不要', 477),
#  ('点', 476),
#  ('写', 475),
#  ('早餐', 475),
#  ('结果', 474),
#  ('屏幕', 473),
#  ('找', 472),
#  ('晚上', 471),
#  ('那么', 470),
#  ('它', 469),
#  ('客人', 469),
#  ('这么', 466),
#  ('居然', 465),
#  ('一样', 463),
#  ('朋友', 462),
#  ('应该', 459),
#  ('作者', 458),
#  ('一下', 457),
#  ('更', 457),
#  ('装', 455),
#  ('有些', 454),
#  ('电池', 450),
#  ('做', 449),
#  ('电话', 448),
#  ('宾馆', 445),
#  ('方便', 442),
#  ('质量', 436),
#  ('换', 434),
#  ('看到', 430),
#  ('支持', 430),
#  ('根本', 428),
#  ('声音', 428),
#  ('一本', 426),
#  ('建议', 422),
#  ('功能', 421),
#  ('却', 420),
#  ('里面', 420),
#  ('为什么', 419),
#  ('与', 414),
#  ('最', 410),
#  ('那', 407),
#  ('只', 406),
#  ('为', 403),
#  ('年', 399),
#  ('设施', 393),
#  ('可是', 391),
#  ('希望', 388),
#  ('地方', 386),
#  ('而', 385),
#  ('6', 385),
#  ('您', 383),
#  ('真的', 382),
#  ('其他', 380),
#  ('一些', 380),
#  ('虽然', 376),
#  ('当当', 376),
#  ('吗', 374),
#  ('不到', 374),
#  ('麻烦', 369),
#  ('需要', 363),
#  ('真是', 359),
#  ('内存', 358),
#  ('这种', 357),
#  ('竟然', 354),
#  ('你们', 351),
#  ('10', 351),
#  ('可', 349),
#  ('收到', 349),
#  ('》', 347),
#  ('跟', 347),
#  ('使用', 344),
#  ('并', 339),
#  ('《', 336),
#  ('房', 336),
#  ('只是', 335),
#  ('无法', 330),
#  ('小时', 330),
#  ('XP', 328),
#  ('容易', 327),
#  ('特别', 327),
#  ('网上', 326),
#  ('不如', 324),
#  ('键盘', 323),
#  ('打电话', 321),
#  ('要求', 321),
#  ('后来', 316),
#  ('故事', 313),
#  ('适合', 312),
#  ('送', 310),
#  ('该', 306),
#  ('打', 306),
#  ('像', 304),
#  ('天', 304),
#  ('一直', 303),
#  ('拿', 302),
#  ('评论', 301),
#  ('连', 301),
#  ('推荐', 293),
#  ('效果', 291),
#  ('完', 289),
#  ('．', 288),
#  ('7', 288),
#  ('最后', 286),
#  ('安装', 284),
#  ('起来', 281),
#  ('没什么', 280),
#  ('出来', 280),
#  ('态度', 279),
#  ('铃声', 279),
#  ('另外', 278),
#  ('问', 277),
#  ('开始', 274),
#  ('叫', 273),
#  ('吃', 267),
#  ('听', 263),
#  ('一次', 262),
#  ('抵制', 262),
#  ('不够', 260),
#  ('选择', 260),
#  (':', 259),
#  ('高', 259),
#  ('好像', 259),
#  ('之后', 257),
#  ('的话', 257),
#  (')', 257),
#  ('完全', 255),
#  ('无', 255),
#  ('本来', 255),
#  ('钱', 254),
#  ('将', 253),
#  ('出', 252),
#  ('那个', 252),
#  ('一定', 252),
#  ('下载', 249),
#  ('(', 247),
#  ('太小', 241),
#  ('客服', 241),
#  ('很差', 239),
#  ('挺', 239),
#  ('这家', 239),
#  ('退房', 239),
#  ('8', 238),
#  ('短信', 238),
#  ('以为', 236),
#  ('显示', 236),
#  ('任何', 235),
#  ('对于', 234),
#  ('/', 233),
#  ('很大', 232),
#  ('简直', 232),
#  ('...', 232),
#  ('第二天', 231),
#  ('不知', 230),
#  ('少', 229),
#  ('按', 228),
#  ('出现', 228),
#  ('请', 228),
#  ('还要', 228),
#  ('打开', 227),
#  ('卫生间', 227),
#  ('环境', 227),
#  ('点评', 227),
#  ('看看', 226),
#  ('真', 226),
#  ('空调', 226),
#  ('直接', 225),
#  ('当', 224),
#  ('2008', 223),
#  ('郁闷', 222),
#  ('读', 222),
#  ('上网', 222),
#  ('来说', 220),
#  ('是不是', 219),
#  ('垃圾', 216),
#  ('值得', 215),
#  ('两个', 215),
#  ('个人', 214),
#  ('然后', 213),
#  ('地', 212),
#  ('机子', 212),
#  ('当当网', 211),
#  ('死机', 211),
#  ('原因', 209),
#  ('下次', 209),
#  ('卡', 209),
#  ('订单', 208),
#  ('后悔', 208),
#  ('坏', 208),
#  ('预定', 207),
#  ('机器', 207),
#  ('情况', 206),
#  ('电脑', 206),
#  ('几个', 205),
#  ('以前', 205),
#  ('明显', 203),
#  (';', 203),
#  ('12', 202),
#  ('告诉', 200),
#  ('儿子', 200),
#  ('开', 200),
#  ('本人', 199),
#  ('讲', 199),
#  ('简单', 199),
#  ('一天', 199),
#  ('人员', 199),
#  ('提供', 198),
#  ('本', 197),
#  ('谁', 197),
#  ('不了', 197),
#  ('这里', 196),
#  ('不太', 195),
#  ('9', 195),
#  ('评价', 194),
#  ('速度', 193),
#  ('订', 193),
#  ('～', 193),
#  ('散热', 193),
#  ('慢', 192),
#  ('所有', 191),
#  ('拿到', 191),
#  ('装修', 191),
#  ('别人', 190),
#  ('中国', 190),
#  ('京东', 190),
#  ('号', 189),
#  ('第一次', 189),
#  ('岁', 189),
#  ('分钟', 189),
#  ('翻', 188),
#  ('介绍', 187),
#  ('其实', 185),
#  ('贵', 184),
#  ('倒', 183),
#  ('影响', 183),
#  ('快', 183),
#  ('此书', 181),
#  ('新', 181),
#  ('较', 180),
#  ('星', 180),
#  ('由于', 179),
#  ('大堂', 179),
#  ('30', 178),
#  ('软件', 178),
#  ('这次', 176),
#  ('总之', 176),
#  ('伊利', 176),
#  ('设计', 175),
#  ('已', 175),
#  ('20', 175),
#  ('开机', 173),
#  ('为了', 172),
#  ('阅读', 171),
#  ('位置', 171),
#  ('除了', 169),
#  ('说明', 168),
#  ('也许', 168),
#  ('这些', 167),
#  ('页', 166),
#  ('通过', 166),
#  ('味道', 166),
#  ('陈旧', 166),
#  ('字', 165),
#  ('—', 165),
#  ('确实', 165),
#  ('舒服', 165),
#  ('不行', 164),
#  ('补充', 164),
#  ('工作', 163),
#  ('前', 163),
#  ('11', 163),
#  ('呀', 162),
#  ('走', 162),
#  ('硬盘', 162),
#  ('不想', 161),
#  ('事情', 161),
#  ('隔音', 161),
#  ('之', 160),
#  ('不买', 160),
#  ('办法', 160),
#  ('按键', 159),
#  ('投诉', 158),
#  ('摄像头', 158),
#  ('才能', 157),
#  ('标准', 157),
#  ('基本', 157),
#  ('正常', 157),
#  ('牛奶', 157),
#  ('"', 157),
#  ('一起', 156),
#  ('小说', 155),
#  ('文字', 155),
#  ('或', 155),
#  ('搞', 155),
#  ('想象', 155),
#  ('公司', 155),
#  ('之前', 154),
#  ('算', 154),
#  ('生活', 153),
#  ('今天', 153),
#  ('干净', 153),
#  ('热', 153),
#  ('呵呵', 152),
#  ('免费', 152),
#  ('看过', 151),
#  ('满意', 151),
#  ('经常', 151),
#  ('们', 150),
#  ('如此', 150),
#  ('设置', 150),
#  ('图片', 150),
#  ('太差', 150),
#  ('待机时间', 150),
#  ('作为', 149),
#  ('有时', 148),
#  ('原来', 148),
#  ('方面', 148),
#  ('旧', 148),
#  ('服务态度', 147),
#  ('接受', 147),
#  ('反应', 147),
#  ('餐厅', 146),
#  ('便宜', 145),
#  ('所谓', 144),
#  ('恶心', 144),
#  ('客房', 144),
#  ('早上', 144),
#  ('刚', 143),
#  ('大床', 143),
#  ('购买', 142),
#  ('印刷', 142),
#  ('啦', 142),
#  ('小姐', 142),
#  ('经理', 142),
#  ('书中', 141),
#  ('或者', 140),
#  ('还好', 140),
#  ('15', 140),
#  ('很小', 139),
#  ('上当', 139),
#  ('如', 139),
#  ('估计', 139),
#  ('左右', 139),
#  ('必须', 139),
#  ('反馈', 139),
#  ('告知', 139),
#  ('套书', 138),
#  ('光盘', 138),
#  ('如何', 138),
#  ('于', 138),
#  ('清楚', 138),
#  ('鼠标', 138),
#  ('联系', 137),
#  ('意思', 137),
#  ('产品', 137),
#  ('包装', 136),
#  ('死', 136),
#  ('这是', 136),
#  ('尤其', 136),
#  ('找到', 135),
#  ('老', 135),
#  ('半天', 135),
#  ('再次', 135),
#  ('那些', 134),
#  ('以', 134),
#  ('所', 134),
#  ('此', 134),
#  ('理解', 134),
#  ('同事', 134),
#  ('绝对', 134),
#  ('解决', 133),
#  ('当时', 133),
#  ('光驱', 133),
#  ('及', 132),
#  ('快递', 132),
#  ('客户', 132),
#  ('分区', 132),
#  ('实际', 131),
#  ('xp', 131),
#  ('浪费', 130),
#  ('下去', 130),
#  ('最差', 130),
#  ('当然', 130),
#  ('三星', 130),
#  ('蓝牙', 130),
#  ('货', 129),
#  ('处理', 129),
#  ('且', 129),
#  ('回来', 129),
#  ('进行', 129),
#  ('信号', 129),
#  ('花', 128),
#  ('短', 127),
#  ('一看', 127),
#  ('电视', 127),
#  ('四星', 127),
#  ('反正', 126),
#  ('回复', 125),
#  ('习惯', 125),
#  ('唯一', 125),
#  ('掉', 125),
#  ('明白', 125),
#  ('结帐', 125),
#  ('一套', 124),
#  ('严重', 124),
#  ('语言', 124),
#  ('心理', 124),
#  ('离', 124),
#  ('VISTA', 124),
#  ('几页', 123),
#  ('好看', 123),
#  ('硬件', 123),
#  ('楼', 123),
#  ('内', 122),
#  ('考虑', 122),
#  ('这本', 122),
#  ('帮', 122),
#  ('>', 122),
#  ('性价比', 122),
#  ('提出', 122),
#  ('MP3', 122),
#  ('毛巾', 122),
#  ('实用', 121),
#  ('带', 121),
#  ('是否', 121),
#  ('解释', 121),
#  ('别的', 121),
#  ('吵', 121),
#  ('买来', 120),
#  ('要是', 120),
#  ('#', 120),
#  ('企业', 119),
#  ('读者', 119),
#  ('于是', 119),
#  ('首先', 119),
#  ('女人', 118),
#  ('兴趣', 118),
#  ('重新', 118),
#  ('总是', 118),
#  ('些', 118),
#  ('整个', 118),
#  ('电梯', 118),
#  ('招待所', 118),
#  ('送货', 117),
#  ('水', 117),
#  ('放', 117),
#  ('收费', 117),
#  ('定', 116),
#  ('几乎', 116),
#  ('事', 116),
#  ('相信', 116),
#  ('缺点', 116),
#  ('地毯', 116),
#  ('差不多', 115),
#  ('两天', 115),
#  ('星级', 115),
#  ('水平', 114),
#  ('向', 114),
#  ('看着', 114),
#  ('外面', 114),
#  ('先', 114),
#  ('长', 114),
#  ('不爽', 113),
#  ('论语', 112),
#  ('小孩', 112),
#  ('其', 112),
#  ('肯定', 112),
#  ('认为', 111),
#  ('总', 111),
#  ('卖', 111),
#  ('相当', 111),
#  ('不足', 111),
#  ('宝宝', 111),
#  ('进去', 111),
#  ('低', 111),
#  ('只好', 111),
#  ('一家', 111),
#  ('vista', 111),
#  ('其中', 110),
#  ('反映', 110),
#  ('心情', 110),
#  ('总体', 110),
#  ('爱', 110),
#  ('一种', 110),
#  ('再也', 110),
#  ('豪华', 110),
#  ('床', 109),
#  ('单词', 108),
#  ('靠', 108),
#  ('弄', 108),
#  ('饭店', 108),
#  ('键', 108),
#  ('重', 107),
#  ('难道', 107),
#  ('女儿', 107),
#  ('好多', 107),
#  ('加', 107),
#  ('售后', 107),
#  ('唉', 106),
#  ('最好', 106),
#  ('不敢', 106),
#  ('样子', 106),
#  ('<', 106),
#  ('操作', 106),
#  ('包', 106),
#  ('其它', 105),
#  ('哦', 105),
#  ('下午', 105),
#  ('次', 105),
#  ('看起来', 104),
#  ('那里', 104),
#  ('上面', 104),
#  ('画面', 104),
#  ('象', 104),
#  ('分', 104),
#  ('不同', 103),
#  ('颜色', 103),
#  ('宽带', 103),
#  ('指纹', 103),
#  ('预装', 103),
#  ('不少', 102),
#  ('并且', 102),
#  ('关于', 102),
#  ('拉拉', 102),
#  ('发货', 102),
#  ('......', 102),
#  ('睡觉', 102),
#  ('同时', 102),
#  ('每次', 102),
#  ('是因为', 101),
#  ('最大', 101),
#  ('张爱玲', 101),
#  ('不用', 101),
#  ('一张', 100),
#  ('退', 100),
#  ('照片', 100),
#  ('预订', 100),
#  ('总台', 100),
#  ('窗户', 100),
#  ('怀疑', 99),
#  ('至少', 99),
#  ('一句', 99),
#  ('就算', 98),
#  ('了解', 98),
#  ('过去', 98),
#  ('退货', 98),
#  ('遇到', 98),
#  ('不怎么样', 98),
#  ('可惜', 98),
#  ('买回来', 98),
#  ('不值', 98),
#  ('成', 98),
#  ('晕', 98),
#  ('后面', 98),
#  ('收', 98),
#  ('更好', 97),
#  ('多少', 97),
#  ('*', 97),
#  ('啥', 97),
#  ('行李', 97),
#  ('过来', 96),
#  ('丹', 96),
#  ('以上', 96),
#  ('显卡', 96),
#  ('没法', 95),
#  ('盘', 95),
#  ('专业', 95),
#  ('看来', 95),
#  ('准备', 95),
#  ('商务', 95),
#  ('房价', 95),
#  ('自带', 95),
#  ('关机', 95),
#  ('帮助', 94),
#  ('部分', 94),
#  ('话', 94),
#  ('随便', 94),
#  ('极差', 94),
#  ('家', 94),
#  ('外观', 94),
#  ('拍照', 94),
#  ('做工', 94),
#  ('英语', 93),
#  ('经历', 93),
#  ('能够', 93),
#  ('比如', 93),
#  ('作品', 93),
#  ('人家', 93),
#  ('放在', 93),
#  ('网站', 93),
#  ('现象', 93),
#  ('2007', 93),
#  ('主要', 92),
#  ('只要', 92),
#  ('炒作', 92),
#  ('确认', 92),
#  ('成功', 92),
#  ('100', 92),
#  ('脏', 92),
#  ('笔记本', 92),
#  ('无线', 92),
#  ('强', 91),
#  ('明明', 91),
#  ('信息', 91),
#  ('么', 91),
#  ('近', 91),
#  ('热水', 91),
#  ('USB', 91),
#  ('那样', 90),
#  ('文章', 90),
#  ('注意', 90),
#  ('间', 90),
#  ('16', 90),
#  ('跑', 90),
#  ('四星级', 90),
#  ('方法', 89),
#  ('吸引', 89),
#  ('决定', 89),
#  ('糟糕', 89),
#  ('一股', 89),
#  ('道理', 88),
#  ('不管', 88),
#  ('一边', 88),
#  ('英文', 88),
#  ('而已', 88),
#  ('网络', 88),
#  ('不太好', 88),
#  ('块', 88),
#  ('维修', 88),
#  ('运行', 88),
#  ('来看', 87),
#  ('似乎', 87),
#  ('得到', 87),
#  ('大概', 87),
#  ('没想到', 87),
#  ('太慢', 87),
#  ('普通', 87),
#  ('进', 87),
#  ('十分', 87),
#  ('未', 87),
#  ('哎', 87),
#  ('门口', 87),
#  ('床单', 87),
#  ('\u3000', 87),
#  ('来电', 87),
#  ('`', 86),
#  ('稍微', 86),
#  ('外壳', 86),
#  ('200', 85),
#  ('每天', 85),
#  ('顾客', 85),
#  ('超级', 85),
#  ('14', 85),
#  ('游戏', 85),
#  ('@', 85),
#  ('自动', 85),
#  ('千万', 84),
#  ('奇怪', 84),
#  ('继续', 84),
#  ('几天', 84),
#  ('温度', 84),
#  ('本身', 84),
#  ('否则', 84),
#  ('宣传', 84),
#  ('三个', 84),
#  ('车', 84),
#  ('管理', 84),
#  ('楼层', 84),
#  ('噪音', 84),
#  ('一间', 84),
#  ('通话', 84),
#  ('这书', 83),
#  ('几次', 83),
#  ('方式', 83),
#  ('安排', 83),
#  ('门', 83),
#  ('洗澡', 83),
#  ('远离', 83),
#  ('网卡', 83),
#  ('手感', 83),
#  ('过于', 82),
#  ('回', 82),
#  ('遗憾', 82),
#  ('终于', 82),
#  ('风扇', 82),
#  ('行', 81),
#  ('破', 81),
#  ('名字', 81),
#  ('升级', 81),
#  ('别', 80),
#  ('好象', 80),
#  ('公平', 80),
#  ('远', 80),
#  ('上海', 80),
#  ('屏', 80),
#  ('人物', 79),
#  ('....', 79),
#  ('教育', 79),
#  ('消费者', 79),
#  ('甚至', 79),
#  ('五星', 79),
#  ('回答', 79),
#  ('员工', 79),
#  ('40', 79),
#  ('马上', 79),
#  ('取消', 79),
#  ('联想', 79),
#  ('走廊', 79),
#  ('版本', 78),
#  ('韩国', 78),
#  ('没收', 78),
#  ('一个月', 78),
#  ('出租车', 78),
#  ('通知', 78),
#  ('睡', 78),
#  ('交通', 78),
#  ('外', 77),
#  ('哪里', 77),
#  ('第一', 77),
#  ('另', 77),
#  ('早就', 77),
#  ('进入', 77),
#  ('拒绝', 77),
#  ('隔壁', 77),
#  ('信用卡', 77),
#  ('充电', 77),
#  ('机身', 77),
#  ('令人', 76),
#  ('办理', 76),
#  ('一半', 76),
#  ('那种', 76),
#  ('小心', 76),
#  ('的确', 76),
#  ('能力', 76),
#  ('错误', 76),
#  ('接口', 76),
#  ('学习', 75),
#  ('我要', 75),
#  ('用户', 75),
#  ('出去', 75),
#  ('附近', 75),
#  ('吃饭', 75),
#  ('观点', 74),
#  ('情节', 74),
#  ('纸张', 74),
#  ('好好', 74),
#  ('过程', 74),
#  ('优点', 74),
#  ('有人', 74),
#  ('同样', 74),
#  ('电源', 74),
#  ('耳机', 74),
#  ('笑', 73),
#  ('粗糙', 73),
#  ('半个', 73),
#  ('送到', 73),
#  ('存在', 73),
#  ('提高', 73),
#  ('难', 73),
#  ('梅拉', 73),
#  ('发票', 73),
#  ('０', 73),
#  ('塑料', 73),
#  ('标间', 73),
#  ('触摸板', 73),
#  ('调', 72),
#  ('中午', 72),
#  ('不怎么', 72),
#  ('没用', 72),
#  ('意见', 72),
#  ('久', 72),
#  ('差劲', 72),
#  ('不合理', 72),
#  ('价钱', 71),
#  ('配置', 71),
#  ('本本', 71),
#  ('旁边', 71),
#  ('房费', 71),
#  ('数据线', 71),
#  ('发', 70),
#  ('男人', 70),
#  ('意义', 70),
#  ('送给', 70),
#  ('真正', 70),
#  ('张', 70),
#  ('感受', 70),
#  ('期间', 70),
#  ('目前', 70),
#  ('电', 70),
#  ('店', 70),
#  ('房间内', 70),
#  ('半夜', 70),
#  ('盗版', 69),
#  ('无聊', 69),
#  ('发生', 69),
#  ('各位', 69),
#  ('周围', 69),
#  ('前面', 69),
#  ('一位', 69),
#  ('设备', 69),
#  ('就要', 69),
#  ('感谢您', 69),
#  ('卫生', 69),
#  ('职场', 68),
#  ('全部', 68),
#  ('50', 68),
#  ('播放', 68),
#  ('浴室', 68),
#  ('乱', 67),
#  ('正在', 67),
#  ('导致', 67),
#  ('起', 67),
#  ('师', 67),
#  ('听到', 67),
#  ('有个', 67),
#  ('到达', 67),
#  ('文笔', 66),
#  ('处', 66),
#  ('怎样', 66),
#  ('色彩', 66),
#  ('到底', 66),
#  ('机场', 66),
#  ('北京', 66),
#  ('修', 66),
#  ('机', 66),
#  ('毛病', 66),
#  ('厚', 65),
#  ('烂', 65),
#  ('第', 65),
#  ('而是', 65),
#  ('..', 65),
#  ('一条', 65),
#  ('度', 65),
#  ('被子', 65),
#  ('不住', 65),
#  ('消费', 65),
#  ('内置', 65),
#  ('输入', 65),
#  ('t', 65),
#  ('http', 65),
#  ('错', 64),
#  ('许多', 64),
#  ('风格', 64),
#  ('广告', 64),
#  ('气愤', 64),
#  ('星期', 64),
#  ...]

# %%
pos_neg_ratios = Counter()
for term,cnt in list(total_counts.most_common()):
    if(cnt > 100):
        pos_neg_ratio = positive_counts[term] / float(negative_counts[term]+1)
        pos_neg_ratios[term] = pos_neg_ratio

# %%
list(reversed(pos_neg_ratios.most_common()))[0:30]
# Out:
# [('爱玲', 1.9428571428571428),
#  ('篡改', 1.9473684210526316),
#  ('吹捧', 1.9487179487179487),
#  ('于丹', 1.9523809523809523),
#  ('恶劣', 1.9545454545454546),
#  ('切糕', 1.9666666666666666),
#  ('日货', 2.0217391304347827),
#  ('旅馆', 2.022222222222222),
#  ('倒闭', 2.025),
#  ('再也不会', 2.026315789473684),
#  ('太烂', 2.0285714285714285),
#  ('上当', 2.0285714285714285),
#  ('工作日', 2.0294117647058822),
#  ('丹', 2.0412371134020617),
#  ('胡兰成', 2.0689655172413794),
#  ('炒作', 2.075268817204301),
#  ('无耻', 2.0754716981132075),
#  ('不买', 2.099378881987578),
#  ('求己', 2.1025641025641026),
#  ('无良', 2.1052631578947367),
#  ('畅销书', 2.121212121212121),
#  ('最差', 2.122137404580153),
#  ('骗', 2.14),
#  ('要命', 2.1458333333333335),
#  ('烂', 2.1515151515151514),
#  ('抵制', 2.1634980988593155),
#  ('毕淑敏', 2.1666666666666665),
#  ('看不下去', 2.1666666666666665),
#  ('师', 2.1911764705882355),
#  ('退货', 2.191919191919192)]

# %%
for word,ratio in pos_neg_ratios.most_common():
    if(ratio > 1):
        pos_neg_ratios[word] = np.log(ratio)
    else:
        pos_neg_ratios[word] = -np.log((1 / (ratio+0.01)))

# %%
pos_neg_ratios.most_common()
# Out:
# [('数学', 5.2882670306945352),
#  ('青春', 5.1239639794032588),
#  ('悲伤', 5.0106352940962555),
#  ('结局', 4.9052747784384296),
#  ('荐', 4.9052747784384296),
#  ('回忆', 4.8559289043352747),
#  ('【', 4.7874917427820458),
#  ('孤独', 4.7874917427820458),
#  ('】', 4.7621739347977563),
#  ('朴实', 4.7621739347977563),
#  ('彼此', 4.7621739347977563),
#  ('少年', 4.7361984483944957),
#  ('清新', 4.7361984483944957),
#  ('功能齐全', 4.7361984483944957),
#  ('恐龙', 4.7095302013123339),
#  ('一书', 4.6821312271242199),
#  ('诗词', 4.6539603501575231),
#  ('英雄', 4.6249728132842707),
#  ('秘密', 4.6249728132842707),
#  ('大方', 4.6200587984818418),
#  ('坚强', 4.5591262474866845),
#  ('伤感', 4.4942386252808095),
#  ('回味', 4.42484663185681),
#  ('贴纸', 4.3882571844245177),
#  ('写意', 4.3502779363593014),
#  ('棒', 4.3481250829981999),
#  ('命运', 4.3174881135363101),
#  ('加油', 4.3107991253855138),
#  ('饮食', 4.3107991253855138),
#  ('学者', 4.2696974496999616),
#  ('一流', 4.2532458448079566),
#  ('领域', 4.1820501426412067),
#  ('温暖', 4.1549691840385359),
#  ('大师', 4.1549691840385359),
#  ('细细', 4.1351665567423561),
#  ('×', 4.1351665567423561),
#  ('成长', 4.1285995867724194),
#  ('人们', 4.1155467698727035),
#  ('展现', 4.1108738641733114),
#  ('快乐', 4.0973702831386376),
#  ('不愧', 4.0859763125515842),
#  ('优雅', 4.0859763125515842),
#  ('划算', 4.0859763125515842),
#  ('功能强大', 4.0859763125515842),
#  ('超值', 4.0809215418899605),
#  ('学校', 4.0604430105464191),
#  ('粒', 4.0604430105464191),
#  ('走向', 4.0342406381523954),
#  ('眼前', 4.0342406381523954),
#  ('亲情', 4.0342406381523954),
#  ('羡慕', 4.0312864262549635),
#  ('讲解', 3.9889840465642745),
#  ('往往', 3.9749978045895347),
#  ('人类', 3.9639827443588569),
#  ('知识点', 3.9512437185814275),
#  ('物超所值', 3.9512437185814275),
#  ('实践', 3.9464244321454784),
#  ('古代', 3.8572147689331513),
#  ('轻便', 3.8572147689331513),
#  ('点滴', 3.8554526539397518),
#  ('自由', 3.8367605209275992),
#  ('美', 3.8322580369592836),
#  ('简洁', 3.8286413964890951),
#  ('著作', 3.7898553714539385),
#  ('周到', 3.7887247890836524),
#  ('深深', 3.7727609380946383),
#  ('充分', 3.7689221617874726),
#  ('神秘', 3.7196511127806899),
#  ('小巧', 3.7157869070338605),
#  ('优秀', 3.7065790312133373),
#  ('幸运', 3.7013019741124933),
#  ('清醒', 3.6971782569286313),
#  ('篇', 3.6971782569286313),
#  ('世界', 3.6897124404178281),
#  ('幸福', 3.6875627982291896),
#  ('喜来登', 3.6720723357975551),
#  ('艺术', 3.6635616461296463),
#  ('童话', 3.6635616461296463),
#  ('平凡', 3.6584202466292277),
#  ('童年', 3.6525118099430616),
#  ('自信', 3.6463198396951406),
#  ('考试', 3.6441435602725449),
#  ('思考', 3.6399756471237672),
#  ('爸爸', 3.6317210402739879),
#  ('美丽', 3.6243409329763652),
#  ('过瘾', 3.6243409329763652),
#  ('大气', 3.6243409329763652),
#  ('贴心', 3.619886582626985),
#  ('结尾', 3.6041382256588457),
#  ('淡淡的', 3.6041382256588457),
#  ('在读', 3.5927355935610339),
#  ('无限', 3.5927355935610339),
#  ('酸酸乳', 3.5779478934066544),
#  ('出色', 3.5489786132039338),
#  ('渴望', 3.5409593240373143),
#  ('宝贝', 3.5198031240700023),
#  ('女主角', 3.5189804173185388),
#  ('均衡', 3.5189804173185388),
#  ('乐观', 3.5085558999826545),
#  ('适中', 3.5085558999826545),
#  ('受益匪浅', 3.499868909169185),
#  ('力量', 3.4965075614664802),
#  ('情感', 3.4927124904979285),
#  ('意外', 3.4904285153900978),
#  ('物有所值', 3.4904285153900978),
#  ('某', 3.4735180432417816),
#  ('视角', 3.4719664525503626),
#  ('独特', 3.4709307196768306),
#  ('现代', 3.4578927253387008),
#  ('时光', 3.4552646029324312),
#  ('不仅仅', 3.4531571205928664),
#  ('应用', 3.4531571205928664),
#  ('感谢', 3.450677438925525),
#  ('梦想', 3.4499875458315872),
#  ('伟大', 3.4499875458315872),
#  ('平静', 3.4258899942525267),
#  ('读一读', 3.4258899942525267),
#  ('危机', 3.4258899942525267),
#  ('好用', 3.4231762883809305),
#  ('小时候', 3.4218166688648912),
#  ('很漂亮', 3.4193646856176043),
#  ('兴奋', 3.414442608412176),
#  ('有着', 3.4111477125153233),
#  ('战争', 3.4067375620377707),
#  ('外形', 3.4011973816621555),
#  ('惊喜', 3.4011973816621555),
#  ('女主', 3.4011973816621555),
#  ('练习', 3.4011973816621555),
#  ('心态', 3.3970220102516748),
#  ('理性', 3.3945083935113587),
#  ('看一看', 3.3758795736778655),
#  ('不禁', 3.3758795736778655),
#  ('以往', 3.3758795736778655),
#  ('图书馆', 3.3758795736778655),
#  ('旋转', 3.3758795736778655),
#  ('外型', 3.3730265046954591),
#  ('母亲', 3.3596034843633182),
#  ('面对', 3.3549040976913105),
#  ('香蕉', 3.3534067178258069),
#  ('赞', 3.3514977131098829),
#  ('善良', 3.3499040872746049),
#  ('年轻', 3.3322045101752038),
#  ('心灵', 3.3286266888273199),
#  ('增强', 3.3232358401924436),
#  ('成就', 3.3232358401924436),
#  ('未来', 3.3178157727231046),
#  ('超越', 3.3105430133940246),
#  ('一步', 3.3105430133940246),
#  ('灵魂', 3.2958368660043291),
#  ('坎坷', 3.2958368660043291),
#  ('信念', 3.2958368660043291),
#  ('轻巧', 3.2958368660043291),
#  ('景色', 3.2958368660043291),
#  ('很强', 3.2798365246578882),
#  ('迷茫', 3.2676659890376327),
#  ('音效', 3.2676659890376327),
#  ('优美', 3.2657594107670511),
#  ('将来', 3.2657594107670511),
#  ('强烈推荐', 3.2635760037861075),
#  ('结合', 3.2619353143286478),
#  ('漂亮', 3.2531533742239627),
#  ('魅力', 3.2425923514855168),
#  ('随着', 3.2386784521643803),
#  ('相处', 3.2386784521643803),
#  ('世纪', 3.2386784521643803),
#  ('校车', 3.2386784521643803),
#  ('梦', 3.2386784521643803),
#  ('爱不释手', 3.2268439945173775),
#  ('乐趣', 3.2255203675868693),
#  ('人生', 3.2233104219360666),
#  ('语音', 3.2188758248682006),
#  ('温馨', 3.2163726946500821),
#  ('很棒', 3.2148678034706619),
#  ('真不错', 3.2088254890146994),
#  ('特点', 3.2079067934976266),
#  ('多种', 3.2054528045360602),
#  ('日常', 3.196402969016142),
#  ('美中不足', 3.1957534074473464),
#  ('感人', 3.1945831322991562),
#  ('制度', 3.1945831322991562),
#  ('强大', 3.1928251476682581),
#  ('动物', 3.1928251476682581),
#  ('整洁', 3.1904763503465028),
#  ('感动', 3.1895614371994254),
#  ('亲切', 3.188416617383492),
#  ('反思', 3.1849742731925192),
#  ('正品', 3.1849742731925192),
#  ('好书', 3.1799459784999837),
#  ('培养', 3.1605402478552374),
#  ('观察', 3.1600353248452673),
#  ('挺不错', 3.1600353248452673),
#  ('引导', 3.1570004211501135),
#  ('具有', 3.1522610757862166),
#  ('积极', 3.142714463902637),
#  ('感悟', 3.1416861861770706),
#  ('万色', 3.1416861861770706),
#  ('情绪', 3.1409142833984891),
#  ('跟着', 3.1398326175277478),
#  ('老师', 3.133203264182594),
#  ('质感', 3.1267605359603952),
#  ('写出', 3.1245651453969594),
#  ('爽', 3.1229940531649181),
#  ('难度', 3.120895416507997),
#  ('难得', 3.1110431200649855),
#  ('最初', 3.1039458581942236),
#  ('投资', 3.0985896589936988),
#  ('压力', 3.0985896589936988),
#  ('入手', 3.0985896589936988),
#  ('够用', 3.0910424533583161),
#  ('挺快', 3.0910424533583161),
#  ('一路', 3.0910424533583161),
#  ('一如既往', 3.0910424533583161),
#  ('配置', 3.0897790293115439),
#  ('分析', 3.0875398228071136),
#  ('设定', 3.0845277723371223),
#  ('外观', 3.0838395410642576),
#  ('那段', 3.0757749812275277),
#  ('足够', 3.0706335817271087),
#  ('很快', 3.068946989730498),
#  ('妈妈', 3.0675119559481216),
#  ('齐全', 3.066501344442198),
#  ('人性', 3.0662624243598287),
#  ('看似', 3.0563568953704259),
#  ('花园', 3.0524276172305362),
#  ('那时', 3.0497994948242666),
#  ('亦', 3.04848283893952),
#  ('神奇', 3.044522437723423),
#  ('单纯', 3.044522437723423),
#  ('也好', 3.0411152794018088),
#  ('爱情', 3.0388373740888146),
#  ('父母', 3.0354107573721674),
#  ('上学', 3.0349529867072724),
#  ('黑暗', 3.0349529867072724),
#  ('鼓励', 3.0349529867072724),
#  ('想起', 3.0301337002713233),
#  ('爱', 3.0267768952359511),
#  ('慢慢', 3.0262152902790671),
#  ('拥有', 3.0204248861443626),
#  ('先生', 3.012826706913291),
#  ('深刻', 3.0081547935525483),
#  ('诱惑', 3.0056826044071592),
#  ('沉重', 3.0056826044071592),
#  ('这句', 3.0056826044071592),
#  ('外观设计', 3.0040310763686859),
#  ('时尚', 3.0023768162726596),
#  ('宽敞', 3.0019628233046269),
#  ('知识', 3.0007198150650303),
#  ('有意思', 2.9995710498611565),
#  ('^', 2.9986691332273008),
#  ('实惠', 2.9980024220885304),
#  ('不错', 2.9976359482198927),
#  ('历史', 2.9847345193444497),
#  ('文中', 2.9831534913471307),
#  ('奇妙', 2.9813435361018916),
#  ('年轻人', 2.9813435361018916),
#  ('全面', 2.9809171877688505),
#  ('庆幸', 2.9789251552376097),
#  ('光明', 2.9746788643561586),
#  ('完整', 2.9746788643561586),
#  ('喜爱', 2.9704144655697009),
#  ('每个', 2.9691526357492788),
#  ('寻找', 2.9687036011660717),
#  ('形成', 2.9531726591351952),
#  ('读完', 2.9521116510781007),
#  ('完美', 2.9480210725489449),
#  ('理念', 2.9403821784708262),
#  ('自然', 2.9394138429637673),
#  ('错过', 2.9299808959912106),
#  ('承受', 2.9267394020670396),
#  ('打动', 2.9267394020670396),
#  ('般', 2.9267394020670396),
#  ('有所', 2.9256884298210646),
#  ('方向', 2.9231615807191558),
#  ('丰富', 2.9156062290747062),
#  ('造型', 2.9153107062434169),
#  ('绘本', 2.9147632110203237),
#  ('生活', 2.9107259688879381),
#  ('发展', 2.9095110981068624),
#  ('正如', 2.9069010598473755),
#  ('办公', 2.9069010598473755),
#  ('好玩', 2.9041650800285006),
#  ('细腻', 2.9009988504704509),
#  ('良好', 2.9004220937496661),
#  ('迅速', 2.8995884130010889),
#  ('一口气', 2.8985685251003432),
#  ('仿佛', 2.8965256234705428),
#  ('阐述', 2.8903717578961645),
#  ('改变', 2.8840023096106848),
#  ('心中', 2.8791984572980396),
#  ('风景', 2.8779492378976075),
#  ('配有', 2.8716796248840124),
#  ('乳', 2.8716796248840124),
#  ('枯燥', 2.8662742063171041),
#  ('一生', 2.8645790033344358),
#  ('广场', 2.8622008809294686),
#  ('研究', 2.8574276021768106),
#  ('一切', 2.855909353709988),
#  ('讲述', 2.8498803965414279),
#  ('海景', 2.8487778605973277),
#  ('黑白', 2.8429695190015809),
#  ('恋爱', 2.8429695190015809),
#  ('毫不犹豫', 2.8415815937267328),
#  ('轻薄', 2.8415815937267328),
#  ('通俗易懂', 2.8405393841482889),
#  ('一岁', 2.83972802507741),
#  ('阶段', 2.83972802507741),
#  ('内心', 2.8364759896910328),
#  ('性价比', 2.8293800858885545),
#  ('学习', 2.8293358673097955),
#  ('价格便宜', 2.8233610476132043),
#  ('感情', 2.823019575866673),
#  ('矛盾', 2.8162637857424428),
#  ('小家伙', 2.8162637857424428),
#  ('精致', 2.814947996078923),
#  ('展示', 2.8134107167600364),
#  ('太好了', 2.8134107167600364),
#  ('TFT', 2.8061114142784249),
#  ('每', 2.8033603809065348),
#  ('付出', 2.8033603809065348),
#  ('成熟', 2.8033603809065348),
#  ('美国', 2.8019163373343012),
#  ('获得', 2.8013381355257669),
#  ('超大', 2.7999876964278956),
#  ('流畅', 2.7993117923805348),
#  ('轻松', 2.796845699885341),
#  ('变焦', 2.7957557815213154),
#  ('成为', 2.7937909298903842),
#  ('创造', 2.7902882993391822),
#  ('买下', 2.7894905330423847),
#  ('原则', 2.7829515092753279),
#  ('足以', 2.7829515092753279),
#  ('眼泪', 2.7829515092753279),
#  ('关心', 2.7829515092753279),
#  ('数码', 2.7829515092753279),
#  ('250G', 2.7829515092753279),
#  ('强劲', 2.7829515092753279),
#  ('熟悉', 2.7803708626818362),
#  ('满足', 2.774900861998161),
#  ('品质', 2.7725887222397811),
#  ('读后', 2.7725887222397811),
#  ('总会', 2.7725887222397811),
#  ('偶', 2.7725887222397811),
#  ('用心', 2.7656200529236878),
#  ('男主角', 2.7636200522570209),
#  ('几遍', 2.7636200522570209),
#  ('清晰', 2.7627364257967697),
#  ('学会', 2.7593434954897607),
#  ('大学', 2.7593434954897607),
#  ('小学', 2.7591053719024941),
#  ('对得起', 2.7586024802650413),
#  ('表现', 2.7522214194153474),
#  ('了解', 2.7521798506085742),
#  ('同学', 2.7507166474211129),
#  ('震撼', 2.7488721956224653),
#  ('偶然', 2.7488721956224653),
#  ('认识', 2.7451897480516667),
#  ('传统', 2.7448641742249262),
#  ('可爱', 2.7447662166404823),
#  ('尽管', 2.7437682837042892),
#  ('身体', 2.7433183399396679),
#  ('感慨', 2.7372493557944724),
#  ('向往', 2.7362210780689065),
#  ('好喝', 2.7233176732329984),
#  ('电影', 2.7229388135959609),
#  ('享受', 2.7080502011022101),
#  ('勇敢', 2.7080502011022101),
#  ('常常', 2.7080502011022101),
#  ('汤姆', 2.7080502011022101),
#  ('型', 2.7080502011022101),
#  ('去过', 2.7080502011022101),
#  ('行业', 2.7080502011022101),
#  ('蓝色', 2.7080502011022101),
#  ('许多', 2.7070240337468978),
#  ('长大', 2.7041209229623204),
#  ('更加', 2.7010815317861168),
#  ('礼物', 2.6991215703579088),
#  ('一款', 2.6974680917716731),
#  ('美观', 2.6968769005040847),
#  ('性能', 2.6963417118373099),
#  ('还会', 2.6956934684133045),
#  ('概念', 2.6931245508855346),
#  ('精细', 2.6931245508855346),
#  ('和弦铃声', 2.6931245508855346),
#  ('彩屏', 2.6925460145662448),
#  ('关注', 2.6918273655953229),
#  ('细节', 2.690350624002809),
#  ('追求', 2.6897010624340134),
#  ('一读', 2.6888188391743224),
#  ('值', 2.6878474937846906),
#  ('迫不及待', 2.6878474937846906),
#  ('究竟', 2.6878474937846906),
#  ('教材', 2.6855773452501515),
#  ('珍惜', 2.6827323931179201),
#  ('真实', 2.6816895314111413),
#  ('家长', 2.6816895314111413),
#  ('智慧', 2.6803986697717002),
#  ('正是', 2.6779727458649321),
#  ('主流', 2.6767976575981058),
#  ('采用', 2.6764448616868788),
#  ('作文', 2.6741486494265287),
#  ('记得', 2.6731031710249757),
#  ('更为', 2.6703098731193631),
#  ('之中', 2.6703098731193631),
#  ('姐姐', 2.6672282065819548),
#  ('不仅', 2.6660019648587108),
#  ('那本', 2.6646997602285962),
#  ('思想', 2.6592600369327779),
#  ('舒适', 2.6574064682834551),
#  ('健康', 2.6521294111826115),
#  ('以及', 2.6519607344511664),
#  ('64', 2.6492097010792768),
#  ('物美价廉', 2.6492097010792768),
#  ('开头', 2.6492097010792768),
#  ('狗', 2.6492097010792768),
#  ('背后', 2.6461747973841225),
#  ('国家', 2.6424529186163968),
#  ('大人', 2.6418008155610093),
#  ('女儿', 2.6357449715022758),
#  ('行为', 2.6328267798646223),
#  ('保持', 2.6306184609693939),
#  ('抱', 2.6306184609693939),
#  ('市中心', 2.6306184609693939),
#  ('从中', 2.6300886596324982),
#  ('社会', 2.6294878785991078),
#  ('真正', 2.627929243105851),
#  ('生动', 2.6257415536394864),
#  ('如同', 2.6246685921631592),
#  ('热爱', 2.6246685921631592),
#  ('哈哈', 2.6239055245946563),
#  ('受益', 2.6230569882688175),
#  ('遍', 2.6210388241125804),
#  ('时代', 2.6198259676873707),
#  ('即使', 2.6197075614353826),
#  ('每晚', 2.6184380424125231),
#  ('体质', 2.6184380424125231),
#  ('市面上', 2.6184380424125231),
#  ('男女', 2.6112003751122925),
#  ('制作', 2.608843551018762),
#  ('总的来说', 2.6051557779395771),
#  ('机会', 2.6047451846264797),
#  ('开心', 2.6026896854443837),
#  ('想法', 2.6026896854443837),
#  ('启发', 2.6009244599198147),
#  ('全新', 2.6002174962989946),
#  ('相对', 2.5990990173136552),
#  ('时期', 2.5985659682605218),
#  ('够', 2.5949075450023287),
#  ('形式', 2.5941059417529924),
#  ('整体', 2.59338729278207),
#  ('创意', 2.59338729278207),
#  ('青岛', 2.5902671654458267),
#  ('幼儿园', 2.5887034434696439),
#  ('美好', 2.5866893440979428),
#  ('较为', 2.5857113489099661),
#  ('曾', 2.5852546236222822),
#  ('搭配', 2.5852546236222822),
#  ('描写', 2.582887058148204),
#  ('教育', 2.5821089777443631),
#  ('小小的', 2.581298495463066),
#  ('题目', 2.5802168295923251),
#  ('从此', 2.5802168295923251),
#  ('感受', 2.5778666522473714),
#  ('需求', 2.5767141990411231),
#  ('重要', 2.5749870828950479),
#  ('指导', 2.5734600471294455),
#  ('感触', 2.5734600471294455),
#  ('快速', 2.5734600471294455),
#  ('屏幕显示', 2.5700644581283072),
#  ('所说', 2.568605668664647),
#  ('各种', 2.5667791841386127),
#  ('欣赏', 2.5649493574615367),
#  ('好奇', 2.5649493574615367),
#  ('地铁站', 2.5649493574615367),
#  ('独显', 2.5649493574615367),
#  ('脆弱', 2.5649493574615367),
#  ('没得说', 2.5649493574615367),
#  ('一种', 2.5593899268813876),
#  ('日子', 2.559014621941722),
#  ('讨论', 2.5572273113676265),
#  ('两人', 2.5572273113676265),
#  ('心里', 2.556904261776705),
#  ('答案', 2.5512817187328731),
#  ('信心', 2.5483284762254965),
#  ('贴近', 2.5477075510270306),
#  ('随意', 2.5477075510270306),
#  ('纯牛奶', 2.5477075510270306),
#  ('优益', 2.5477075510270306),
#  ('共同', 2.5437471498109336),
#  ('接触', 2.5379612127438897),
#  ('比较满意', 2.5374246840714467),
#  ('便利', 2.5374246840714467),
#  ('看待', 2.5356789751614235),
#  ('一一', 2.5356789751614235),
#  ('第一部', 2.5356789751614235),
#  ('工艺', 2.5356789751614235),
#  ('在于', 2.5343867070513699),
#  ('挑', 2.5336968139574321),
#  ('各个', 2.5323731870269239),
#  ('心', 2.5321595346385459),
#  ('勇气', 2.531426665422893),
#  ('身边', 2.5303690238647576),
#  ('带给', 2.5301632413761213),
#  ('做到', 2.5242460643480324),
#  ('该书', 2.5233729306157966),
#  ('步行', 2.5233729306157966),
#  ('兔子', 2.521274293958875),
#  ('教会', 2.521274293958875),
#  ('中学', 2.521274293958875),
#  ('单独', 2.521274293958875),
#  ('有趣', 2.5181322974163205),
#  ('科学', 2.5168000135639539),
#  ('《', 2.5163075502391909),
#  ('掌握', 2.515678308454754),
#  ('日常生活', 2.515678308454754),
#  ('一贯', 2.5095992623783721),
#  ('经典', 2.5094262669623189),
#  ('值得一看', 2.5091209079085948),
#  ('独立', 2.508921525991874),
#  ('购物', 2.507379505640059),
#  ('完后', 2.5055259369907361),
#  ('图画书', 2.5055259369907361),
#  ('动画', 2.5055259369907361),
#  ('MM', 2.5055259369907361),
#  ('则', 2.5006550067561393),
#  ('无论是', 2.5006550067561393),
#  ('书籍', 2.497406812552232),
#  ('处于', 2.4941233048929243),
#  ('就行了', 2.4941233048929243),
#  ('读', 2.4938352805323016),
#  ('曾经', 2.4911371995386364),
#  ('价位', 2.490703767472326),
#  ('身上', 2.4883728577644866),
#  ('宝宝', 2.4871363051152695),
#  ('做工', 2.4866594986154147),
#  ('高兴', 2.4849066497880004),
#  ('正确', 2.4849066497880004),
#  ('出发', 2.4849066497880004),
#  ('》', 2.4829891036587286),
#  ('总体', 2.4811458330198732),
#  ('是从', 2.4807312783775197),
#  ('回家', 2.4798433478314537),
#  ('孩子', 2.4793574271261334),
#  ('准确', 2.4789364828014966),
#  ('避免', 2.477302050402781),
#  ('自助餐', 2.477302050402781),
#  ('易懂', 2.474435349920705),
#  ('热闹', 2.474435349920705),
#  ('精神', 2.4733458273869244),
#  ('使', 2.4724841297894433),
#  ('民族', 2.469158292819861),
#  ('香港', 2.4676648433534942),
#  ('收获', 2.4665092846482843),
#  ('注重', 2.4662145167758478),
#  ('然而', 2.465488563930899),
#  ('无论', 2.4644977781567934),
#  ('实现', 2.4619171315633017),
#  ('提升', 2.4614863755799017),
#  ('办公室', 2.4595888418037104),
#  ('令人满意', 2.4595888418037104),
#  ('位于', 2.4595888418037104),
#  ('运用', 2.4531579514734201),
#  ('手感', 2.4526457875697787),
#  ('到位', 2.4504661598077084),
#  ('变化', 2.4502210918001102),
#  ('刚好', 2.4456859366347188),
#  ('一部', 2.4433576468751279),
#  ('卖家', 2.4423470353692043),
#  ('之所以', 2.4375044108934163),
#  ('大学生', 2.4375044108934163),
#  ('遇见', 2.4375044108934163),
#  ('系列', 2.4369932940921029),
#  ('小灵通', 2.4368974306016398),
#  ('算是', 2.4363087748221219),
#  ('第一本', 2.4346448150071121),
#  ('各', 2.4341614507827649),
#  ('晦涩', 2.4336133554004498),
#  ('提到', 2.4322629163025784),
#  ('经济', 2.4320641684136204),
#  ('她', 2.4318373048020638),
#  ('基础', 2.4310108815828682),
#  ('地理位置', 2.430572298824671),
#  ('抢', 2.4304184645039304),
#  ('合理', 2.4301962175866918),
#  ('活动', 2.4298468726049731),
#  ('记忆', 2.4287619207788977),
#  ('他', 2.4255235409259406),
#  ('路', 2.4250708581773353),
#  ('好吃', 2.4240649905317553),
#  ('阳光', 2.423537703411708),
#  ('利用', 2.4218485138208634),
#  ('教授', 2.4203681286504293),
#  ('顺利', 2.4168531865429848),
#  ('和弦', 2.4150630764207359),
#  ('书中', 2.4137736629251485),
#  ('体会', 2.4095572125462135),
#  ('怀念', 2.4079456086518718),
#  ('分别', 2.4079456086518718),
#  ('平衡', 2.4079456086518718),
#  ('期待', 2.4076378689971891),
#  ('值得', 2.4071119279032946),
#  ('执着', 2.4061257719348861),
#  ('繁华', 2.4061257719348861),
#  ('恨', 2.4061257719348861),
#  ('相当', 2.4059793911983296),
#  ('商场', 2.404863942114464),
#  ('面前', 2.4043677873039879),
#  ('读读', 2.4043677873039879),
#  ('思维', 2.4020189899822326),
#  ('仍然', 2.4012566205010755),
#  ('或许', 2.400489307975417),
#  ('最好', 2.3987445297496257),
#  ('这是', 2.3925725722744726),
#  ('中国', 2.3897709748266278),
#  ('女子', 2.3895964699836756),
#  ('涉及', 2.3871424810221087),
#  ('\\', 2.3856999997045523),
#  ('交通', 2.3851562470209409),
#  ('微笑', 2.3838105329166317),
#  ('入门', 2.3838105329166317),
#  ('养生', 2.3826278006675823),
#  ('坏点', 2.3812282203131589),
#  ('充满', 2.3790711875527353),
#  ('说出', 2.3774864011671637),
#  ('亲人', 2.3774864011671637),
#  ('生命', 2.3730583496514313),
#  ('哭', 2.3724970821927602),
#  ('能够', 2.3724286663613099),
#  ('对比', 2.3690748342628787),
#  ('合适', 2.367123614131617),
#  ('当中', 2.367123614131617),
#  ('抱怨', 2.3648889763302003),
#  ('主人公', 2.364716874101052),
#  ('痛苦', 2.3639937211226894),
#  ('所', 2.3636453497552918),
#  ('进步', 2.3623043276956679),
#  ('适用', 2.3623043276956679),
#  ('金属', 2.3623043276956679),
#  ('天下', 2.3592804366705908),
#  ('高清', 2.3592804366705908),
#  ('不同', 2.3586745596450891),
#  ('收藏', 2.3575672274113986),
#  ('思路', 2.3556949183079943),
#  ('众多', 2.3556949183079943),
#  ('女孩', 2.3553356583795746),
#  ('音质', 2.3552288264794679),
#  ('作家', 2.3545448319247568),
#  ('布置', 2.3513752571634776),
#  ('文字', 2.3501535099131554),
#  ('那种', 2.3482783206529443),
#  ('书后', 2.3466019784108201),
#  ('职业', 2.3460702049337847),
#  ('由', 2.3450058088779979),
#  ('观念', 2.3434070875143007),
#  ('佩服', 2.3434070875143007),
#  ('日本', 2.3425904276077447),
#  ('章节', 2.3407368589584219),
#  ('妹妹', 2.3407368589584219),
#  ('讲故事', 2.3403254209768929),
#  ('猫', 2.3403254209768929),
#  ('套书', 2.3379244594393547),
#  ('对话', 2.3372706509819356),
#  ('大量', 2.3353749158170367),
#  ('阅读', 2.3346244467386623),
#  ('配合', 2.33214389523559),
#  ('还原', 2.3294925459139701),
#  ('结婚', 2.3294925459139701),
#  ('热情', 2.329018350062201),
#  ('精美', 2.3279029009783359),
#  ('毕竟', 2.3237873006446486),
#  ('大厦', 2.3237873006446486),
#  ('新装修', 2.3237873006446486),
#  ('永远', 2.320374634557544),
#  ('故事', 2.3196363428667044),
#  ('速度', 2.3179306626687062),
#  ('伤害', 2.3178525651248343),
#  ('人士', 2.3178525651248343),
#  ('大多', 2.3150076129926029),
#  ('对于', 2.3148499961587987),
#  ('手写', 2.3116349285139637),
#  ('地铁', 2.3105532626432224),
#  ('级', 2.3092296357127142),
#  ('机型', 2.3092296357127142),
#  ('家庭', 2.3090159833243362),
#  ('LED', 2.3067431031427095),
#  ('谢谢', 2.3045439574793787),
#  ('安静', 2.3043379418214602),
#  ('蛮', 2.3025850929940459),
#  ('我会', 2.3025850929940459),
#  ('食物', 2.3025850929940459),
#  ('1000', 2.3025850929940459),
#  ('如今', 2.3025850929940459),
#  ('∩', 2.3025850929940459),
#  ('特色', 2.300081962775927),
#  ('小说', 2.2993748173637973),
#  ('正好', 2.2990072716461616),
#  ('中', 2.2977954841114814),
#  ('紧张', 2.2963154799804504),
#  ('复杂', 2.2951501145065274),
#  ('根据', 2.2951501145065274),
#  ('与', 2.2943585767232419),
#  ('183', 2.2939767184574453),
#  ('之间', 2.2932827003317322),
#  ('专门', 2.2930156419778949),
#  ('电视剧', 2.2930156419778949),
#  ('巧克力', 2.2925347571405443),
#  ('作品', 2.2918898038772979),
#  ('场景', 2.2914117923959205),
#  ('感到', 2.2904427061683204),
#  ('带', 2.290213801191499),
#  ('传说', 2.2891620726619051),
#  ('屏', 2.2889117910938359),
#  ('方面', 2.2883908702284184),
#  ('书上', 2.2873176208632571),
#  ('给予', 2.2864557110641619),
#  ('精彩', 2.2861720633527156),
#  ('她们', 2.2857779746776643),
#  ('表情', 2.2857779746776643),
#  ('高', 2.2851258716222769),
#  ('每天', 2.2849893311036662),
#  ('经历', 2.282165253985303),
#  ('方式', 2.282139401833756),
#  ('设计', 2.2819184561854864),
#  ('轻', 2.2815316837962132),
#  ('嘿嘿', 2.2809235962128662),
#  ('那些', 2.280869526083896),
#  ('认为', 2.2800107709555064),
#  ('当年', 2.2784875414149854),
#  ('同时', 2.2750242934151745),
#  ('悲剧', 2.2749335616635356),
#  ('海边', 2.2749335616635356),
#  ('地', 2.2744946956861591),
#  ('电话簿', 2.2744142160273495),
#  ('&#', 2.2739171981244737),
#  ('其实', 2.2736766168790274),
#  ('玩', 2.2686835413183641),
#  ('解读', 2.2686835413183641),
#  ('那样', 2.267925391168327),
#  ('—', 2.2670203392717614),
#  ('插图', 2.2662174488231708),
#  ('年龄', 2.2662174488231708),
#  ('角度', 2.2640752382321701),
#  ('全', 2.2635345781221727),
#  ('尝试', 2.2626684855886032),
#  ('一是', 2.2617630984737906),
#  ('杂志', 2.2617630984737906),
#  ('一遍', 2.2600254785752498),
#  ('利益', 2.2600254785752498),
#  ('专家', 2.2600254785752498),
#  ('仍', 2.2597449343175535),
#  ('交流', 2.2587824703356527),
#  ('口味', 2.2587824703356527),
#  ('一段', 2.2580167735141692),
#  ('表扬', 2.2578491991526541),
#  ('十分', 2.2560650773591528),
#  ('很近', 2.2550441482250458),
#  ('喜欢', 2.2538183752085961),
#  ('酸奶', 2.2536812860038768),
#  ('作为', 2.2519933068779854),
#  ('呵呵', 2.2509477421778477),
#  ('市场', 2.2494752676800971),
#  ('失去', 2.2490008468599392),
#  ('排版', 2.2487823870010692),
#  ('忘记', 2.2487823870010692),
#  ('赶上', 2.2477768564990508),
#  ('新颖', 2.2464956263430023),
#  ('皆', 2.2464956263430023),
#  ('满意', 2.2457362287618929),
#  ('想要', 2.2437445929711122),
#  ('某些', 2.2431616725232448),
#  ('读物', 2.2416763399070532),
#  ('小朋友', 2.2402663285947875),
#  ('既', 2.2400647360127119),
#  ('不远', 2.2380465718564744),
#  ('目前', 2.2371071636145388),
#  ('全书', 2.2361399935858928),
#  ('欢迎', 2.2361399935858928),
#  ('周末', 2.2361399935858928),
#  ('女孩子', 2.2356908581640154),
#  ('地图', 2.2335922215070942),
#  ('滴', 2.2335922215070942),
#  ('虽然', 2.2334027378494929),
#  ('记录', 2.2308411881352046),
#  ('出门', 2.230340186120717),
#  ('学生', 2.2300144001592104),
#  ('力', 2.2300144001592104),
#  ('角色', 2.2300144001592104),
#  ('尽', 2.2300144001592104),
#  ('厦门', 2.2300144001592104),
#  ('红色', 2.2293816889707507),
#  ('儿童', 2.2291179411121731),
#  ('人物', 2.2286694100438775),
#  ('最近', 2.2278615467981093),
#  ('这套', 2.2270775404859005),
#  ('最终', 2.226212114209472),
#  ('音乐', 2.2261522142423988),
#  ('出版', 2.2256240518579173),
#  ('_', 2.2256240518579173),
#  ('看得', 2.2225423853205091),
#  ('这本', 2.2222035745430855),
#  ('年代', 2.2219171899265908),
#  ('冲动', 2.2216160304603783),
#  ('细致', 2.2210920587428626),
#  ('封面', 2.2205201399397416),
#  ('品牌', 2.2177285575339267),
#  ('使得', 2.217225244042889),
#  ('搜索', 2.217225244042889),
#  ('过程', 2.2163007243970334),
#  ('超市', 2.216200478795225),
#  ('房子', 2.2146163200480884),
#  ('文化', 2.2107775437409227),
#  ('随时', 2.2102117728630306),
#  ('国内', 2.2097717933883079),
#  ('体现', 2.2090590349832224),
#  ('家人', 2.2082744135228043),
#  ('教', 2.2082744135228043),
#  ('一起', 2.2077843375512218),
#  ('儿子', 2.2076728439550197),
#  ('女性', 2.2069807522815839),
#  ('发挥', 2.2064412324411435),
#  ('茶', 2.2064412324411435),
#  ('及时', 2.2061932473189798),
#  ('家里', 2.2041450201807931),
#  ('不得了', 2.2033784429105978),
#  ('读书', 2.2019415672143583),
#  ('美的', 2.2013313592888726),
#  ('能力', 2.2001064237111083),
#  ('而是', 2.1989066635192041),
#  ('很', 2.1987626769881112),
#  ('这方面', 2.1972245773362196),
#  ('欲望', 2.1972245773362196),
#  ('犹豫', 2.1972245773362196),
#  ('拍摄', 2.19523847936459),
#  ('自我', 2.1945108714646233),
#  ('来说', 2.1936990133721803),
#  ('看书', 2.1922740721763634),
#  ('色彩', 2.1922370358251801),
#  ('详细', 2.1919195251065262),
#  ('吸引', 2.1910326070882982),
#  ('一辈子', 2.1906671767900603),
#  ('情节', 2.1897895988487015),
#  ('生', 2.1892564076870427),
#  ('眼光', 2.1892564076870427),
#  ('多多', 2.1892564076870427),
#  ('160', 2.1892564076870427),
#  ('帮助', 2.1890037441913623),
#  ('城市', 2.1881747418163013),
#  ('以', 2.188129847430337),
#  ('不断', 2.187723318212079),
#  ('有种', 2.1873722808932077),
#  ('行动', 2.1870722058722012),
#  ('学到', 2.1865861791311638),
#  ('有关', 2.1863252868781835),
#  ('活着', 2.1852483862895036),
#  ('讲', 2.1849270495258133),
#  ('关于', 2.1841950770458856),
#  ('依然', 2.1828771289280779),
#  ('携带', 2.1822989271195437),
#  ('触摸', 2.1822989271195437),
#  ('描述', 2.1815992594331384),
#  ('只要', 2.1803567075238139),
#  ('本本', 2.1801035365561079),
#  ('聪明', 2.1795250002368185),
#  ('深入', 2.1795250002368185),
#  ('挺', 2.1794753958319371),
#  ('参考', 2.178532444324067),
#  ('生产', 2.178532444324067),
#  ('包含', 2.178532444324067),
#  ('规范', 2.178532444324067),
#  ('mp3', 2.1761711681383868),
#  ('QQ', 2.1761711681383868),
#  ('开始', 2.1759906231499544),
#  ('而', 2.1751049327670464),
#  ('分享', 2.174751721484161),
#  ('数字', 2.174751721484161),
#  ('穿越', 2.174751721484161),
#  ('华丽', 2.174751721484161),
#  ('便', 2.1741688010362936),
#  ('正', 2.1699191266459521),
#  ('方法', 2.1684185780871381),
#  ('游戏', 2.1683890276963322),
#  ('关键', 2.1673716141865382),
#  ('虽', 2.1668534794599204),
#  ('式', 2.1668534794599204),
#  ('技巧', 2.1664529186694654),
#  ('大陆', 2.1649637151179979),
#  ('其中', 2.1646682941409603),
#  ('可以', 2.16328824668095),
#  ('或是', 2.1628231506188871),
#  ('边', 2.1628231506188871),
#  ('回到', 2.162684252084043),
#  ('努力', 2.162619048158744),
#  ('一本', 2.1614639134571214),
#  ('带来', 2.1603200204007686),
#  ('它们', 2.1594842493533721),
#  ('功夫', 2.1559816188021705),
#  ('影子', 2.1559816188021705),
#  ('水果', 2.1550789558854557),
#  ('坚持', 2.1538741364626057),
#  ('书里', 2.1538741364626057),
#  ('哦', 2.152200895962264),
#  ('行', 2.1514785555480156),
#  ('怎样', 2.1514150413049253),
#  ('放下', 2.1503932776521202),
#  ('体积', 2.1503932776521202),
#  ('或者说', 2.1498223384416355),
#  ('好', 2.1491096141559693),
#  ('风格', 2.148177970031647),
#  ('算', 2.1480042131171326),
#  ('的确', 2.1469181126488235),
#  ('今年', 2.1465808445174646),
#  ('终于', 2.1464243622387631),
#  ('们', 2.1451176605407936),
#  ('优点', 2.1439800628174073),
#  ('学', 2.142514145134911),
#  ('着', 2.1419850894868802),
#  ('大小', 2.1419618986611697),
#  ('烤', 2.1419618986611697),
#  ('变得', 2.1400661634962708),
#  ('最高', 2.1400661634962708),
#  ('一面', 2.1400661634962708),
#  ('发生', 2.1383840773132858),
#  ('款', 2.1382262365742637),
#  ('像素', 2.1382262365742637),
#  ('类', 2.137261112568662),
#  ('成人', 2.1361368853563811),
#  ('同', 2.1350113928346466),
#  ('测试', 2.1347042203548856),
#  ('部分', 2.1344778223462209),
#  ('看到', 2.1330812689743199),
#  ('万', 2.1328160022712108),
#  ('哲学', 2.132686056198648),
#  ('对待', 2.1323639431341785),
#  ('尤其', 2.1310085212399197),
#  ('舒服', 2.1308101344372123),
#  ('当然', 2.1305916960523508),
#  ('理论', 2.1294019809974585),
#  ('播放', 2.1289215989432058),
#  ('这些', 2.1280899724495552),
#  ('中医', 2.1275099447208583),
#  ('材质', 2.1269080789187598),
#  ('令', 2.1246981332679566),
#  ('反复', 2.1246981332679566),
#  ('毕业', 2.1238933042506698),
#  ('派', 2.1238933042506698),
#  ('相似', 2.1238933042506698),
#  ('新书', 2.1238933042506698),
#  ('用过', 2.1238933042506698),
#  ('人性化', 2.122926653619575),
#  ('确实', 2.1221893913933054),
#  ('等等', 2.120263536200091),
#  ('来讲', 2.120263536200091),
#  ('动作', 2.120263536200091),
#  ('一眼', 2.120263536200091),
#  ('自己', 2.1181443005622569),
#  ('总是', 2.1175708385111829),
#  ('压抑', 2.1171818696626832),
#  ('非常', 2.115282205849887),
#  ('推荐', 2.1149432862865245),
#  ('一键', 2.1145328614911061),
#  ('主角', 2.1138429683971682),
#  ('出行', 2.112231364502827),
#  ('更', 2.1103455192353042),
#  ('最', 2.1094018412757105),
#  ('为', 2.1072083903934442),
#  ('穿', 2.1068405158679502),
#  ('背景', 2.1064181293780382),
#  ('之一', 2.1056112594132208),
#  ('味', 2.1054170280830968),
#  ('实用', 2.1047337345819641),
#  ('主要', 2.1046585381312011),
#  ('更好', 2.1033872352761898),
#  ('+', 2.1000608288825715),
#  ('&', 2.1000608288825715),
#  ('始终', 2.0977906803480324),
#  ('一件', 2.0977906803480324),
#  ('正在', 2.097656981571177),
#  ('比较', 2.0964703124267472),
#  ('效果', 2.0951564541674816),
#  ('一份', 2.0949457282158011),
#  ('26', 2.0944794190443763),
#  ('干净', 2.0923449465157438),
#  ('方便', 2.0923377114371888),
#  ('甚至', 2.0903196598270188),
#  ('这部', 2.0902524577840516),
#  ('走进', 2.0898043287153825),
#  ('品味', 2.0898043287153825),
#  ('身体健康', 2.0898043287153825),
#  ('欢迎您', 2.0898043287153825),
#  ('价值', 2.0890109926959868),
#  ('现实', 2.0890109926959868),
#  ('来到', 2.0890109926959868),
#  ('大海', 2.0890109926959868),
#  ('名片', 2.0890109926959868),
#  ('通话质量', 2.0890109926959868),
#  ('比如', 2.0887069951256261),
#  ('翻译', 2.0877403444945308),
#  ('两种', 2.0877403444945308),
#  ('分组', 2.0877403444945308),
#  ('一些', 2.0876101870037838),
#  ('种', 2.0863619845244097),
#  ...]

# %% [markdown]
# 我们会发现一些一些词：好，不错，喜欢等带有感情色彩的词

# %%
list(reversed(pos_neg_ratios.most_common()))[0:30]
# Out:
# [('爱玲', 0.664159643686693),
#  ('篡改', 0.66647893347778397),
#  ('吹捧', 0.66717169415668465),
#  ('于丹', 0.66904962898088483),
#  ('恶劣', 0.67015766233524654),
#  ('切糕', 0.67634006224356402),
#  ('日货', 0.70395809666416098),
#  ('旅馆', 0.70419701674653024),
#  ('倒闭', 0.70556970055850243),
#  ('再也不会', 0.70621926212729802),
#  ('太烂', 0.70733181555190172),
#  ('上当', 0.70733181555190172),
#  ('工作日', 0.70774597998109789),
#  ('丹', 0.71355605219115237),
#  ('胡兰成', 0.72704873223562672),
#  ('炒作', 0.73009069575162955),
#  ('无耻', 0.73018845224029438),
#  ('不买', 0.74164153049855586),
#  ('求己', 0.74315760113460672),
#  ('无良', 0.74444047494749577),
#  ('畅销书', 0.75198768058287868),
#  ('最差', 0.7524237904894856),
#  ('骗', 0.76080582903376015),
#  ('要命', 0.76352797732174493),
#  ('烂', 0.76617231557483512),
#  ('抵制', 0.77172640194856634),
#  ('毕淑敏', 0.77318988823348167),
#  ('看不下去', 0.77318988823348167),
#  ('师', 0.78443860076935257),
#  ('退货', 0.78477750340586971)]

# %% [markdown]
# 我们现在有了个大致的判断，对于标注为 positive 和 negative 的其评论其评论切词后是会有写写不同，一些词在正评论中出现的评论会比负评论中多

# %%
vocab = set(total_counts.keys())
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 50884

# %% [markdown]
# ## 对词进行编号
# 现在我们思路是直接对存在的50884个分词进行排号，即一个1*50884的向量，然后对于每段话都可以用一个1*50884的向量表示了

# %%
layer_0 = np.zeros((1,vocab_size))

# %%
word2index = {}

for i,word in enumerate(vocab):
    word2index[word] = i
word2index
# Out:
# {'灰姑娘': 0,
#  '刘弘章': 1,
#  '名不符实': 2,
#  '刺心': 3,
#  '空調': 4,
#  'T6400': 5,
#  '宝贵意见': 6,
#  '成钢': 7,
#  '直言': 8,
#  '司法解释': 9,
#  '巨硬': 10,
#  '不深': 11,
#  '金街': 12,
#  '120M': 13,
#  '挑不出': 14,
#  '代笔': 15,
#  '装不上': 16,
#  '69.5': 17,
#  '贴手': 18,
#  '眼': 19,
#  '八九十': 20,
#  '今人': 21,
#  '朴素': 22,
#  '盆子': 23,
#  '拜拜': 24,
#  '白屏': 25,
#  '七夕': 26,
#  '而索': 27,
#  '太冤': 28,
#  '组中': 29,
#  '遥控器': 30,
#  '咽炎': 31,
#  '三围': 32,
#  '边个': 33,
#  '责任': 34,
#  '爽死': 35,
#  '哐当': 36,
#  '考论': 37,
#  '一伸': 38,
#  '深切': 39,
#  '民间故事': 40,
#  'P50': 41,
#  '微博成': 42,
#  '败絮其中': 43,
#  '65': 44,
#  '五箱': 45,
#  '水斗': 46,
#  '分解': 47,
#  '贵上': 48,
#  '兄第': 49,
#  '宿命': 50,
#  '各饮': 51,
#  '货来': 52,
#  '左晃右': 53,
#  '一接': 54,
#  '其一': 55,
#  '光标键': 56,
#  '封面设计': 57,
#  '吕海锋': 58,
#  '补气': 59,
#  '打预防针': 60,
#  '选页': 61,
#  '得逞': 62,
#  '最贵': 63,
#  '美食节': 64,
#  '叫嚣': 65,
#  '鸡腿': 66,
#  'f11': 67,
#  '锋利': 68,
#  'pplive': 69,
#  '八毛': 70,
#  '打給': 71,
#  '任人': 72,
#  '越修': 73,
#  '情境': 74,
#  '菜': 75,
#  '擬': 76,
#  '良想': 77,
#  '石光荣': 78,
#  '员工素质': 79,
#  '饱和度': 80,
#  '门可罗雀': 81,
#  '漏风': 82,
#  '糟心': 83,
#  '对装': 84,
#  '张券': 85,
#  '卖关子': 86,
#  '摔门': 87,
#  '诗词': 88,
#  '政协会议': 89,
#  '兩天': 90,
#  '有气': 91,
#  '打一': 92,
#  '坦坦荡荡': 93,
#  '真令人': 94,
#  '演讲词': 95,
#  'soho': 96,
#  '英子': 97,
#  '同乡': 98,
#  '坠地': 99,
#  '1024': 100,
#  '天杀': 101,
#  '拍键': 102,
#  '书店': 103,
#  'happy': 104,
#  '唯望': 105,
#  '小半': 106,
#  '解放军': 107,
#  '一款': 108,
#  '众口难调': 109,
#  '付钱': 110,
#  '虚电': 111,
#  '要说': 112,
#  '肇庆': 113,
#  '摩托罗拉': 114,
#  '补好': 115,
#  '迷路': 116,
#  '被迫': 117,
#  '名': 118,
#  '词组': 119,
#  '展示': 120,
#  '安岛': 121,
#  '减点': 122,
#  '樓層': 123,
#  '罗兰德': 124,
#  '久久': 125,
#  'caps': 126,
#  '六瓣': 127,
#  'ρ': 128,
#  '留美': 129,
#  '未退': 130,
#  '宏大': 131,
#  '应当': 132,
#  '舞曲': 133,
#  '人报': 134,
#  '本着': 135,
#  '茅坑': 136,
#  '超高': 137,
#  '随性': 138,
#  '154': 139,
#  '旅伴': 140,
#  '那盏': 141,
#  '假话': 142,
#  '利乐': 143,
#  '轻叹': 144,
#  '态度生硬': 145,
#  '玫瑰红': 146,
#  '日晚': 147,
#  '原始社会': 148,
#  '沟缝': 149,
#  '已拨': 150,
#  '唐山人': 151,
#  '大果': 152,
#  '专辑': 153,
#  '耍手段': 154,
#  '彊': 155,
#  '爱玲': 156,
#  '出货': 157,
#  '较弱': 158,
#  '姑苏': 159,
#  '还响': 160,
#  '小朋友': 161,
#  '拘束': 162,
#  '有情': 163,
#  '不服气': 164,
#  '8821': 165,
#  '1.9': 166,
#  '没雪碧好': 167,
#  '书背': 168,
#  '久悦': 169,
#  '赠送': 170,
#  '原地': 171,
#  '肯以': 172,
#  '茴': 173,
#  '喜不喜欢': 174,
#  '国际性': 175,
#  '天换': 176,
#  '难受': 177,
#  '泥沼': 178,
#  '会场': 179,
#  '长篇': 180,
#  '识货': 181,
#  '显现出': 182,
#  '之爱': 183,
#  '这要': 184,
#  '原来如此': 185,
#  '地流': 186,
#  '篇篇': 187,
#  '提太高': 188,
#  '修过': 189,
#  '1': 190,
#  '1280': 191,
#  '电脑公司': 192,
#  '回国': 193,
#  '始发': 194,
#  '另行': 195,
#  '报效': 196,
#  '柯南': 197,
#  '得知': 198,
#  '待机图片': 199,
#  '庭': 200,
#  '玷污': 201,
#  '咖啡': 202,
#  '级差': 203,
#  '踢皮球': 204,
#  '改善生活': 205,
#  '李先生': 206,
#  '德国人': 207,
#  '世纪之交': 208,
#  'charges': 209,
#  '有技': 210,
#  '结网': 211,
#  '端倪': 212,
#  '车接': 213,
#  '品性': 214,
#  '二十元': 215,
#  'MMC7': 216,
#  '屏太亮': 217,
#  '铸就': 218,
#  '成长': 219,
#  '脏字': 220,
#  '掞': 221,
#  '地漏': 222,
#  '自传体': 223,
#  '深究': 224,
#  '用字': 225,
#  '多贴': 226,
#  '打印机': 227,
#  '绚丽': 228,
#  '寸': 229,
#  '长河': 230,
#  '不难想象': 231,
#  '此点': 232,
#  '宝华': 233,
#  '咳嗽声': 234,
#  '父父': 235,
#  '媒体文件': 236,
#  '我想': 237,
#  '就诺记': 238,
#  '仙人掌': 239,
#  '问过': 240,
#  '上半年': 241,
#  '一念': 242,
#  '嵇康': 243,
#  '致命': 244,
#  'advanced': 245,
#  '庸俗': 246,
#  '蛋': 247,
#  '福地': 248,
#  '多星期': 249,
#  'SL500': 250,
#  '一口气': 251,
#  '重吧': 252,
#  '层面': 253,
#  '需求': 254,
#  '总忘': 255,
#  '逆天': 256,
#  '因书中': 257,
#  '扣出': 258,
#  '丑恶': 259,
#  '获奖': 260,
#  '飞翔': 261,
#  '至上': 262,
#  '发音': 263,
#  '体贴人': 264,
#  '不容': 265,
#  '成册': 266,
#  '呼啸而过': 267,
#  '寒腿': 268,
#  '开使': 269,
#  '少不了': 270,
#  '富贵': 271,
#  '附着': 272,
#  '内涵': 273,
#  '安康': 274,
#  '自封': 275,
#  '所好': 276,
#  '全豹': 277,
#  '383161223': 278,
#  '塔迷们': 279,
#  'zODXlH1': 280,
#  '宁波': 281,
#  '此错': 282,
#  '餐桌': 283,
#  'attached': 284,
#  '連勇氣': 285,
#  '所付': 286,
#  '乡愁': 287,
#  '心安': 288,
#  '前些': 289,
#  '自营': 290,
#  '题材': 291,
#  '哗啦啦': 292,
#  '单程': 293,
#  '蔬果': 294,
#  '该楼': 295,
#  '七岁': 296,
#  '然而': 297,
#  '墨玉': 298,
#  '挖土机': 299,
#  '哪能': 300,
#  '公章': 301,
#  '艳丽': 302,
#  '讹人': 303,
#  '奇瑞': 304,
#  '搭载': 305,
#  '货币': 306,
#  '茞': 307,
#  '拉动': 308,
#  '残红': 309,
#  '相临': 310,
#  '里算': 311,
#  '华大': 312,
#  '推向': 313,
#  '中途': 314,
#  '市图书馆': 315,
#  '用卡': 316,
#  '被认': 317,
#  '天虹': 318,
#  '创新': 319,
#  '犯罪': 320,
#  'び': 321,
#  '不外乎': 322,
#  '差一点儿': 323,
#  '上少点': 324,
#  '拼读': 325,
#  '急键': 326,
#  '小得': 327,
#  '奇香': 328,
#  '故事情节': 329,
#  '普天': 330,
#  '漏页': 331,
#  '万万': 332,
#  '能比': 333,
#  '胆子': 334,
#  'FEEL': 335,
#  '设成': 336,
#  '眩迷': 337,
#  '冲击': 338,
#  '土鳖': 339,
#  '诈': 340,
#  '下轻': 341,
#  '直来': 342,
#  '电源开关': 343,
#  '玄学': 344,
#  '空气清新': 345,
#  '青山绿水': 346,
#  '数码港': 347,
#  '屋顶': 348,
#  '大罐': 349,
#  'THINKPad': 350,
#  '地理环境': 351,
#  '回有': 352,
#  '长风': 353,
#  '颗粒感': 354,
#  '真是假': 355,
#  '划等号': 356,
#  '每当': 357,
#  '丛书': 358,
#  'R380': 359,
#  '558': 360,
#  '花洒管': 361,
#  '恩恩怨怨': 362,
#  '启发': 363,
#  '互动': 364,
#  '奢望': 365,
#  '世界史': 366,
#  '积雪': 367,
#  '坑命': 368,
#  '外人': 369,
#  '琥珀': 370,
#  '6000': 371,
#  '联系方式': 372,
#  '无聊': 373,
#  '周游': 374,
#  'freedom': 375,
#  '优惠价格': 376,
#  '绑架': 377,
#  '抽奖': 378,
#  '163': 379,
#  '话说回来': 380,
#  '鼓掌': 381,
#  '防范': 382,
#  '64MB': 383,
#  '绘本': 384,
#  '这比': 385,
#  '死': 386,
#  '环境保护': 387,
#  '880': 388,
#  'working': 389,
#  '我常': 390,
#  '真对不起': 391,
#  '圖': 392,
#  '机和': 393,
#  '下文': 394,
#  '女主角': 395,
#  '720': 396,
#  '哈腰': 397,
#  '托儿所': 398,
#  '显出': 399,
#  '大不一样': 400,
#  '七斗': 401,
#  '价卖': 402,
#  '木': 403,
#  '实用软件': 404,
#  '七窍玲珑': 405,
#  '戰爭': 406,
#  '能强': 407,
#  '战败': 408,
#  '我頭': 409,
#  '肉片': 410,
#  '小是': 411,
#  'COMPAQ': 412,
#  '马戏': 413,
#  '一关': 414,
#  '锈到': 415,
#  'ｅ': 416,
#  '勒斯': 417,
#  '崇众': 418,
#  '桌餐': 419,
#  '步行': 420,
#  '分区': 421,
#  '环境优美': 422,
#  '产品质量': 423,
#  '除上': 424,
#  '博': 425,
#  '装在': 426,
#  '补送': 427,
#  '垫纸': 428,
#  '这时候': 429,
#  '雪山飞狐': 430,
#  '失掉': 431,
#  '一栏': 432,
#  '做份': 433,
#  '那颗': 434,
#  '指摘': 435,
#  '水电工': 436,
#  '字句': 437,
#  '省去': 438,
#  '誠意': 439,
#  '恒': 440,
#  '还脏': 441,
#  '绝迹': 442,
#  '接鼠': 443,
#  '某某人': 444,
#  '慧眼识': 445,
#  '哥儿': 446,
#  '缝合': 447,
#  '难过': 448,
#  '发动机': 449,
#  '上官': 450,
#  '理财': 451,
#  '開放式': 452,
#  '保持一致': 453,
#  '多号': 454,
#  '撥電話': 455,
#  '几眼': 456,
#  '点前': 457,
#  'Native': 458,
#  '苦': 459,
#  '指示灯': 460,
#  '可供': 461,
#  '蛾子': 462,
#  '远去': 463,
#  '地址': 464,
#  '音画': 465,
#  '回退': 466,
#  '拉力': 467,
#  '买到': 468,
#  '叹为观止': 469,
#  '中部': 470,
#  '再住': 471,
#  '异味': 472,
#  '音讯': 473,
#  '买回': 474,
#  '渐变': 475,
#  '万个': 476,
#  '后重': 477,
#  '完换': 478,
#  '千呼万唤': 479,
#  '近邻': 480,
#  '一千六': 481,
#  '开关': 482,
#  '不唯': 483,
#  '基础设施': 484,
#  '同去': 485,
#  '品着': 486,
#  '快键': 487,
#  '提出批评': 488,
#  '玩游戏': 489,
#  '翻翻': 490,
#  '汪': 491,
#  '尽可能': 492,
#  '疑神疑鬼': 493,
#  '老总': 494,
#  '色': 495,
#  '不对劲': 496,
#  '次晨泳': 497,
#  '靶纸': 498,
#  'atittude': 499,
#  '太爽了': 500,
#  '香皂': 501,
#  '邮件': 502,
#  '东街口': 503,
#  '大气候': 504,
#  '别墅式': 505,
#  '矫揉造作': 506,
#  '分节': 507,
#  '螢幕': 508,
#  '是非之地': 509,
#  '依法办理': 510,
#  '先后顺序': 511,
#  '当地人': 512,
#  '人类学': 513,
#  '更难': 514,
#  '讲过': 515,
#  '中华民族': 516,
#  '社会现状': 517,
#  '感堵断': 518,
#  '飞向': 519,
#  'zW1yV6c': 520,
#  '太晕': 521,
#  '下达': 522,
#  '实体店': 523,
#  '货时': 524,
#  '末日': 525,
#  '受苦受累': 526,
#  '努力学习': 527,
#  '东拉西扯': 528,
#  '参展': 529,
#  '楼顶': 530,
#  '懂不懂': 531,
#  '帽头': 532,
#  '一个天': 533,
#  '盛世': 534,
#  '可能性': 535,
#  '一些则': 536,
#  '要斯掉': 537,
#  '水时': 538,
#  '上千年': 539,
#  '猫咪': 540,
#  '心怡': 541,
#  '惊': 542,
#  '合情合理': 543,
#  '毕恭毕敬': 544,
#  '153': 545,
#  '本高木': 546,
#  '提心吊胆': 547,
#  '手先': 548,
#  '拖拽': 549,
#  '新颖': 550,
#  '预备': 551,
#  '中看': 552,
#  '肌理': 553,
#  '不停': 554,
#  '哼': 555,
#  '９': 556,
#  '老去': 557,
#  '值得一提': 558,
#  '来信': 559,
#  '超前': 560,
#  '很美': 561,
#  '灯罩': 562,
#  '中犯': 563,
#  '蕴藏': 564,
#  '口吃': 565,
#  '依舊': 566,
#  '医疗队': 567,
#  '标间': 568,
#  '安抚': 569,
#  '鲜红': 570,
#  '干充': 571,
#  '成书': 572,
#  '倭国': 573,
#  '简讯': 574,
#  '時間': 575,
#  '现场会议': 576,
#  '病重': 577,
#  '部好': 578,
#  'Thinkad': 579,
#  '风雨': 580,
#  '建于': 581,
#  '形而上': 582,
#  '吻合': 583,
#  '领教': 584,
#  '门内': 585,
#  '但此': 586,
#  '理工': 587,
#  '能学': 588,
#  '倾斜': 589,
#  '吐沫': 590,
#  '衣架': 591,
#  '太假': 592,
#  '难点': 593,
#  'WINDOS7': 594,
#  '整课': 595,
#  '印尼': 596,
#  '150': 597,
#  '第一套': 598,
#  '高歌': 599,
#  '消磁': 600,
#  '三苏祠': 601,
#  '豪门': 602,
#  '别于': 603,
#  '中班': 604,
#  '8280': 605,
#  '就要': 606,
#  '操作过程': 607,
#  '109': 608,
#  '盒饭': 609,
#  '装作': 610,
#  '其四': 611,
#  '花茶': 612,
#  '融为': 613,
#  '权和钱': 614,
#  '方太多': 615,
#  '還特別': 616,
#  '山高皇帝远': 617,
#  '洛心': 618,
#  '14.0': 619,
#  '我变': 620,
#  '领略到': 621,
#  '团体': 622,
#  'AS3': 623,
#  '唯物辩证法': 624,
#  '物不所值': 625,
#  '画风': 626,
#  '高声': 627,
#  '停产': 628,
#  '塑料绳': 629,
#  '铅味': 630,
#  '经久不衰': 631,
#  '午后': 632,
#  '内有': 633,
#  '脂肪肝': 634,
#  '第三国': 635,
#  '热血沸腾': 636,
#  '酒鬼': 637,
#  '旅舍': 638,
#  '开背': 639,
#  '现代人': 640,
#  '服务网': 641,
#  '小车': 642,
#  '天有': 643,
#  '免单': 644,
#  '吧唧': 645,
#  '倒底': 646,
#  '一滴水': 647,
#  '空调器': 648,
#  'XY': 649,
#  'lonely': 650,
#  '江米': 651,
#  '618B': 652,
#  '仓储': 653,
#  '册里': 654,
#  '咆哮': 655,
#  '第七章': 656,
#  '刮花': 657,
#  '衰退': 658,
#  '药补': 659,
#  '路窄': 660,
#  '不响': 661,
#  '梦个': 662,
#  '文句': 663,
#  '英皇': 664,
#  '蜀黍': 665,
#  '心境': 666,
#  '味重': 667,
#  '买带': 668,
#  '人脸识别': 669,
#  '归来': 670,
#  '货色': 671,
#  '太吵': 672,
#  '指挥': 673,
#  '不信邪': 674,
#  '东': 675,
#  '桃红色': 676,
#  '听觉': 677,
#  '近点': 678,
#  '遵华': 679,
#  '总能': 680,
#  '称科健': 681,
#  '火花': 682,
#  '污物': 683,
#  '本钱': 684,
#  '刚定': 685,
#  '仆人': 686,
#  '怎對': 687,
#  '一年': 688,
#  '一滩': 689,
#  '大红门': 690,
#  '强有力': 691,
#  '咸菜': 692,
#  '清除': 693,
#  '夜床': 694,
#  '印人': 695,
#  '地笑': 696,
#  '乳房': 697,
#  '情人': 698,
#  '顾正荣': 699,
#  '得益于': 700,
#  '論述': 701,
#  '餐': 702,
#  'V3': 703,
#  '凸': 704,
#  '临晨': 705,
#  '动静': 706,
#  '美味': 707,
#  '我放': 708,
#  '白白的': 709,
#  '图片下载': 710,
#  '伦理': 711,
#  '怪僻': 712,
#  '准时到达': 713,
#  '卷券': 714,
#  '指引': 715,
#  '相素': 716,
#  '流通性': 717,
#  '好贵': 718,
#  '路上': 719,
#  'DDR800': 720,
#  '成败论': 721,
#  '父': 722,
#  '老套': 723,
#  '公司股票': 724,
#  '新闻联播': 725,
#  '新著': 726,
#  'HD3400': 727,
#  '单充': 728,
#  '手时': 729,
#  '奶好': 730,
#  '四日游': 731,
#  '盛名之下': 732,
#  '有感': 733,
#  '低点': 734,
#  'Series': 735,
#  '实习生': 736,
#  '过不去': 737,
#  '趁机': 738,
#  '长途费': 739,
#  '心计': 740,
#  'jpg': 741,
#  '李跃儿': 742,
#  '月初': 743,
#  '尿': 744,
#  '前店': 745,
#  '巨星': 746,
#  '评析': 747,
#  '备受': 748,
#  '没换': 749,
#  '晚宴': 750,
#  '但付': 751,
#  '纯一': 752,
#  '拨过': 753,
#  '哪得成': 754,
#  '古代汉语': 755,
#  '粒邀': 756,
#  '幻化': 757,
#  '久违': 758,
#  '效率': 759,
#  '换汇': 760,
#  '电烧': 761,
#  '加钱换': 762,
#  '提出异议': 763,
#  '会伤': 764,
#  '短语': 765,
#  '常亮': 766,
#  '不弃': 767,
#  '旅游车': 768,
#  '椰子树': 769,
#  '所示': 770,
#  '个厅': 771,
#  '燕丰': 772,
#  '切口': 773,
#  '宜家': 774,
#  '正看': 775,
#  '全家人': 776,
#  '繁冗': 777,
#  '该套': 778,
#  '120MB': 779,
#  '横冲直撞': 780,
#  '165': 781,
#  '尽力': 782,
#  '康年': 783,
#  '剥削': 784,
#  '仲': 785,
#  '2050': 786,
#  '餐牌': 787,
#  '宝贝': 788,
#  '胶垫': 789,
#  '藏书': 790,
#  '登记表': 791,
#  '科学家': 792,
#  '插上': 793,
#  '不复存在': 794,
#  '故生': 795,
#  '7.0': 796,
#  '缓解': 797,
#  '间距': 798,
#  '粗略': 799,
#  '秩序': 800,
#  '明玉格': 801,
#  '传达出来': 802,
#  '不祥': 803,
#  '身临其境': 804,
#  '物价上涨': 805,
#  '何种': 806,
#  '补中': 807,
#  '得益': 808,
#  '打广告': 809,
#  '一清早': 810,
#  'xp3': 811,
#  '悬崖': 812,
#  '强力': 813,
#  '推行': 814,
#  '风景优美': 815,
#  '衬托出': 816,
#  '宽裕': 817,
#  '霸王龙': 818,
#  '重重': 819,
#  'V904SH': 820,
#  '借用': 821,
#  '挺力': 822,
#  '互弄': 823,
#  '未果': 824,
#  '一念之间': 825,
#  '文学界': 826,
#  '想进': 827,
#  '赶得上': 828,
#  '礼貌': 829,
#  '证大丽笙': 830,
#  '阿拉伯文': 831,
#  '岁数': 832,
#  '清清楚楚': 833,
#  '楞楞': 834,
#  '音听': 835,
#  '慧心': 836,
#  '使用方便': 837,
#  '词源': 838,
#  '鼓噪': 839,
#  '超差': 840,
#  '环境恶劣': 841,
#  '目的性': 842,
#  '纲要': 843,
#  '理睬': 844,
#  '机关算尽': 845,
#  '不死': 846,
#  '多事之秋': 847,
#  'S5290': 848,
#  '搏斗': 849,
#  '除夕': 850,
#  '货品': 851,
#  '当今': 852,
#  '嘻嘻哈哈': 853,
#  '垫江县': 854,
#  '勐': 855,
#  '餐廳': 856,
#  '沦丧': 857,
#  'Italian': 858,
#  '无肉': 859,
#  '会儿': 860,
#  '蜕变': 861,
#  '没费': 862,
#  '吵过': 863,
#  '埋下': 864,
#  'key': 865,
#  '系列丛书': 866,
#  '要收': 867,
#  '汲取': 868,
#  '造工': 869,
#  '狗屁不通': 870,
#  '金刚石': 871,
#  '瞎伙': 872,
#  '一唱三叹': 873,
#  '两名': 874,
#  '货一到': 875,
#  '启程': 876,
#  '五年级': 877,
#  '首要': 878,
#  'CQ35': 879,
#  '加菲': 880,
#  'i': 881,
#  '会象': 882,
#  '因必': 883,
#  '如家店': 884,
#  '忽然': 885,
#  '参考消息': 886,
#  '有货': 887,
#  '祝攜程': 888,
#  'ping': 889,
#  '荣誉': 890,
#  '348': 891,
#  '平台': 892,
#  '音响': 893,
#  '地去': 894,
#  '无拖影': 895,
#  '炸过': 896,
#  '电子表': 897,
#  '房價': 898,
#  '購物區': 899,
#  '搞了半天': 900,
#  '只定': 901,
#  '较久': 902,
#  '押韵': 903,
#  '随手': 904,
#  '初因': 905,
#  '医师': 906,
#  '关键': 907,
#  '低电': 908,
#  '謝謝': 909,
#  '比不高': 910,
#  '幫忙': 911,
#  '点多时': 912,
#  '中复': 913,
#  '股份': 914,
#  '两处': 915,
#  '电源适配器': 916,
#  '很凉': 917,
#  '多花钱': 918,
#  '关键字': 919,
#  '内建': 920,
#  '人脑': 921,
#  'iPOD': 922,
#  '杳无音讯': 923,
#  '疑': 924,
#  '触感': 925,
#  '传进': 926,
#  '貼': 927,
#  '支配': 928,
#  '房务部': 929,
#  '299': 930,
#  '时代气息': 931,
#  '橱': 932,
#  '悲愤': 933,
#  '借': 934,
#  '一丝': 935,
#  '警报声': 936,
#  '重要': 937,
#  '种子': 938,
#  '炫红': 939,
#  '落成': 940,
#  '窃笑': 941,
#  '无边': 942,
#  '在外': 943,
#  '悠久': 944,
#  '礼仪': 945,
#  '接站': 946,
#  '非常少': 947,
#  '口干舌燥': 948,
#  '跳楼自杀': 949,
#  '正义': 950,
#  '省墨': 951,
#  '6699': 952,
#  '风速': 953,
#  '刘公岛': 954,
#  '顺': 955,
#  '认住': 956,
#  '阳光': 957,
#  '威胁': 958,
#  '幸存者': 959,
#  '提不上': 960,
#  '工作餐': 961,
#  '旅游区': 962,
#  '曹世如': 963,
#  '焕轻': 964,
#  '该用': 965,
#  '民风': 966,
#  '托架': 967,
#  '只当': 968,
#  '5h': 969,
#  '我无语': 970,
#  '方可': 971,
#  '居民小区': 972,
#  '组合键': 973,
#  '小版': 974,
#  '撕扯': 975,
#  '沉迷': 976,
#  '一死': 977,
#  '张盘': 978,
#  '没星': 979,
#  '有吉之岛': 980,
#  '四岁': 981,
#  '音视': 982,
#  '盖茨': 983,
#  '桔子': 984,
#  '国有企业': 985,
#  '更悲': 986,
#  '人设': 987,
#  '不爱': 988,
#  '数据服务': 989,
#  '冷光': 990,
#  '我草': 991,
#  '懒': 992,
#  '混浊': 993,
#  '牌牌': 994,
#  '不惜': 995,
#  '大奖': 996,
#  '经理': 997,
#  '东林党': 998,
#  '急于求成': 999,
#  ...}

# %%
def update_input_layer(reviews):
    
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    for word in reviews:
        layer_0[0][word2index[word]] += 1

update_input_layer(pn['words'][5])
layer_0
# Out:
# array([[ 0.,  0.,  0., ...,  0.,  0.,  0.]])

# %% [markdown]
# 下一步我们就是要构建神经网络了，简单神经网络的构建可以参见[如何构建一个简单的神经网络](http://www.jianshu.com/p/15db29e72719)

# %%
import time
import sys
import numpy as np

# Let's tweak our network from before to model these phenomena
class SentimentNetwork:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
       
        # set our random number generator 
#         np.random.seed(1)
    
        self.pre_process_data(reviews, labels)
        
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)
        
        
    def pre_process_data(self, reviews, labels):
        
        review_vocab = set()
        for review in reviews:
            for word in review:
                review_vocab.add(word)
        self.review_vocab = list(review_vocab)
        
#         label_vocab = set()
#         for label in labels:
#             label_vocab.add(label)
        
#         self.label_vocab = list(label_vocab)
        
        self.review_vocab_size = len(self.review_vocab)
#         self.label_vocab_size = len(self.label_vocab)
        
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
#         self.label2index = {}
#         for i, label in enumerate(self.label_vocab):
#             self.label2index[label] = i
         
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Initialize weights
        self.weights_0_1 = np.zeros((self.hidden_nodes,self.input_nodes))
    
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.output_nodes, self.hidden_nodes))
        
        self.learning_rate = learning_rate
        
        self.layer_0 = np.zeros((input_nodes,1))
    
        
    def update_input_layer(self,review):

        # clear out previous state, reset the layer to be all 0s
        self.layer_0 *= 0
        for word in review:
            if(word in self.word2index.keys()):
                self.layer_0[self.word2index[word]][0] += 1
                
#     def get_target_for_label(self,label):
#         if(label == 'POSITIVE'):
#             return 1
#         else:
#             return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def train(self, training_reviews, training_labels):
        
        assert(len(training_reviews) == len(training_labels))
        
        correct_so_far = 0
        
        start = time.time()
        
        for i in range(len(training_reviews)):
            
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            # Input Layer
            self.update_input_layer(review)
            layer_0 = self.layer_0
            # Hidden layer
            layer_1 = self.weights_0_1.dot(self.layer_0)

            # Output layer
            layer_2 = self.sigmoid(self.weights_1_2.dot(layer_1))

            #### Implement the backward pass here ####
            ### Backward pass ###

            # TODO: Output error
            layer_2_error = layer_2 - label # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # TODO: Backpropagated error
            layer_1_error = self.weights_1_2.T.dot(layer_2_delta) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # TODO: Update the weights
            self.weights_1_2 -= layer_2_delta.dot(layer_1.T) * self.learning_rate # update hidden-to-output weights with gradient descent step
            self.weights_0_1 -= layer_1_delta.dot(layer_0.T) * self.learning_rate # update input-to-hidden weights with gradient descent step

            if(np.abs(layer_2_error) < 0.5):
                correct_so_far += 1
            
            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + __builtins__.str(100 * i/float(len(training_reviews)))[:4] + "% Speed(reviews/sec):" + __builtins__.str(reviews_per_second)[0:5] + " #Correct:" + __builtins__.str(correct_so_far) + " #Trained:" + __builtins__.str(i+1) + " Training Accuracy:" + __builtins__.str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        
        correct = 0
        
        start = time.time()
        
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + __builtins__.str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + __builtins__.str(reviews_per_second)[0:5] \
                            + "% #Correct:" + __builtins__.str(correct) + " #Tested:" + __builtins__.str(i+1) + " Testing Accuracy:" + __builtins__.str(correct * 100 / float(i+1))[:4] + "%")
            
    def run(self, review):
        
        # Input Layer
#         print(review)
        self.update_input_layer(review)
#         print(self.layer_0.shape)
#         print(self.weights_0_1.shape)
#         print(np.dot(self.weights_0_1,self.layer_0))
        # Hidden layer
        layer_1 = self.weights_0_1.dot(self.layer_0)

        # Output layer
        layer_2 = self.sigmoid(self.weights_1_2.dot(layer_1))
#         print(layer_2) # 发现一只0.5呢
        if(layer_2[0] > 0.5):
            return 1
        else:
            return 0

# %%
reviews = pn['words'].values
labels = pn['mark'].values

# %%
# 除最后1000个外的数据训练
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)

# %%
# train the network
# print(len(reviews),len(labels))
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:0 #Trained:1 Training Accuracy:0.0%
# Progress:12.4% Speed(reviews/sec):177.3 #Correct:1499 #Trained:2501 Training Accuracy:59.9%
# Progress:24.8% Speed(reviews/sec):169.9 #Correct:3315 #Trained:5001 Training Accuracy:66.2%
# Progress:29.6% Speed(reviews/sec):165.2 #Correct:4052 #Trained:5960 Training Accuracy:67.9%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-224-2db8cecc49e0> in <module>()
#       1 # train the network
#       2 # print(len(reviews),len(labels))
# ----> 3 mlp.train(reviews[:-1000],labels[:-1000])
#
# <ipython-input-211-d67a17005419> in train(self, training_reviews, training_labels)
#     117             # TODO: Update the weights
#     118             self.weights_1_2 -= layer_2_delta.dot(layer_1.T) * self.learning_rate # update hidden-to-output weights with gradient descent step
# --> 119             self.weights_0_1 -= layer_1_delta.dot(layer_0.T) * self.learning_rate # update input-to-hidden weights with gradient descent step
#     120
#     121             if(np.abs(layer_2_error) < 0.5):
#
# KeyboardInterrupt:

# %% [markdown]
# 上面的一个问题是执行太慢了，而且准确率不是很高，为什么呢？
# 我们来分析下，到底是什么导致的？

# %%
review_counter = Counter()
for word in reviews[0]:
    review_counter[word] += 1
review_counter.most_common()
# Out:
# [('，', 9),
#  ('。', 5),
#  ('功能', 2),
#  ('手机', 2),
#  ('内存', 2),
#  ('的', 2),
#  ('用', 2),
#  ('可', 2),
#  ('都', 2),
#  ('了', 2),
#  ('不够', 2),
#  ('电话薄', 2),
#  ('录音', 1),
#  ('时间', 1),
#  ('短', 1),
#  ('无', 1),
#  ('JAVA', 1),
#  ('下载', 1),
#  ('无外', 1),
#  ('接', 1),
#  ('存储', 1),
#  ('里', 1),
#  ('东西', 1),
#  ('我', 1),
#  ('一般', 1),
#  ('数据线', 1),
#  ('传', 1),
#  ('每次', 1),
#  ('这样', 1),
#  ('太', 1),
#  ('麻烦', 1),
#  ('而且', 1),
#  ('机身', 1),
#  ('本身', 1),
#  ('就', 1),
#  ('大', 1),
#  ('和', 1),
#  ('短信', 1),
#  ('容量', 1),
#  ('不是', 1),
#  ('很大', 1),
#  ('二千', 1),
#  ('多元', 1),
#  ('买', 1),
#  ('就是', 1),
#  ('不想', 1),
#  ('换', 1),
#  ('现在', 1),
#  ('联系人', 1),
#  ('越来越', 1),
#  ('多', 1),
#  ('担心', 1),
#  ('以后', 1)]

# %% [markdown]
# 我们可以看到最多的竟然是.,'。'等好多无关的所以一个优化方法就是只记录出现的1，不记录次数，于是有下面的代码：

# %%
import time
import sys
import numpy as np

# Let's tweak our network from before to model these phenomena
class SentimentNetwork:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
       
        # set our random number generator 
#         np.random.seed(1)
    
        self.pre_process_data(reviews, labels)
        
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)
        
        
    def pre_process_data(self, reviews, labels):
        
        review_vocab = set()
        for review in reviews:
            for word in review:
                review_vocab.add(word)
        self.review_vocab = list(review_vocab)
        
#         label_vocab = set()
#         for label in labels:
#             label_vocab.add(label)
        
#         self.label_vocab = list(label_vocab)
        
        self.review_vocab_size = len(self.review_vocab)
#         self.label_vocab_size = len(self.label_vocab)
        
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
#         self.label2index = {}
#         for i, label in enumerate(self.label_vocab):
#             self.label2index[label] = i
         
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Initialize weights
        self.weights_0_1 = np.zeros((self.hidden_nodes,self.input_nodes))
    
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.output_nodes, self.hidden_nodes))
        
        self.learning_rate = learning_rate
        
        self.layer_0 = np.zeros((input_nodes,1))
    
        
    def update_input_layer(self,review):

        # clear out previous state, reset the layer to be all 0s
        self.layer_0 *= 0
        for word in review:
            if(word in self.word2index.keys()):
                self.layer_0[self.word2index[word]][0] = 1
                
#     def get_target_for_label(self,label):
#         if(label == 'POSITIVE'):
#             return 1
#         else:
#             return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def train(self, training_reviews, training_labels):
        
        assert(len(training_reviews) == len(training_labels))
        
        correct_so_far = 0
        
        start = time.time()
        
        for i in range(len(training_reviews)):
            
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            # Input Layer
            self.update_input_layer(review)
            layer_0 = self.layer_0
            # Hidden layer
            layer_1 = self.weights_0_1.dot(self.layer_0)

            # Output layer
            layer_2 = self.sigmoid(self.weights_1_2.dot(layer_1))

            #### Implement the backward pass here ####
            ### Backward pass ###

            # TODO: Output error
            layer_2_error = layer_2 - label # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # TODO: Backpropagated error
            layer_1_error = self.weights_1_2.T.dot(layer_2_delta) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # TODO: Update the weights
            self.weights_1_2 -= layer_2_delta.dot(layer_1.T) * self.learning_rate # update hidden-to-output weights with gradient descent step
            self.weights_0_1 -= layer_1_delta.dot(layer_0.T) * self.learning_rate # update input-to-hidden weights with gradient descent step

            if(np.abs(layer_2_error) < 0.5):
                correct_so_far += 1
            
            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + __builtins__.str(100 * i/float(len(training_reviews)))[:4] + "% Speed(reviews/sec):" + __builtins__.str(reviews_per_second)[0:5] + " #Correct:" + __builtins__.str(correct_so_far) + " #Trained:" + __builtins__.str(i+1) + " Training Accuracy:" + __builtins__.str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        
        correct = 0
        
        start = time.time()
        
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + __builtins__.str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + __builtins__.str(reviews_per_second)[0:5] \
                            + "% #Correct:" + __builtins__.str(correct) + " #Tested:" + __builtins__.str(i+1) + " Testing Accuracy:" + __builtins__.str(correct * 100 / float(i+1))[:4] + "%")
            
    def run(self, review):
        
        # Input Layer
#         print(review)
        self.update_input_layer(review)
#         print(self.layer_0.shape)
#         print(self.weights_0_1.shape)
#         print(np.dot(self.weights_0_1,self.layer_0))
        # Hidden layer
        layer_1 = self.weights_0_1.dot(self.layer_0)

        # Output layer
        layer_2 = self.sigmoid(self.weights_1_2.dot(layer_1))
#         print(layer_2) # 发现一只0.5呢
        if(layer_2[0] > 0.5):
            return 1
        else:
            return 0

# %%
# 除最后1000个外的数据训练
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:0 #Trained:1 Training Accuracy:0.0%
# Progress:12.4% Speed(reviews/sec):169.4 #Correct:1924 #Trained:2501 Training Accuracy:76.9%
# Progress:24.8% Speed(reviews/sec):169.3 #Correct:4013 #Trained:5001 Training Accuracy:80.2%
# Progress:37.3% Speed(reviews/sec):162.4 #Correct:6148 #Trained:7501 Training Accuracy:81.9%
# Progress:49.7% Speed(reviews/sec):161.6 #Correct:8316 #Trained:10001 Training Accuracy:83.1%
# Progress:62.1% Speed(reviews/sec):162.1 #Correct:10504 #Trained:12501 Training Accuracy:84.0%
# Progress:74.6% Speed(reviews/sec):162.8 #Correct:12684 #Trained:15001 Training Accuracy:84.5%
# Progress:87.0% Speed(reviews/sec):165.6 #Correct:14905 #Trained:17501 Training Accuracy:85.1%
# Progress:99.4% Speed(reviews/sec):167.5 #Correct:17122 #Trained:20001 Training Accuracy:85.6%
# Progress:99.9% Speed(reviews/sec):167.6 #Correct:17210 #Trained:20105 Training Accuracy:85.6%

# %%
mlp.test(reviews[-1000:],labels[-1000:])
# Out:
# Progress:99.9% Speed(reviews/sec):1023.% #Correct:881 #Tested:1000 Testing Accuracy:88.1%

# %% [markdown]
# ## 加快运算速度
# 下一步我们要来看下为什么计算的这么慢原因，我们来看下下面的一个例子：

# %%
layer_0 = np.zeros(10)
layer_0[4] = 1
layer_0[9] = 1
weights_0_1 = np.random.randn(10,5)
value1 = layer_0.dot(weights_0_1)
value1
# Out:
# array([-0.20849069, -0.69363945, -0.59383309,  0.6525091 , -0.02585029])

# %%
indices = [4,9]
layer_1 = np.zeros(5)
for index in indices:
    layer_1 += (weights_0_1[index])

layer_1 == value1
# Out:
# array([ True,  True,  True,  True,  True], dtype=bool)

# %% [markdown]
# 因此我们可以通过上面的方式，只需要计算不为1的index就可以了，可以大大减少计算量，于是就有了下面的优化：

# %%
# Let's tweak our network from before to model these phenomena
class SentimentNetwork:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
       
        # set our random number generator 
        np.random.seed(1)
    
        self.pre_process_data(reviews, labels)
        
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)
        
        
    def pre_process_data(self, reviews, labels):
        
        review_vocab = set()
        for review in reviews:
            for word in review:
                review_vocab.add(word)
        self.review_vocab = list(review_vocab)
        
#         label_vocab = set()
#         for label in labels:
#             label_vocab.add(label)
        
#         self.label_vocab = list(label_vocab)
        
        self.review_vocab_size = len(self.review_vocab)
#         self.label_vocab_size = len(self.label_vocab)
        
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
#         self.label2index = {}
#         for i, label in enumerate(self.label_vocab):
#             self.label2index[label] = i
         
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Initialize weights
        self.weights_0_1 = np.zeros((self.hidden_nodes,self.input_nodes))
    
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.output_nodes, self.hidden_nodes))
        
        self.learning_rate = learning_rate
        
        self.layer_0 = np.zeros((input_nodes,1))
        self.layer_1 = np.zeros((hidden_nodes,1))
    
        
    def update_input_layer(self,review):

        # clear out previous state, reset the layer to be all 0s
        self.layer_0 *= 0
        for word in review:
            if(word in self.word2index.keys()):
                self.layer_0[self.word2index[word]][0] = 1
                
#     def get_target_for_label(self,label):
#         if(label == 'POSITIVE'):
#             return 1
#         else:
#             return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def train(self, training_reviews_raw, training_labels):
        
        training_reviews = list()
        for review in training_reviews_raw:
            indices = set()
            for word in review:
                if(word in self.word2index.keys()):
                    indices.add(self.word2index[word])
            training_reviews.append(list(indices))
        
        assert(len(training_reviews) == len(training_labels))
        
        correct_so_far = 0
        
        start = time.time()
        
        for i in range(len(training_reviews)):
            
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            # Input Layer
#             self.update_input_layer(review)
#             layer_0 = self.layer_0
            # Hidden layer
#             layer_1 = self.weights_0_1.dot(self.layer_0)
            self.layer_1 *= 0
            for index in review:
                self.layer_1 += self.weights_0_1[:,[index]]

            # Output layer
            layer_2 = self.sigmoid(self.weights_1_2.dot(self.layer_1))

            #### Implement the backward pass here ####
            ### Backward pass ###

            # TODO: Output error
            layer_2_error = layer_2 - label # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # TODO: Backpropagated error
            layer_1_error = self.weights_1_2.T.dot(layer_2_delta) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # TODO: Update the weights
            self.weights_1_2 -= layer_2_delta.dot(self.layer_1.T) * self.learning_rate # update hidden-to-output weights with gradient descent step
#             self.weights_0_1 -= layer_1_delta.dot(self.layer_0.T) * self.learning_rate # update input-to-hidden weights with gradient descent step
            for index in review:
                self.weights_0_1[:,[index]] -= layer_1_delta * self.learning_rate

            if(np.abs(layer_2_error) < 0.5):
                correct_so_far += 1
            
            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + __builtins__.str(100 * i/float(len(training_reviews)))[:4] + "% Speed(reviews/sec):" + __builtins__.str(reviews_per_second)[0:5] + " #Correct:" + __builtins__.str(correct_so_far) + " #Trained:" + __builtins__.str(i+1) + " Training Accuracy:" + __builtins__.str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        
        correct = 0
        
        start = time.time()
        
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + __builtins__.str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + __builtins__.str(reviews_per_second)[0:5] \
                            + "% #Correct:" + __builtins__.str(correct) + " #Tested:" + __builtins__.str(i+1) + " Testing Accuracy:" + __builtins__.str(correct * 100 / float(i+1))[:4] + "%")
            
    def run(self, review):
        
        # Input Layer
#         print(review)
        self.update_input_layer(review)
#         print(self.layer_0.shape)
#         print(self.weights_0_1.shape)
#         print(np.dot(self.weights_0_1,self.layer_0))
        # Hidden layer
        layer_1 = self.weights_0_1.dot(self.layer_0)

        # Output layer
        layer_2 = self.sigmoid(self.weights_1_2.dot(layer_1))
#         print(layer_2) # 发现一只0.5呢
        if(layer_2[0] > 0.5):
            return 1
        else:
            return 0

# %%
# 除最后1000个外的数据训练
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:0 #Trained:1 Training Accuracy:0.0%
# Progress:12.4% Speed(reviews/sec):785.5 #Correct:1881 #Trained:2501 Training Accuracy:75.2%
# Progress:24.8% Speed(reviews/sec):756.7 #Correct:3959 #Trained:5001 Training Accuracy:79.1%
# Progress:37.3% Speed(reviews/sec):700.4 #Correct:6077 #Trained:7501 Training Accuracy:81.0%
# Progress:49.7% Speed(reviews/sec):694.7 #Correct:8238 #Trained:10001 Training Accuracy:82.3%
# Progress:62.1% Speed(reviews/sec):700.1 #Correct:10431 #Trained:12501 Training Accuracy:83.4%
# Progress:74.6% Speed(reviews/sec):701.2 #Correct:12607 #Trained:15001 Training Accuracy:84.0%
# Progress:87.0% Speed(reviews/sec):706.2 #Correct:14827 #Trained:17501 Training Accuracy:84.7%
# Progress:99.4% Speed(reviews/sec):708.3 #Correct:17034 #Trained:20001 Training Accuracy:85.1%
# Progress:99.9% Speed(reviews/sec):708.4 #Correct:17122 #Trained:20105 Training Accuracy:85.1%

# %%
a = np.random.normal(0,1,(2,3))
b = np.random.normal(0,1,(2,1))

# %%
a
# Out:
# array([[ 0.58281521, -1.10061918,  1.14472371],
#        [ 0.90159072,  0.50249434,  0.90085595]])

# %%
b
# Out:
# array([[-0.68372786],
#        [-0.12289023]])

# %%
a[:,[1]] = b

# %%
a
# Out:
# array([[ 0.58281521, -0.68372786,  1.14472371],
#        [ 0.90159072, -0.12289023,  0.90085595]])

# %% [markdown]
# ## 有策略的减少无效单词来减少噪声
# 优化到这，让我们来看下还有没有什么可优化的了，我们来将分词后正负对比的一个直方图

# %%
import pandas as pd
neg=pd.read_excel('data/neg.xls',header=None,index=None)
pos=pd.read_excel('data/pos.xls',header=None,index=None)


pos['mark']=1
neg['mark']=0 #给训练语料贴上标签
pn=pd.concat([pos,neg],ignore_index=True) #合并语料
neglen=len(neg)
poslen=len(pos) #计算语料数目

cw = lambda x: list(jieba.cut(x)) #定义分词函数
pn['words'] = pn[0].apply(cw)
pn = pn.reindex(np.random.permutation(pn.index))

positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

for i in range(len(pn['words'])):
    if pn['mark'][i] == 1:
        for word in pn['words'][i]:
            positive_counts[word] += 1
            total_counts[word] += 1
    else:
        for word in pn['words'][i]:
            negative_counts[word] += 1
            total_counts[word] += 1

pos_neg_ratios = Counter()
for term,cnt in list(total_counts.most_common()):
    if(cnt > 180):
        pos_neg_ratio = positive_counts[term] / float(negative_counts[term]+1)
        pos_neg_ratios[term] = pos_neg_ratio  
        
for word,ratio in pos_neg_ratios.most_common():
    if(ratio > 1):
        pos_neg_ratios[word] = np.log(ratio)
    else:
        pos_neg_ratios[word] = -np.log((1 / (ratio+0.01))) 


#

# %%
pos_neg_ratios.most_common()
# Out:
# [('结局', 3.7954891891721947),
#  ('成长', 3.0002674287193822),
#  ('快乐', 2.968080742223481),
#  ('世界', 2.5416019934645457),
#  ('幸福', 2.5403579543242145),
#  ('感谢', 2.2894558015522528),
#  ('很漂亮', 2.256541154492639),
#  ('漂亮', 2.0762312660495876),
#  ('人生', 2.044102175234527),
#  ('感动', 2.0074680420547466),
#  ('好书', 1.9965538818740682),
#  ('老师', 1.9459101490553132),
#  ('配置', 1.8971199848858813),
#  ('外观', 1.8902543650998997),
#  ('很快', 1.8747563887990228),
#  ('妈妈', 1.8735894874756871),
#  ('爱情', 1.8420602077028538),
#  ('父母', 1.8382794848629478),
#  ('爱', 1.8271613962789708),
#  ('拥有', 1.823307826962981),
#  ('先生', 1.8144877203056111),
#  ('深刻', 1.8094590463274558),
#  ('时尚', 1.8028093054146399),
#  ('知识', 1.80005827204275),
#  ('不错', 1.7940434443358855),
#  ('历史', 1.7812881693607596),
#  ('每个', 1.7640568666787193),
#  ('读完', 1.7460134474398512),
#  ('完美', 1.7412633052135227),
#  ('丰富', 1.7047480922384253),
#  ('生活', 1.6976390575593188),
#  ('改变', 1.6703986122237875),
#  ('一切', 1.6382860667717587),
#  ('学习', 1.6068028647960952),
#  ('性价比', 1.6061805805637939),
#  ('每', 1.5779116587873265),
#  ('成为', 1.5686159179138452),
#  ('清晰', 1.5320061723012843),
#  ('了解', 1.5185623296976414),
#  ('认识', 1.5130460667590344),
#  ('可爱', 1.5121746070088933),
#  ('电影', 1.4872702784598928),
#  ('许多', 1.4675198010424764),
#  ('更加', 1.4615177823574781),
#  ('还会', 1.4561640410803767),
#  ('性能', 1.455287232606842),
#  ('细节', 1.4500101755059984),
#  ('真实', 1.4397195277934711),
#  ('家长', 1.4397195277934711),
#  ('健康', 1.4058389571928607),
#  ('以及', 1.4043128666225688),
#  ('女儿', 1.3839768629795282),
#  ('社会', 1.3779261114493739),
#  ('真正', 1.3756747922924304),
#  ('哈哈', 1.3730491343698699),
#  ('即使', 1.3678322982801552),
#  ('开心', 1.3480731482996928),
#  ('够', 1.3386663121306361),
#  ('整体', 1.3359404749742758),
#  ('教育', 1.3217558399823195),
#  ('感受', 1.3170499489449068),
#  ('重要', 1.3140761533080914),
#  ('各种', 1.3057554986358784),
#  ('一种', 1.2943568657942051),
#  ('心里', 1.2935849630156231),
#  ('身边', 1.2626804051527141),
#  ('《', 1.2421087019341943),
#  ('经典', 1.2374487335223254),
#  ('书籍', 1.2226649373380887),
#  ('读', 1.215564552489721),
#  ('价位', 1.215533626727012),
#  ('宝宝', 1.2084271546753163),
#  ('做工', 1.2081744911796362),
#  ('》', 1.2022471783584663),
#  ('总体', 1.2012664427281929),
#  ('孩子', 1.1977031913123406),
#  ('使', 1.1927995037278107),
#  ('手感', 1.1676051601550612),
#  ('系列', 1.1499055830556602),
#  ('算是', 1.148622709242771),
#  ('地理位置', 1.142506482225335),
#  ('她', 1.1403498944227874),
#  ('他', 1.1325961414837082),
#  ('书中', 1.1195189734874234),
#  ('期待', 1.1138797607988982),
#  ('值得', 1.110882381259924),
#  ('相当', 1.1104467463151124),
#  ('最好', 1.1017227110825021),
#  ('这是', 1.0937342302146769),
#  ('中国', 1.0898479906745215),
#  ('交通', 1.0858732628906798),
#  ('生命', 1.0718010312174528),
#  ('能够', 1.0698333241180662),
#  ('所', 1.0583045651800167),
#  ('不同', 1.0527025873640319),
#  ('文字', 1.0414538748281612),
#  ('那种', 1.0406896409354052),
#  ('日本', 1.0354333870465782),
#  ('套书', 1.0265314064925817),
#  ('阅读', 1.022116255678003),
#  ('热情', 1.0180734261840974),
#  ('毕竟', 1.0116009116784799),
#  ('故事', 1.0028773902334887),
#  ('速度', 1.0012381246429334),
#  ('对于', 0.99718414142800438),
#  ('谢谢', 0.98815529310379902),
#  ('安静', 0.98738665355788524),
#  ('蛮', 0.98553514404913889),
#  ('小说', 0.97842251298116123),
#  ('中', 0.97526774135058014),
#  ('之间', 0.973860583695633),
#  ('与', 0.9711439472772625),
#  ('作品', 0.97013396389497819),
#  ('感到', 0.96999491084601608),
#  ('带', 0.96742007839675936),
#  ('屏', 0.96684301103698644),
#  ('方面', 0.96476125403990665),
#  ('每天', 0.96175310595091246),
#  ('高', 0.95993949654316846),
#  ('方式', 0.95825493097318726),
#  ('经历', 0.95796342827472303),
#  ('设计', 0.95638518907603309),
#  ('那些', 0.95551144502743635),
#  ('认为', 0.95482439587639789),
#  ('同时', 0.94876732055206336),
#  ('地', 0.94680627580010557),
#  ('其实', 0.94595392369771392),
#  ('玩', 0.9433716904768259),
#  ('那样', 0.94017894704885041),
#  ('—', 0.9377456668754145),
#  ('十分', 0.925340567394073),
#  ('喜欢', 0.91980156052421813),
#  ('作为', 0.91895384929363888),
#  ('呵呵', 0.91759706778821049),
#  ('满意', 0.9110136747733113),
#  ('目前', 0.90210609688219856),
#  ('虽然', 0.89430003610858311),
#  ('人物', 0.89097292388986515),
#  ('音乐', 0.88952049080955031),
#  ('这本', 0.88154778343028206),
#  ('品牌', 0.87828961369554115),
#  ('过程', 0.87546873735389985),
#  ('可惜', 0.31015492830383945),
#  ('时候', 0.30758753279859374),
#  ('第一次', 0.30593551276113129),
#  ('看看', 0.30514976549217188),
#  ('或者', 0.30351353766846167),
#  ('是因为', 0.30228087187293362),
#  ('使用', 0.29849298855599654),
#  ('是', 0.29841228970389388),
#  ('图片', 0.29592614222686303),
#  ('屏幕', 0.29556233387708675),
#  ('还', 0.29416879745753727),
#  ('感觉', 0.28920530199230249),
#  ('如果', 0.28454235244711323),
#  ('上网', 0.28318768286394169),
#  ('同事', 0.28211102740232558),
#  ('接受', 0.28090238546640217),
#  ('有些', 0.27996002635787059),
#  ('这个', 0.27575253353182755),
#  ('好多', 0.27369583047704105),
#  ('那个', 0.26872888664954264),
#  ('机器', 0.26088387929705681),
#  ('里面', 0.25815296098086271),
#  ('本身', 0.25782910930209985),
#  ('左右', 0.25685460865652149),
#  ('名字', 0.25671984684781407),
#  ('马上', 0.25270235355575427),
#  ('铃声', 0.25131442828090617),
#  ('家', 0.25014415313271571),
#  ('后面', 0.24906723632400138),
#  ('100', 0.24652399995827343),
#  ('~', 0.24430177682155577),
#  ('联想', 0.24294617861038939),
#  ('近', 0.24038535774871589),
#  ('不管', 0.23875144898020073),
#  ('决定', 0.23638877806423036),
#  ('想象', 0.23334772148845143),
#  ('没想到', 0.23219338683412777),
#  ('看起来', 0.22884157242884745),
#  ('得', 0.22835868699331788),
#  ('之后', 0.22778393087071197),
#  ('书', 0.22599132145520781),
#  ('看来', 0.22314355131420976),
#  ('手机', 0.2223828057469007),
#  ('等', 0.2218901565397165),
#  ('小孩', 0.22137207166582767),
#  ('显卡', 0.22107956709335827),
#  ('价格', 0.21896817990372916),
#  ('的话', 0.21223151786322714),
#  ('总', 0.2087548138621102),
#  ('肯定', 0.20708611441835112),
#  ('小', 0.20656119755789906),
#  (';', 0.20334092401803011),
#  ('我', 0.19997489805027774),
#  ('去', 0.18849027690528006),
#  ('出', 0.18692228787989132),
#  ('送', 0.18178550746458141),
#  ('唯一', 0.18099792986344632),
#  ('时间', 0.17467142801571012),
#  ('把', 0.17309275035633315),
#  ('跑', 0.17127172060736964),
#  ('东西', 0.17047972318300542),
#  ('楼', 0.17015102117369948),
#  ('就是', 0.16989903679539742),
#  ('给', 0.16943565451779649),
#  ('除了', 0.16251892949777494),
#  ('兴趣', 0.16251892949777494),
#  ('；', 0.15537093623248768),
#  ('那么', 0.15141719293159775),
#  ('@', 0.15082288973458369),
#  ('安装', 0.14660347419187544),
#  ('一', 0.14005567126550675),
#  ('字', 0.13503628380394292),
#  ('味道', 0.13427961562987478),
#  ('习惯', 0.13353139262452257),
#  ('经常', 0.12941107365150251),
#  ('这样', 0.12917539625118116),
#  ('写', 0.12800142461506148),
#  ('送货', 0.12715517548524666),
#  ('早餐', 0.12058024027744467),
#  ('还有', 0.11993522710971398),
#  ('拍照', 0.1189519428613653),
#  ('标准', 0.11355469954686231),
#  ('到', 0.11036610461560331),
#  ('服务', 0.1091289165119209),
#  ('已', 0.10763066419236536),
#  ('又', 0.10117265431735158),
#  ('放在', 0.10109611687136881),
#  ('告诉', 0.099372473813203771),
#  ('一句', 0.095310179804324935),
#  ('还好', 0.094665226541078271),
#  ('睡觉', 0.092658830482704763),
#  ('加', 0.088553397341445031),
#  ('不足', 0.085522173438161916),
#  ('餐厅', 0.084741228455090717),
#  ('包装', 0.083965380117334121),
#  ('其他', 0.080648217834331792),
#  ('别人', 0.080445365218739281),
#  ('：', 0.078353314246515163),
#  ('门口', 0.076540077122334391),
#  ('用', 0.076020307294408423),
#  ('呢', 0.0755407304580826),
#  ('至少', 0.067658648473814864),
#  ('下', 0.062983775862361202),
#  ('硬件', 0.06252035698133393),
#  ('一次', 0.059057749643601151),
#  ('一下', 0.055215722602446768),
#  ('/', 0.054067221270275793),
#  ('被', 0.053900651768766364),
#  ('老', 0.050189744523855308),
#  ('出来', 0.048620687006074116),
#  ('．', 0.047306117396937054),
#  ('京东', 0.046043938501406798),
#  ('了', 0.04589923707770055),
#  ('可能', 0.042642119266002532),
#  ('机子', 0.041385216162854281),
#  ('）', 0.039864598563927829),
#  ('吧', 0.038299925087545268),
#  ('小时', 0.035612071788876938),
#  ('电脑', 0.033257221756482339),
#  ('牛奶', 0.031155167779795479),
#  ('跟', 0.031119908713804472),
#  ('分', 0.028170876966696224),
#  ('差不多', 0.025533302005164845),
#  ('缺点', 0.025317807984289786),
#  ('再次', 0.021819047394639673),
#  ('信息', 0.021506205220963682),
#  ('地方', 0.020461071871340025),
#  ('成', 0.020000666706669435),
#  ('才能', 0.018809331957496289),
#  ('（', 0.017413375325197912),
#  ('软件', 0.016620881236040282),
#  ('由于', 0.016529301951210506),
#  ('过', 0.01499687275151575),
#  ('另外', 0.01423511582187191),
#  ('两个', 0.009950330853168092),
#  ('三星', 0.009950330853168092),
#  ('内', 0.009950330853168092),
#  ('然后', 0.0093023926623134103),
#  ('就', -0.00085588438633175652),
#  ('影响', -0.00086994350854003536),
#  ('时', -0.00088309840188429735),
#  ('是否', -0.0064139682101175093),
#  ('下午', -0.0089074785862516773),
#  (':', -0.009273636785329253),
#  ('......', -0.0094621005424220129),
#  ('而且', -0.0097363641083791207),
#  ('照片', -0.0098503358528348635),
#  ('装修', -0.010892441166423754),
#  ('拿', -0.016538652930024406),
#  ('要', -0.019880923496683245),
#  ('大家', -0.020264056383499228),
#  ('5', -0.020902871331898405),
#  ('真', -0.02556634219856305),
#  ('豪华', -0.026380974007654091),
#  ('～', -0.026428654722339816),
#  ('年', -0.027885203489535642),
#  ('考虑', -0.039552475497395628),
#  ('下去', -0.044406656023957797),
#  ('回来', -0.044836451938917062),
#  ('花', -0.045273100481210735),
#  ('本人', -0.046043938501406798),
#  ('一天', -0.046043938501406798),
#  ('不是', -0.046091972701766654),
#  ('以上', -0.053248541588776545),
#  ('英语', -0.0553327971874535),
#  ('首先', -0.058335577012963422),
#  ('-', -0.066658039899349542),
#  ('设施', -0.068431027900296579),
#  ('提出', -0.073970395626561686),
#  ('买', -0.075687487332760775),
#  ('7', -0.075850239619507986),
#  ('真是', -0.076161360965563946),
#  ('好像', -0.077545827474949272),
#  ('象', -0.078734040542504047),
#  ('硬盘', -0.078923702092038445),
#  ('原因', -0.083899341282999987),
#  ('#', -0.084370239765990465),
#  ('饭店', -0.085278100998216283),
#  ('.', -0.092496897636668907),
#  ('30', -0.094924779220336444),
#  ('再', -0.098156399798912289),
#  ('质量', -0.10518255030975211),
#  ('提供', -0.10597488636608392),
#  ('态度', -0.10615448155900278),
#  ('待机时间', -0.10823439848030188),
#  ('产品', -0.11198466137571213),
#  ('后', -0.11576157159773344),
#  ('一点', -0.11627751552836303),
#  ('8', -0.11803934465135539),
#  ('此', -0.1232144256535903),
#  ('服务态度', -0.12599231545135664),
#  ('个', -0.12639762108378069),
#  ('...', -0.1264200125982933),
#  ('水平', -0.12832756474949564),
#  ('发现', -0.13075221981802274),
#  ('旧', -0.13264971047130372),
#  (')', -0.1342847217098467),
#  ('谁', -0.13509104981616946),
#  ('以后', -0.13688676930460039),
#  ('问题', -0.14118953794737626),
#  ('少', -0.14326808170444619),
#  ('4', -0.1463734755084036),
#  ('其它', -0.15192046420543107),
#  ('买回来', -0.15258624762405501),
#  ('2008', -0.15290146042682648),
#  ('一家', -0.15290146042682648),
#  ('显示', -0.15303316102414732),
#  (' ', -0.15789811862187139),
#  ('只', -0.15928669673368775),
#  ('完全', -0.17193815141426649),
#  ('重新', -0.17205510984035774),
#  ('宾馆', -0.17483396384605751),
#  ('设置', -0.17695848038834619),
#  ('这种', -0.17815149266012731),
#  ('有点', -0.17825734671455359),
#  ('大床', -0.17866159596246753),
#  ('情况', -0.1790226563284614),
#  ('几个', -0.18003291559637896),
#  ('后来', -0.18990862556971796),
#  ('心理', -0.19116050546115898),
#  ('3', -0.19282763421866272),
#  ('分钟', -0.19780929609675543),
#  ('买来', -0.19855172993493003),
#  ('且', -0.20126916510768011),
#  ('6', -0.20370927387834797),
#  ('啊', -0.20834460434175273),
#  ('容易', -0.20846522165164075),
#  ('印刷', -0.21418034463308647),
#  ('20', -0.21634850818138093),
#  ('包', -0.21766791580052308),
#  ('(', -0.22274040678143672),
#  ('内容', -0.22355876665546157),
#  (',', -0.22370054204223011),
#  ('大堂', -0.22453340560326401),
#  ('实际', -0.2257985879582623),
#  ('评价', -0.22989707432998951),
#  ('知道', -0.23034534803548526),
#  ('公司', -0.23312913919915612),
#  ('电视', -0.23414130552375115),
#  ('有时', -0.23759308236597784),
#  ('内存', -0.23932530456811602),
#  ('两天', -0.24097398672888121),
#  ('该', -0.24591720010499246),
#  ('上面', -0.24663153262142334),
#  ('才', -0.24829971701252568),
#  ('按键', -0.25006520888047412),
#  ('出现', -0.25031056550756059),
#  ('直接', -0.2542644136445813),
#  ('人员', -0.25489224962879004),
#  ('按', -0.25593519364395051),
#  ('清楚', -0.2580068652605666),
#  ('那里', -0.25889410197583829),
#  ('呀', -0.26040912179043574),
#  ('总之', -0.2651874549616392),
#  ('什么', -0.26602381077268999),
#  ('整个', -0.26617825116595517),
#  ('电池', -0.27225111618250886),
#  ('企业', -0.27443684570176036),
#  ('放', -0.28002782526633418),
#  ('补充', -0.2804356639310136),
#  ('可是', -0.2811726922662639),
#  ('说', -0.28269453094074182),
#  ('您', -0.28476965100474594),
#  ('短信', -0.29249138716833439),
#  ('反馈', -0.29341274716076593),
#  ('"', -0.29547608005285786),
#  ('不会', -0.29773845321290116),
#  ('床', -0.30479740467104893),
#  ('蓝牙', -0.30762516762837866),
#  ('晚上', -0.30846144779750656),
#  ('蒙牛', -0.31126119109258799),
#  ('处理', -0.32105326081617058),
#  ('要是', -0.32747154235784681),
#  ('！', -0.3275929319581603),
#  ('住', -0.32770558147621326),
#  ('XP', -0.33099788655389528),
#  ('所谓', -0.33764533822902237),
#  ('酒店', -0.33776494998779832),
#  ('倒', -0.34096055493880251),
#  ('这么', -0.34218875897766149),
#  ('点', -0.34515130040519237),
#  ('只有', -0.34602445790584957),
#  ('网上', -0.34637431175797279),
#  ('1', -0.34787028157358241),
#  ('这家', -0.34837614112403731),
#  ('四星', -0.34911431197028231),
#  ('卡', -0.34921980944371567),
#  ('声音', -0.35007009741188094),
#  ('以为', -0.35384591746347971),
#  ('任何', -0.36177266101040123),
#  ('建议', -0.36641489503202124),
#  ('本来', -0.37151668253108144),
#  ('键', -0.37266048811735103),
#  ('水', -0.3740157130549131),
#  ('早上', -0.37707873712059314),
#  ('点评', -0.37769635876757091),
#  ('10', -0.38082792942672911),
#  ('房间', -0.38862101475792882),
#  ('装', -0.39057649561441371),
#  ('入住', -0.39556478350578811),
#  ('9', -0.39561581287013653),
#  ('叫', -0.39960639154474981),
#  ('估计', -0.40475107737450733),
#  ('一看', -0.41788567498362883),
#  ('客房', -0.41813119224881784),
#  ('不想', -0.41832522383776916),
#  ('2', -0.41941572192507665),
#  ('系统', -0.42129144082588493),
#  ('15', -0.42252469247821911),
#  ('订', -0.42414362518500398),
#  ('贵', -0.42580571792883287),
#  ('评论', -0.42712177094733661),
#  ('是不是', -0.42938529182581636),
#  ('别的', -0.43179225253948583),
#  ('信号', -0.43315258544777274),
#  ('解决', -0.43954680982357985),
#  ('?', -0.44018944749500877),
#  ('货', -0.44508590128278536),
#  ('说明', -0.45064198558228397),
#  ('房', -0.45237943631931743),
#  ('元', -0.46411446242439175),
#  ('卫生间', -0.46454487120198434),
#  ('正常', -0.48192247863927562),
#  ('要求', -0.49531506680916354),
#  ('xp', -0.49678326664295169),
#  ('定', -0.49710255348657634),
#  ('收到', -0.50370815599712671),
#  ('问', -0.50496751627248848),
#  ('很小', -0.50607502100739288),
#  ('光盘', -0.51094553503179774),
#  ('月', -0.51172472064293784),
#  ('连', -0.52292948593207678),
#  ('外面', -0.52322097022070857),
#  ('必须', -0.53005698569387827),
#  ('!', -0.53049572972302905),
#  ('没有', -0.53979168957881574),
#  ('无法', -0.54300972205430686),
#  ('星', -0.54634784408373982),
#  ('不知', -0.54974046739620797),
#  ('吗', -0.55280569600687346),
#  ('不到', -0.55280569600687346),
#  ('没', -0.55322002832199391),
#  ('找', -0.55797337422200632),
#  ('一般', -0.56641311176063303),
#  ('不', -0.56947442769863366),
#  ('陈旧', -0.57821584519571589),
#  ('打开', -0.58295624492490927),
#  ('打', -0.58477491812299665),
#  ('伊利', -0.60381270368097784),
#  ('日', -0.61095351897729544),
#  ('隔音', -0.61458705284663162),
#  ('没什么', -0.61572493038912213),
#  ('还要', -0.61918269967377826),
#  ('快递', -0.62303213193180695),
#  ('死', -0.62446579310222194),
#  ('天', -0.62625487437208349),
#  ('下载', -0.62735944002194222),
#  ('为什么', -0.6277162006393544),
#  ('开', -0.63038262002016587),
#  ('第二天', -0.6319547686483602),
#  ('不太', -0.63410844945722766),
#  ('不要', -0.63709118727247571),
#  ('当当网', -0.64597557622592405),
#  ('明显', -0.68300273148817281),
#  ('不够', -0.68467740347646122),
#  ('联系', -0.68765504361560115),
#  ('客人', -0.69442459184712646),
#  ('怎么', -0.69563903828238949),
#  ('VISTA', -0.69715520195748415),
#  ('热', -0.6991391224160729),
#  ('服务员', -0.70737764790399182),
#  ('当当', -0.70773583804469797),
#  ('客户', -0.71089777936909482),
#  ('结果', -0.72197993065167954),
#  ('11', -0.73498595198528749),
#  ('搞', -0.73825183687220131),
#  ('请', -0.7489091899139515),
#  ('？', -0.75126873112052739),
#  ('号', -0.77082426746935473),
#  ('驱动', -0.78918489768264721),
#  ('实在', -0.79471995085809033),
#  ('钱', -0.8090202766068586),
#  ('空调', -0.81708346994556869),
#  ('鼠标', -0.81722697769128672),
#  ('太', -0.81731082318086767),
#  ('翻', -0.82423258745620753),
#  ('电话', -0.82641134831314988),
#  ('意思', -0.84329621582159098),
#  ('预定', -0.84800323731215099),
#  ('不能', -0.86330768944468717),
#  ('无', -0.88589793284443918),
#  ('只能', -0.90604923782195801),
#  ('前台', -0.91608967970043897),
#  ('12', -0.91838652256915332),
#  ('客服', -0.92022407717921018),
#  ('反应', -0.92852745832259187),
#  ('小姐', -0.96592915781379873),
#  ('开机', -1.0042429902253385),
#  ('办法', -1.0452187169358944),
#  ('竟然', -1.0635986795012942),
#  ('居然', -1.0837448184938838),
#  ('不行', -1.0868633961790266),
#  ('太小', -1.0893167830818535),
#  ('携程', -1.1004518957718248),
#  ('换', -1.1100568387593051),
#  ('简直', -1.1291599917280972),
#  ('订单', -1.1362992503900142),
#  ('不了', -1.1454498150216568),
#  ('慢', -1.1529645246444826),
#  ('喝', -1.1577389071778386),
#  ('不好', -1.1935466525752536),
#  ('退房', -1.2407520558292324),
#  ('打电话', -1.3293153974726424),
#  ('不如', -1.3500366130972665),
#  ('你们', -1.4505904873950459),
#  ('麻烦', -1.5104490037723128),
#  ('坏', -1.5336737595318182),
#  ('后悔', -1.5336737595318182),
#  ('根本', -1.5365211256505318),
#  ('郁闷', -1.5735428334599848),
#  ('页', -1.6315365868037763),
#  ('差', -1.7188899346366118),
#  ('失望', -1.7210375431333034),
#  ('垃圾', -2.1947851588250678),
#  ('很差', -2.286055791042835),
#  ('死机', -2.5163389039584163),
#  ('抵制', -2.7025520357679857)]

# %%
list(reversed(pos_neg_ratios.most_common()))[0:30]
# Out:
# [('抵制', -2.7025520357679857),
#  ('死机', -2.5163389039584163),
#  ('很差', -2.286055791042835),
#  ('垃圾', -2.1947851588250678),
#  ('失望', -1.7210375431333034),
#  ('差', -1.7188899346366118),
#  ('页', -1.6315365868037763),
#  ('郁闷', -1.5735428334599848),
#  ('根本', -1.5365211256505318),
#  ('后悔', -1.5336737595318182),
#  ('坏', -1.5336737595318182),
#  ('麻烦', -1.5104490037723128),
#  ('你们', -1.4505904873950459),
#  ('不如', -1.3500366130972665),
#  ('打电话', -1.3293153974726424),
#  ('退房', -1.2407520558292324),
#  ('不好', -1.1935466525752536),
#  ('喝', -1.1577389071778386),
#  ('慢', -1.1529645246444826),
#  ('不了', -1.1454498150216568),
#  ('订单', -1.1362992503900142),
#  ('简直', -1.1291599917280972),
#  ('换', -1.1100568387593051),
#  ('携程', -1.1004518957718248),
#  ('太小', -1.0893167830818535),
#  ('不行', -1.0868633961790266),
#  ('居然', -1.0837448184938838),
#  ('竟然', -1.0635986795012942),
#  ('办法', -1.0452187169358944),
#  ('开机', -1.0042429902253385)]

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b5d1699b-ba6e-47f8-9d3d-1aa2edad9bfb">Loading BokehJS ...</span>
#     </div>

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],pos_neg_ratios.most_common())), density=True, bins=100, normed=True)
# print(hist,edges)
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Word Positive/Negative Affinity Distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a4c93a9f-9a10-4079-b97e-93695ae882e9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("a4c93a9f-9a10-4079-b97e-93695ae882e9").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a4c93a9f-9a10-4079-b97e-93695ae882e9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a4c93a9f-9a10-4079-b97e-93695ae882e9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"30afd5ae-d839-47ca-b7c9-63dba48ccc66":{"roots":{"references":[{"attributes":{"plot":{"id":"8ff51323-7c64-4490-b1a1-f67a7409bbf4","subtype":"Figure","type":"Plot"}},"id":"ba5cf22b-3770-4303-abd8-804213e70ca5","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["left","right","top"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[100]},"right":{"__ndarray__":"...","dtype":"float64","shape":[100]},"top":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"9ce2e331-fc1f-4bea-bbdf-bf9b728af6e3","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"d13c7662-9186-4ba3-a222-16acf808225b","type":"LinearAxis"}],"left":[{"id":"652eb704-5e25-455a-9085-89fd67e0dea2","type":"LinearAxis"}],"renderers":[{"id":"d13c7662-9186-4ba3-a222-16acf808225b","type":"LinearAxis"},{"id":"793491d5-1f2d-460d-9f02-ff3d849e05a6","type":"Grid"},{"id":"652eb704-5e25-455a-9085-89fd67e0dea2","type":"LinearAxis"},{"id":"bc1eb442-f3b3-4f21-a9c7-ae81a83e074c","type":"Grid"},{"id":"fd77606d-7291-43a7-ba65-7928d6473eca","type":"GlyphRenderer"}],"title":{"id":"7cb23103-e9e6-4163-8ab4-1f086de3fab8","type":"Title"},"tool_events":{"id":"b8537d7e-e2db-4ad8-94ea-efece48c96af","type":"ToolEvents"},"toolbar":{"id":"71fb5dd6-99e9-4837-9319-e8a0f02e417a","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"b0b418d8-5b35-4fc0-8814-bad4b25f9007","type":"DataRange1d"},"y_range":{"id":"c1d35a8e-e2bf-4a1d-8d68-af4df33405c9","type":"DataRange1d"}},"id":"8ff51323-7c64-4490-b1a1-f67a7409bbf4","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":"Word Positive/Negative Affinity Distribution"},"id":"7cb23103-e9e6-4163-8ab4-1f086de3fab8","type":"Title"},{"attributes":{"plot":{"id":"8ff51323-7c64-4490-b1a1-f67a7409bbf4","subtype":"Figure","type":"Plot"}},"id":"11b9cd75-311d-4ec2-85ec-3b46c9bf7d83","type":"ResetTool"},{"attributes":{},"id":"b8537d7e-e2db-4ad8-94ea-efece48c96af","type":"ToolEvents"},{"attributes":{},"id":"a4527be8-2453-40bd-a92f-901474253459","type":"BasicTicker"},{"attributes":{"plot":{"id":"8ff51323-7c64-4490-b1a1-f67a7409bbf4","subtype":"Figure","type":"Pl
type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"4130eb6a-a2d7-44b1-96ef-7e7d16887df0","type":"DataRange1d"},"y_range":{"id":"0d5baf05-a31b-4459-9421-3b6f17031daa","type":"DataRange1d"}},"id":"d0db1a8a-0ab4-4ba2-8b99-69559dad1ba9","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"d0db1a8a-0ab4-4ba2-8b99-69559dad1ba9","subtype":"Figure","type":"Plot"},"ticker":{"id":"d6bbda2f-35cb-4b45-b20a-e1237ec21d9e","type":"BasicTicker"}},"id":"6e2cd207-8eca-4403-8f22-415e73ca8330","type":"Grid"},{"attributes":{"formatter":{"id":"4a4cfe72-3663-4642-8d29-b573c1c81f82","type":"BasicTickFormatter"},"plot":{"id":"d0db1a8a-0ab4-4ba2-8b99-69559dad1ba9","subtype":"Figure","type":"Plot"},"ticker":{"id":"9077e535-90d6-42d6-862c-3487191f282b","type":"BasicTicker"}},"id":"f0b7d78d-6c76-43c8-b99d-d486c1845cf7","type":"LinearAxis"},{"attributes":{},"id":"d6bbda2f-35cb-4b45-b20a-e1237ec21d9e","type":"BasicTicker"},{"attributes":{"plot":{"id":"d0db1a8a-0ab4-4ba2-8b99-69559dad1ba9","subtype":"Figure","type":"Plot"}},"id":"ee511a9b-67f1-41bf-9a0b-275ecdd8fd85","type":"PanTool"},{"attributes":{"plot":null,"text":"The frequency distribution of the words in our corpus"},"id":"de1fbdf5-5097-43c4-8d27-4e20e80c55cb","type":"Title"},{"attributes":{"formatter":{"id":"9a68aa24-9b35-472e-b40a-d2c72f5d4319","type":"BasicTickFormatter"},"plot":{"id":"d0db1a8a-0ab4-4ba2-8b99-69559dad1ba9","subtype":"Figure","type":"Plot"},"ticker":{"id":"d6bbda2f-35cb-4b45-b20a-e1237ec21d9e","type":"BasicTicker"}},"id":"2daaca9b-67a8-4236-9f26-ea17615f863a","type":"LinearAxis"},{"attributes":{},"id":"9077e535-90d6-42d6-862c-3487191f282b","type":"BasicTicker"},{"attributes":{},"id":"9a68aa24-9b35-472e-b40a-d2c72f5d4319","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"d0db1a8a-0ab4-4ba2-8b99-69559dad1ba9","subtype":"Figure","type":"Plot"}},"id":"9146809a-8492-4333-8774-8aa8f30fd6a4","type":"SaveTool"},{"attributes":{},"id":"4a4cfe72-3663-4642-8d29-b573c1c81f82","type":"BasicTickFormatter"},{"attributes ...

# %% [markdown]
# 从上面两个图我们可以知道，大多数词出现的次数其实是不到180的，因此我们完全可以把这些词过滤出去
# 另外一个就是在词的分布上，我们可以看到对于一些中间的其实其是比较模糊的词，没有很强的对比性，可能在-0.2到0.2之间的词，我们也不做考虑
# 考虑以上两点，就有了下面的优化

# %%
import time
import sys
import numpy as np
# Let's tweak our network from before to model these phenomena
class SentimentNetwork:
    def __init__(self, reviews,labels,min_count = 180,polarity_cutoff = 0.1,hidden_nodes = 10, learning_rate = 0.1):
       
        # set our random number generator 
        np.random.seed(1)
    
        self.pre_process_data(reviews, labels, polarity_cutoff, min_count)
        
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)
        
        
    def pre_process_data(self, reviews, labels, polarity_cutoff, min_count):
        positive_counts = Counter()
        negative_counts = Counter()
        total_counts = Counter()

        # 计算出 pos 和 neg 中出现的次数
        for i in range(len(reviews)):
            if(labels[i] == 1):
                for word in reviews[i]:
                    positive_counts[word] += 1
                    total_counts[word] += 1
            else:
                for word in reviews[i]:
                    negative_counts[word] += 1
                    total_counts[word] += 1
        
        pos_neg_ratios = Counter()
        # 计算单词在 pos 和 neg 中出现的比率
        for term,cnt in list(total_counts.most_common()):
            if(cnt >= min_count):
                pos_neg_ratio = positive_counts[term] / float(negative_counts[term]+1)
                pos_neg_ratios[term] = pos_neg_ratio
                
        # 转换数据正规化
        for word,ratio in pos_neg_ratios.most_common():
            if(ratio > 1):
                pos_neg_ratios[word] = np.log(ratio)
            else:
                pos_neg_ratios[word] = -np.log((1 / (ratio + 0.01)))
                
        review_vocab = set()
        for review in reviews:
            for word in review:
                if(total_counts[word] > min_count):
                    if(word in pos_neg_ratios.keys()):
                        if((pos_neg_ratios[word] >= polarity_cutoff) or (pos_neg_ratios[word] <= -polarity_cutoff)):
                            review_vocab.add(word)
                    else:
                        review_vocab.add(word)
                        
        self.review_vocab = list(review_vocab)
        
#         label_vocab = set()
#         for label in labels:
#             label_vocab.add(label)
        
#         self.label_vocab = list(label_vocab)
        
        self.review_vocab_size = len(self.review_vocab)
#         self.label_vocab_size = len(self.label_vocab)
        
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
#         self.label2index = {}
#         for i, label in enumerate(self.label_vocab):
#             self.label2index[label] = i
         
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Initialize weights
        self.weights_0_1 = np.zeros((self.hidden_nodes,self.input_nodes))
    
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.output_nodes, self.hidden_nodes))
        
        self.learning_rate = learning_rate
        
        self.layer_0 = np.zeros((input_nodes,1))
        self.layer_1 = np.zeros((hidden_nodes,1))
    
        
    def update_input_layer(self,review):

        # clear out previous state, reset the layer to be all 0s
        self.layer_0 *= 0
        for word in review:
            if(word in self.word2index.keys()):
                self.layer_0[self.word2index[word]][0] = 1
                
#     def get_target_for_label(self,label):
#         if(label == 'POSITIVE'):
#             return 1
#         else:
#             return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def train(self, training_reviews_raw, training_labels):
        
        training_reviews = list()
        for review in training_reviews_raw:
            indices = set()
            for word in review:
                if(word in self.word2index.keys()):
                    indices.add(self.word2index[word])
            training_reviews.append(list(indices))
        
        assert(len(training_reviews) == len(training_labels))
        
        correct_so_far = 0
        
        start = time.time()
        
        for i in range(len(training_reviews)):
            
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            # Input Layer
#             self.update_input_layer(review)
#             layer_0 = self.layer_0
            # Hidden layer
#             layer_1 = self.weights_0_1.dot(self.layer_0)
            self.layer_1 *= 0
            for index in review:
                self.layer_1 += self.weights_0_1[:,[index]]

            # Output layer
            layer_2 = self.sigmoid(self.weights_1_2.dot(self.layer_1))

            #### Implement the backward pass here ####
            ### Backward pass ###

            # TODO: Output error
            layer_2_error = layer_2 - label # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # TODO: Backpropagated error
            layer_1_error = self.weights_1_2.T.dot(layer_2_delta) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # TODO: Update the weights
            self.weights_1_2 -= layer_2_delta.dot(self.layer_1.T) * self.learning_rate # update hidden-to-output weights with gradient descent step
#             self.weights_0_1 -= layer_1_delta.dot(self.layer_0.T) * self.learning_rate # update input-to-hidden weights with gradient descent step
            for index in review:
                self.weights_0_1[:,[index]] -= layer_1_delta * self.learning_rate

            if(np.abs(layer_2_error) < 0.5):
                correct_so_far += 1
            
            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + __builtins__.str(100 * i/float(len(training_reviews)))[:4] + "% Speed(reviews/sec):" + __builtins__.str(reviews_per_second)[0:5] + " #Correct:" + __builtins__.str(correct_so_far) + " #Trained:" + __builtins__.str(i+1) + " Training Accuracy:" + __builtins__.str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        
        correct = 0
        
        start = time.time()
        
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + __builtins__.str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + __builtins__.str(reviews_per_second)[0:5] \
                            + "% #Correct:" + __builtins__.str(correct) + " #Tested:" + __builtins__.str(i+1) + " Testing Accuracy:" + __builtins__.str(correct * 100 / float(i+1))[:4] + "%")
            
    def run(self, review):
        
        # Input Layer
#         print(review)
        self.update_input_layer(review)
#         print(self.layer_0.shape)
#         print(self.weights_0_1.shape)
#         print(np.dot(self.weights_0_1,self.layer_0))
        # Hidden layer
        layer_1 = self.weights_0_1.dot(self.layer_0)

        # Output layer
        layer_2 = self.sigmoid(self.weights_1_2.dot(layer_1))
#         print(layer_2) # 发现一只0.5呢
        if(layer_2[0] > 0.5):
            return 1
        else:
            return 0

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=180,polarity_cutoff=0.1,learning_rate=0.1)

# %%
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:0 #Trained:1 Training Accuracy:0.0%
# Progress:12.4% Speed(reviews/sec):1077. #Correct:1865 #Trained:2501 Training Accuracy:74.5%
# Progress:24.8% Speed(reviews/sec):1131. #Correct:3854 #Trained:5001 Training Accuracy:77.0%
# Progress:37.3% Speed(reviews/sec):1214. #Correct:5898 #Trained:7501 Training Accuracy:78.6%
# Progress:49.7% Speed(reviews/sec):1218. #Correct:7972 #Trained:10001 Training Accuracy:79.7%
# Progress:62.1% Speed(reviews/sec):1229. #Correct:10040 #Trained:12501 Training Accuracy:80.3%
# Progress:74.6% Speed(reviews/sec):1229. #Correct:12111 #Trained:15001 Training Accuracy:80.7%
# Progress:87.0% Speed(reviews/sec):1243. #Correct:14210 #Trained:17501 Training Accuracy:81.1%
# Progress:99.4% Speed(reviews/sec):1221. #Correct:16314 #Trained:20001 Training Accuracy:81.5%
# Progress:99.9% Speed(reviews/sec):1223. #Correct:16397 #Trained:20105 Training Accuracy:81.5%

# %% [markdown]
# 进行到这，处理速度是快了，但是准确率不高。囧
# ## 分析：weights发生了什么
# 我们来分析下，在不断训练过程中，weight是怎么变化的
# 一个预测是词义相同的词应该对于最终的贡献是相当的，那weight值也应该是差不多的，让我们来验证下

# %%
mlp_full = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=0,polarity_cutoff=0,learning_rate=0.1)

# %%
mlp_full.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:0 #Trained:1 Training Accuracy:0.0%
# Progress:12.4% Speed(reviews/sec):729.0 #Correct:1881 #Trained:2501 Training Accuracy:75.2%
# Progress:24.8% Speed(reviews/sec):657.7 #Correct:3959 #Trained:5001 Training Accuracy:79.1%
# Progress:37.3% Speed(reviews/sec):647.5 #Correct:6077 #Trained:7501 Training Accuracy:81.0%
# Progress:49.7% Speed(reviews/sec):638.3 #Correct:8238 #Trained:10001 Training Accuracy:82.3%
# Progress:62.1% Speed(reviews/sec):644.2 #Correct:10431 #Trained:12501 Training Accuracy:83.4%
# Progress:74.6% Speed(reviews/sec):653.8 #Correct:12607 #Trained:15001 Training Accuracy:84.0%
# Progress:87.0% Speed(reviews/sec):659.0 #Correct:14827 #Trained:17501 Training Accuracy:84.7%
# Progress:99.4% Speed(reviews/sec):658.7 #Correct:17034 #Trained:20001 Training Accuracy:85.1%
# Progress:99.9% Speed(reviews/sec):658.8 #Correct:17122 #Trained:20105 Training Accuracy:85.1%

# %%
def get_most_similar_words(focus = "快乐"):
    most_similar = Counter()

    for word in mlp_full.word2index.keys():
        most_similar[word] = np.dot(mlp_full.weights_0_1[:,mlp_full.word2index[word]],mlp_full.weights_0_1[:,mlp_full.word2index[focus]])
    
    return most_similar.most_common()

# %%
get_most_similar_words("快乐")
# Out:
# [('不错', 0.33538066226583924),
#  ('配置', 0.25838511832658073),
#  ('很快', 0.23718560658398344),
#  ('外观', 0.22438845743883634),
#  ('性价比', 0.21692741585717784),
#  ('感动', 0.20675190024284118),
#  ('感谢', 0.20565860660647881),
#  ('很漂亮', 0.20487517481149334),
#  ('光明', 0.20001075298186977),
#  ('漂亮', 0.19736937455766837),
#  ('好书', 0.19366636139248222),
#  ('真正', 0.18227985122536425),
#  ('幸福', 0.18077308105077824),
#  ('小巧', 0.17988430420309548),
#  ('热情', 0.17671572715206291),
#  ('还会', 0.17573211604280287),
#  ('超值', 0.17403785747706707),
#  ('哈哈', 0.17319925416462717),
#  ('好评', 0.17237904911309371),
#  ('清晰', 0.17131698383957533),
#  ('他', 0.16729380070886524),
#  ('完美', 0.16656352304193311),
#  ('结局', 0.16309226052192979),
#  ('酸酸乳', 0.16252179145922346),
#  ('比', 0.15436270654073617),
#  ('其实', 0.1530907295500456),
#  ('实惠', 0.15106874868159834),
#  ('很', 0.15070259293616733),
#  ('齐全', 0.14996883087047183),
#  ('喜欢', 0.14568771045978945),
#  ('活动', 0.14339230577439147),
#  ('今天', 0.14321462964042642),
#  ('挺快', 0.14299058937954262),
#  ('好吃', 0.14277205150214961),
#  ('优点', 0.14239115242795114),
#  ('方便', 0.14187773129609182),
#  ('爱', 0.14072874277646394),
#  ('非常', 0.14013127246883314),
#  ('带', 0.13973015932278163),
#  ('毕竟', 0.13959651634414977),
#  ('成长', 0.13741762793376394),
#  ('学习', 0.13732954386831617),
#  ('坚持', 0.13697113724397764),
#  ('实用', 0.13682835706629048),
#  ('交通', 0.13578935594907141),
#  ('免费', 0.13457060708868257),
#  ('支持', 0.13450656246447068),
#  ('行', 0.13242937826786555),
#  ('世界', 0.13054606443159156),
#  ('高', 0.12563950448409475),
#  ('游戏', 0.12493602700267337),
#  ('最好', 0.1235892918628852),
#  ('妈妈', 0.12231632326136882),
#  ('挺', 0.12189925937857907),
#  ('一口气', 0.12160775446681368),
#  ('人生', 0.12020352471674921),
#  ('品牌', 0.1194549191616705),
#  ('了解', 0.11941607104064592),
#  ('犹豫', 0.054398279917678878),
#  ('长', 0.054395786125626323),
#  ('com', 0.054395191096380656),
#  ('应用', 0.054389789553870853),
#  ('金属外壳', 0.054265572216895229),
#  ('有名', 0.054180421606733434),
#  ('太好了', 0.054179774285000586),
#  ('放在', 0.053997540886293487),
#  ('@', 0.053957816045684094),
#  ('特仑苏', 0.053894247591509375),
#  ('均衡', 0.053852258973758796),
#  ('理性', 0.053723998958950719),
#  ('娓娓道来', 0.053710869029139109),
#  ('现实', 0.053676131078326375),
#  ('黑白', 0.053672212161413851),
#  ('强', 0.053560467114746102),
#  ('计较', 0.053327192799513271),
#  ('行货', 0.05325631818299012),
#  ('信心', 0.053232650646842267),
#  ('过程', 0.053226540074192377),
#  ('模式', 0.053179791855434713),
#  ('美味', 0.053174105969439035),
#  ('24', 0.053170085748173744),
#  ('编辑', 0.053146179077700327),
#  ('嗯', 0.05304682804775003),
#  ('单独', 0.052979090935268522),
#  ('连续', 0.052937128964024083),
#  ('楼层', 0.052904255547531406),
#  ('mm', 0.052883592585756367),
#  ('着', 0.052828538111932943),
#  ('见识', 0.052681320107844674),
#  ('牛奶', 0.052604096196189054),
#  ('感悟', 0.052519129370540485),
#  ('美中不足', 0.052515454288812817),
#  ('杂志', 0.052465808469030178),
#  ('欢迎', 0.052390682397849303),
#  ('讲解', 0.052372070291891434),
#  ('古代', 0.052210228268345468),
#  ('不贵', 0.052204285684830654),
#  ('看过', 0.052201429337582386),
#  ('那段', 0.052187434107751243),
#  ('安排', 0.05214016762789915),
#  ('心爱', 0.052066319084504667),
#  ('做到', 0.052048677161762369),
#  ('反而', 0.051857468605385676),
#  ('仍然', 0.051847845836668217),
#  ('细腻', 0.051789594590430629),
#  ('万', 0.05178763700247517),
#  ('大', 0.051680828270848411),
#  ('照顾', 0.051563582790256107),
#  ('关键', 0.051549064257582843),
#  ('过', 0.051375916084710135),
#  ('达到', 0.05134001373340083),
#  ('一段时间', 0.051182501089281587),
#  ('吹风机', 0.051101495215749235),
#  ('增强', 0.051055941309511049),
#  ('幸运', 0.050988686279915332),
#  ('民主', 0.050880146480771896),
#  ('房子', 0.05083719741681849),
#  ('出差', 0.050821871754745562),
#  ('酸牛奶', 0.050761010989099027),
#  ('豪华', 0.050708650700496072),
#  ('out', 0.050693536348324762),
#  ('最初', 0.050678681155453709),
#  ('放下', 0.050473589002484769),
#  ('雀巢', 0.050457693775916822),
#  ('\n', 0.050351524134026542),
#  ('相对', 0.05034971059421238),
#  ('地铁', 0.050304545500376795),
#  ('结合', 0.05025612534224469),
#  ('音质', 0.050189377973907469),
#  ('第一本', 0.050188717528008936),
#  ('古典', 0.050155492949245359),
#  ('国家', 0.050060590017220838),
#  ('南京', 0.050020130192484372),
#  ('自助', 0.049874409859678961),
#  ('C', 0.049839072651732895),
#  ('某种', 0.049783827315000327),
#  ('欣赏', 0.049777989392883255),
#  ('很近', 0.049702184417467946),
#  ('情绪', 0.049622075352534538),
#  ('数码相机', 0.049503929706186875),
#  ('新鲜', 0.034280627638727135),
#  ('日子', 0.034215245776376212),
#  ('下次', 0.034199395273851747),
#  ('一大', 0.034180741351347681),
#  ('骄傲', 0.034151272517333145),
#  ('大有', 0.034102424257158606),
#  ('哈哈哈哈', 0.034098854984424221),
#  ('专门', 0.034026252956068016),
#  ('风景', 0.033952529633624592),
#  ('芦荟', 0.033939426609677546),
#  ('分享', 0.033917710028213491),
#  ('揣摩', 0.033861658593483723),
#  ('体积', 0.033830970086655157),
#  ('大清', 0.033791016543343294),
#  ('家乡', 0.033789741557731109),
#  ('吸引', 0.033786487453683949),
#  ('无穷', 0.033785453292916628),
#  ('便于', 0.033781215564779629),
#  ('完备', 0.033763593630323385),
#  ('写给', 0.033723315371960036),
#  ('买下', 0.033700500760477176),
#  ('感性', 0.033672905538198752),
#  ('篮球', 0.033669888621486392),
#  ('几率', 0.033637299612439678),
#  ('打算', 0.033636930964597689),
#  ('现在', 0.033602565377443341),
#  ...]

# %%
get_most_similar_words("很差")
# Out:
# [('失望', 0.85875815559965318),
#  ('差', 0.6900918464910496),
#  ('抵制', 0.64737891767552369),
#  ('很差', 0.61566873849650305),
#  ('不如', 0.59475802794155375),
#  ('垃圾', 0.57265810403945516),
#  ('内容', 0.5178029813713555),
#  ('不', 0.49460849862501899),
#  ('不够', 0.49421096739949072),
#  ('根本', 0.49069603367023529),
#  ('不好', 0.48279059089122578),
#  ('没有', 0.47988697809120617),
#  ('不是', 0.46787450230499544),
#  ('投诉', 0.45251685102295336),
#  ('恶心', 0.44848101653371764),
#  ('远离', 0.4368951082501939),
#  ('不了', 0.43286174021667428),
#  ('上当', 0.42958499335700484),
#  ('麻烦', 0.42611840032075671),
#  ('没什么', 0.41830870085654498),
#  ('后悔', 0.40416130203055928),
#  ('太差', 0.40233821454809066),
#  ('翻', 0.4019551210563671),
#  ('死机', 0.39615470896260663),
#  ('喝', 0.38790485419495879),
#  ('重', 0.3834931817481842),
#  ('严重', 0.37150603537219618),
#  ('慢', 0.37021794711393319),
#  ('论语', 0.36786171501341336),
#  ('不能', 0.35867759913666436),
#  ('脏', 0.35719651072579922),
#  ('不买', 0.35280715241874805),
#  ('居然', 0.35256756954971513),
#  ('几页', 0.35185104168984299),
#  ('唉', 0.34610839607356558),
#  ('太', 0.34478099990711858),
#  ('无法', 0.3444997544936827),
#  ('退房', 0.33960301741933352),
#  ('丹', 0.33198204477165472),
#  ('写', 0.32636345913299608),
#  ('太小', 0.32324058706054348),
#  ('逼', 0.3230092577291136),
#  ('简直', 0.32274718153684617),
#  ('骗', 0.30876713242385884),
#  ('竟然', 0.30781354243409936),
#  ('书', 0.30503690077672985),
#  ('指纹', 0.30181979856215746),
#  ('不要', 0.29894433407956034),
#  ('极差', 0.2971642448087749),
#  ('？', 0.29290246443082713),
#  ('没法', 0.28967527100071494),
#  ('可能', 0.28824739158536439),
#  ('要是', 0.28783760050864565),
#  ('不太', 0.28679331997463392),
#  ('无', 0.28581848704843282),
#  ('只能', 0.28495326882191158),
#  ('设施', 0.16768152076811577),
#  ('没到', 0.1673952002622888),
#  ('远', 0.16716097179442557),
#  ('早已', 0.16707852878790835),
#  ('跟风', 0.16693542065986128),
#  ('号称', 0.16686245992443433),
#  ('下', 0.1663357393887101),
#  ('而已', 0.16598260235933321),
#  ('就', 0.1657083446607473),
#  ('一般般', 0.16552030726433387),
#  ('一家', 0.16506367453640686),
#  ('黑色', 0.16490098627378014),
#  ('不爽', 0.16488906228752273),
#  ('哎', 0.16457097190408165),
#  ('彩信', 0.16397774477048277),
#  ('浪费时间', 0.1636383161904118),
#  ('怎么', 0.16342496226658609),
#  ('无奈', 0.16321323460214809),
#  ('无非', 0.16296450792216205),
#  ('预订', 0.16283614731945656),
#  ('英文', 0.16281299446221775),
#  ('取', 0.16237176238901724),
#  ('粗糙', 0.16237032004903182),
#  ('幽默', 0.16236783087667828),
#  ('不可', 0.16226684492484705),
#  ('次', 0.16180201739753625),
#  ('啥', 0.16159006458411243),
#  ('无所谓', 0.16118162611437362),
#  ('不佳', 0.16098567785820195),
#  ('键', 0.16095243676408011),
#  ('连', 0.16044074422118296),
#  ('大众', 0.16014693610897621),
#  ('烂', 0.1600736174933986),
#  ('原版', 0.15906598949206247),
#  ('到达', 0.15888998453407369),
#  ('容易', 0.1586372170648799),
#  ('定', 0.15850932129881246),
#  ('分钟', 0.15846384592699442),
#  ('异味', 0.15795332608825799),
#  ('书写', 0.15789908513861536),
#  ('t', 0.15787666901879843),
#  ('混乱', 0.15779777569724143),
#  ('赶', 0.15775910877588539),
#  ('就要', 0.15758953307990994),
#  ('自杀', 0.15757916617237744),
#  ('缝隙', 0.15753967077558317),
#  ('电源', 0.1573825013405637),
#  ('职场', 0.15732653744382752),
#  ('大失所望', 0.15704546210397019),
#  ('维修', 0.15689536852510982),
#  ('地方', 0.15677544134575805),
#  ('小孩子', 0.15651864876178032),
#  ('意思', 0.15638243827108622),
#  ('梅拉', 0.15617243628857502),
#  ('外壳', 0.15611673763496864),
#  ('星', 0.15584229110030462),
#  ('生命', 0.15544252387013177),
#  ('一会', 0.15515411847586735),
#  ('满怀', 0.15478595499355452),
#  ('只有', 0.1544720679589302),
#  ('提醒', 0.15443521729279025),
#  ('外企', 0.15435916752497184),
#  ('错误', 0.15427859908964325),
#  ('N', 0.1542278634875871),
#  ('洗手间', 0.1542199757307546),
#  ('文采', 0.15386520235720802),
#  ('松动', 0.15365746326631563),
#  ('死', 0.15351046442254662),
#  ('就算', 0.15343450587502733),
#  ('男人', 0.15339456517512906),
#  ('要求', 0.1533157184437747),
#  ('百家讲坛', 0.1532556150717598),
#  ('宽带', 0.15322669435605843),
#  ('空调', 0.15223268620662819),
#  ('这部', 0.15221000486902905),
#  ('星期', 0.15161473448911),
#  ('废话', 0.15082992525647987),
#  ('按键', 0.15080277899949379),
#  ('心理学', 0.15079414605778785),
#  ('如果', 0.15036278585591706),
#  ('抱歉', 0.15024445154839094),
#  ('退', 0.14947674046192325),
#  ('公平', 0.14947005764076743),
#  ('不肯', 0.14920242399591122),
#  ('讨厌', 0.14918078642682964),
#  ('别扭', 0.14917031832134592),
#  ('易中天', 0.14898392479328215),
#  ('例子', 0.14863754824694161),
#  ('乱', 0.14826001298824404),
#  ('成', 0.14822745791806996),
#  ('三思', 0.14804759388805569),
#  ('不太好', 0.14774978453655063),
#  ('10', 0.14734981061616054),
#  ('显示', 0.14704497477715003),
#  ('通病', 0.14684124859288594),
#  ('写成', 0.14665665876471473),
#  ('求己', 0.14641272922180534),
#  ('折腾', 0.14624350899074232),
#  ('不大好', 0.14507084725734604),
#  ('气愤', 0.14504468798757431),
#  ('反映', 0.14485636523094264),
#  ('张', 0.14485513305607955),
#  ('进去', 0.14479415138901069),
#  ('烫', 0.14477585904320983),
#  ('悲哀', 0.14471015585361541),
#  ('配', 0.14440766172592359),
#  ('太太', 0.1435506064463587),
#  ('膜', 0.14334194293315816),
#  ('昏暗', 0.14281326062789182),
#  ('烫手', 0.14262181810858654),
#  ('办法', 0.14185416919456972),
#  ('亲子', 0.14123766920547282),
#  ('马路', 0.14102255820143256),
#  ('还要', 0.14093329276741356),
#  ('强烈', 0.14069718465215908),
#  ('洗', 0.14041146272247534),
#  ('道歉', 0.14030970708118326),
#  ('也就是说', 0.1401663036175945),
#  ('幼稚', 0.14010254498242503),
#  ('心得', 0.13993677034838575),
#  ('胡', 0.13981249223675707),
#  ('才能', 0.13958105852825123),
#  ('畅销书', 0.13928832750424242),
#  ('乏味', 0.13919976324373151),
#  ('自', 0.13919025883167757),
#  ('忽悠', 0.13888393151203424),
#  ('修', 0.13877308187001619),
#  ('自动关机', 0.13869150311885731),
#  ('爱看', 0.13851110017973384),
#  ('发霉', 0.13825449850383204),
#  ('心理', 0.13821261059994933),
#  ('纯粹', 0.13770302794684824),
#  ('嘈杂', 0.13739881810838911),
#  ('短信', 0.13735306774787695),
#  ('半天', 0.13699855919894033),
#  ('生产日期', 0.13684774487952528),
#  ('嫌疑', 0.13666640389461698),
#  ('...', 0.13661818661970909),
#  ('调侃', 0.13656333453169192),
#  ('黑心', 0.13647699321070578),
#  ('，', 0.13643126768684849),
#  ('浴室', 0.13631347464910437),
#  ('费', 0.13614780218066938),
#  ('过来', 0.13587865905013038),
#  ('订单', 0.13563510847182378),
#  ('看', 0.13546917219388169),
#  ('新意', 0.13543407115892228),
#  ('宝贵意见', 0.13543103361503073),
#  ('毒害', 0.13541433530265182),
#  ('过期', 0.1349216067466629),
#  ('类型', 0.13453566235871853),
#  ('左边', 0.13447992860836838),
#  ('缘故', 0.13413396932419219),
#  ('损失', 0.13348286667565151),
#  ('心目', 0.13336033730150865),
#  ('蓝牙', 0.13323117488645883),
#  ('罢了', 0.13322877587594598),
#  ('一晚', 0.133171850609732),
#  ('驱动', 0.13300108534171395),
#  ('卫生', 0.13278511733928797),
#  ('温度', 0.13252080717680464),
#  ('.....', 0.13251162788261661),
#  ('蚊子', 0.13246305316783469),
#  ('40', 0.13211321939409201),
#  ('停车场', 0.13158605168008861),
#  ('一个', 0.13110203748184907),
#  ('书评', 0.13102859022522265),
#  ('光线', 0.13091103280189062),
#  ('卫生条件', 0.13075702577574108),
#  ('否则', 0.13057545636667053),
#  ('物质', 0.13043962053099631),
#  ('盖', 0.13043908088385761),
#  ('叙述', 0.13043096422164524),
#  ('中好', 0.13024035641837323),
#  ('问题', 0.12998963989527418),
#  ('庄子', 0.12981244605068817),
#  ('感觉不好', 0.12977387422515479),
#  ('玩意', 0.12958100752541463),
#  ('味道', 0.12955961794292598),
#  ('恶劣', 0.12954663872205879),
#  ('不少', 0.12945478305930666),
#  ('菜鸟', 0.12927630803685897),
#  ('该', 0.12917821255292403),
#  ('隔壁', 0.12908371630407425),
#  ('将', 0.12894644710274297),
#  ('除了', 0.12887899992652185),
#  ('很小', 0.12882213406239595),
#  ('上海', 0.12870904556094781),
#  ('边上', 0.12839084302123674),
#  ('看不懂', 0.1280982021436603),
#  ('随便', 0.12806033828184796),
#  ('开机', 0.1279969459201355),
#  ('偏', 0.12797182019352857),
#  ('按钮', 0.1278172794465082),
#  ('顶多', 0.12780554047798462),
#  ('什么', 0.12770572590137913),
#  ('蒙', 0.12746413571961301),
#  ('老旧', 0.12727889406799639),
#  ('脑残', 0.12720614108068345),
#  ('输入', 0.12690070919956922),
#  ('失败', 0.12646769536395583),
#  ('差异', 0.12642790075090921),
#  ('牵强', 0.12640828847077668),
#  ('星级', 0.12630052932950775),
#  ('稍', 0.12617619594648766),
#  ('可怜', 0.12603045109912822),
#  ('太过', 0.12581273682394972),
#  ('顾客', 0.1255516540627849),
#  ('害', 0.12522622563941654),
#  ('比较慢', 0.12515704849511511),
#  ('答复', 0.12507111436005416),
#  ('真是', 0.12443068445187869),
#  ('难以', 0.12441965541232969),
#  ('杂乱', 0.12424940412193589),
#  ('啊', 0.12406384989464991),
#  ('太高', 0.12392499015752298),
#  ('状况', 0.12358887479282599),
#  ('之处', 0.1234112266158752),
#  ('网速', 0.12297205443401418),
#  ('好像', 0.12287154695097355),
#  ('厂家', 0.12235626731650916),
#  ('纸张', 0.1222825954271598),
#  ('路边', 0.12224763975923372),
#  ('别的', 0.12197258315599312),
#  ('宽', 0.12176466522643342),
#  ('睡', 0.12175707597834834),
#  ('去死吧', 0.12171841812443673),
#  ('反正', 0.12130065474200782),
#  ('发货', 0.12096164675235113),
#  ('几个', 0.1209001275273246),
#  ('电梯', 0.12029688412767992),
#  ('京东', 0.11994085121934826),
#  ('出风口', 0.11981216798639469),
#  ('店大欺客', 0.11964694184772134),
#  ('A', 0.11949000262006589),
#  ('vista', 0.11941308416464552),
#  ('飞机', 0.11939845909289767),
#  ('臭', 0.11929965708758447),
#  ('时候', 0.11895294180623536),
#  ('电视', 0.11880394643433868),
#  ('系统性', 0.11853692082947823),
#  ('态度', 0.11826226160826694),
#  ('失真', 0.118020658954489),
#  ('鄙视', 0.11800805519714601),
#  ('从来不', 0.11800003151175684),
#  ('本人', 0.11794662455293942),
#  ('明明', 0.11787405710314178),
#  ('纸', 0.11787060111986361),
#  ('下去', 0.11781700458920565),
#  ('不符', 0.11761863949358156),
#  (',', 0.11758634448342448),
#  ('低于', 0.1175523642633037),
#  ('送人', 0.11719262190465936),
#  ('但书', 0.11714610225426093),
#  ('陪', 0.11706223564663797),
#  ('200', 0.11686349470234654),
#  ('那里', 0.11671009055700812),
#  ('经理', 0.11664373842804926),
#  ('不想', 0.11631246013054648),
#  ('难看', 0.11603350611649976),
#  ('睡觉', 0.11601023911463798),
#  ('cn', 0.11567754006666547),
#  ('估计', 0.11547444735717863),
#  ('下水', 0.11546571382265607),
#  ('插槽', 0.11535671736795045),
#  ('信号', 0.11500401622092703),
#  ('害得', 0.11496466797731852),
#  ('一边', 0.11491565755449852),
#  ('入睡', 0.11484688980372551),
#  ('购书', 0.11478204282549721),
#  ('月', 0.11468346696562193),
#  ('还是', 0.11426506473552783),
#  ('千万', 0.11424430847419248),
#  ('照片', 0.11415971384303428),
#  ('空', 0.11396434104510456),
#  ('坑', 0.11392658490611951),
#  ('不要脸', 0.11379910500904628),
#  ('些', 0.11353437832257528),
#  ('互相', 0.11352843050226223),
#  ('为啥', 0.11342994494587001),
#  ('单调', 0.11329852229490718),
#  ('最烂', 0.11326535526411255),
#  ('很难', 0.11321565800634925),
#  ('内存', 0.1129153099694632),
#  ('块', 0.1127527843375864),
#  ('好点', 0.11256981485390921),
#  ('不吃', 0.11207454600393033),
#  ('负面', 0.11180786249218716),
#  ('1', 0.11170531201512834),
#  ('过时', 0.1116758530714064),
#  ('大多数', 0.11166498244907401),
#  ('不知', 0.11166346580322078),
#  ('好处', 0.11128589433901163),
#  ('卖弄', 0.11124273181291144),
#  ('弱', 0.11107833536132185),
#  ('黑', 0.11089198403488754),
#  ('霉味', 0.11034941220367683),
#  ('宁静', 0.11018640344859224),
#  ('个人感觉', 0.10992930636948095),
#  ('毛巾', 0.10958472330153454),
#  ('翻翻', 0.10945755675185068),
#  ('偏小', 0.10933666031273404),
#  ('典型', 0.10923315730775865),
#  ('一个个', 0.10921444439811197),
#  ('三个', 0.10906937174213618),
#  ('成都', 0.10904069169063366),
#  ('上面', 0.10882224447647057),
#  ('广大', 0.10873894126431871),
#  ('实现', 0.10856030928770465),
#  ('榜样', 0.10826453546360498),
#  ('强烈要求', 0.10813390421113048),
#  ('爹', 0.10785005837335523),
#  ('用处', 0.10778773095203595),
#  ('交涉', 0.10750940779072952),
#  ('以下', 0.1074283803930707),
#  ('别', 0.10736826363554659),
#  ('体验', 0.10728948871462682),
#  ('彻底', 0.10717019159812638),
#  ('拉肚子', 0.10716809902076305),
#  ('这种', 0.10713687328290128),
#  ('声卡', 0.10711193415366063),
#  ('同志', 0.10668094315893747),
#  ('不负责任', 0.10661583577439183),
#  ('网卡', 0.10652233398757288),
#  ('找个', 0.10650655364657877),
#  ('机场', 0.1064820226234628),
#  ('边框', 0.10641505839213071),
#  ('纠结', 0.10636351595433957),
#  ('专业', 0.10633084598917862),
#  ('连锁', 0.10626118641969412),
#  ('初中生', 0.10625455083311587),
#  ('用时', 0.10621496519441215),
#  ('订', 0.1059830528267641),
#  ('半夜', 0.10593353589102553),
#  ('搬', 0.10593237860021081),
#  ('以便', 0.10587616241259615),
#  ('相差', 0.10577631717863561),
#  ('不足', 0.10576922846940848),
#  ('此书', 0.10561993730040561),
#  ('只会', 0.10554237466352756),
#  ('5', 0.10550548143041585),
#  ('绝不会', 0.10544589068505769),
#  ('理睬', 0.10543240512049805),
#  ('这个', 0.10534545335130235),
#  ('风扇', 0.10515195656749519),
#  ('呸', 0.1047191038126547),
#  ('另外', 0.10466979482042983),
#  ('呀', 0.10454020862786571),
#  ('整本书', 0.1044835284473847),
#  ('第三', 0.10441591062267953),
#  ('插图', 0.10430851622595216),
#  ('SATA', 0.10416910116093524),
#  ('靠', 0.10410265001363535),
#  ('好意思', 0.10409626123022644),
#  ('偏僻', 0.1040672952895639),
#  ('休息', 0.10405360568937039),
#  ('松', 0.10378687370336767),
#  ('区域', 0.10378686508233635),
#  ('新机', 0.10374711367250244),
#  ('至今', 0.10366339570657865),
#  ('程度', 0.10361789514083174),
#  ('畅销', 0.10355350243440706),
#  ('块钱', 0.10344737348958469),
#  ('发出', 0.10309148885451935),
#  ('评论', 0.10302901912225491),
#  ('接近', 0.10269584783834847),
#  ('不低', 0.10266305137815694),
#  ('无用', 0.10254129350015725),
#  ('外', 0.10208641647004599),
#  ('见', 0.10184937764569352),
#  ('朗读', 0.1017267355774478),
#  ('右下角', 0.1016801835103842),
#  ('原', 0.10159687085507106),
#  ('几年', 0.10155601384979102),
#  ('订购', 0.1013160021122665),
#  ('我订', 0.1012941166246497),
#  ('不理', 0.10112365164587771),
#  ('认同', 0.10092386942814312),
#  ('生硬', 0.10073853744427454),
#  ('士兵', 0.10056298971082128),
#  ('大卫', 0.10051028090867919),
#  ('是', 0.1004475502717154),
#  ('何必', 0.10043362095406852),
#  ('弥补', 0.10041652738190687),
#  ('不让', 0.10013990179336676),
#  ('慎重', 0.10005950819136256),
#  ('押金', 0.09995184097925161),
#  ('噪音', 0.099883645333467497),
#  ('东方', 0.099655289033222572),
#  ('色戒', 0.099637755890133156),
#  ('当地', 0.099496158346237207),
#  ('奸商', 0.099471786528954789),
#  ('经验', 0.099444000622274598),
#  ('手续', 0.099435368513556249),
#  ('周而复始', 0.099430050369004763),
#  ('空隙', 0.099357847811192695),
#  ('烟味', 0.099193872673990852),
#  ('爱玲', 0.099096844610036997),
#  ('布局', 0.09878694035130442),
#  ('付款', 0.098763680886629193),
#  ('密密麻麻', 0.098726829019367857),
#  ('液晶屏', 0.098707021911566301),
#  ('呜呜', 0.098312917261058771),
#  ('手写笔', 0.098284322636826835),
#  ('例如', 0.098159009414588744),
#  ('要命', 0.098125708936059708),
#  ('事件', 0.098109452333807357),
#  ('一页', 0.098056053495596082),
#  ('厕所', 0.097547255407475136),
#  ('官方', 0.09741658618106383),
#  ('单', 0.097253398213235601),
#  ('造假', 0.09706351042048722),
#  ('欺骗', 0.096967176374607278),
#  ('敢', 0.096902922952897902),
#  ('想像中', 0.096624427127263102),
#  ('千万别', 0.096555426564309557),
#  ('明朝', 0.096151128511551637),
#  ('整改', 0.096051283001534427),
#  ('概括', 0.095962970156720256),
#  ('叫', 0.095862455076645148),
#  ('充电', 0.095853709501130119),
#  ('差得', 0.095731557821233826),
#  ('承认', 0.095698665893432344),
#  ('生意', 0.095361621572795346),
#  ('拖', 0.095200128063630679),
#  ('标题', 0.095085982259478286),
#  ('看后', 0.094950381108688031),
#  ('?', 0.094947021822450198),
#  ('亮度', 0.094906660268430559),
#  ('而言', 0.094795473584777731),
#  ('刷卡', 0.09471260780634877),
#  ('困难', 0.094282333147099009),
#  ('换成', 0.094172891780843426),
#  ('您', 0.094049036558720378),
#  ('连接', 0.093982073158084184),
#  ('于', 0.093537677101042854),
#  ('60', 0.093396874968155172),
#  ('触摸板', 0.093350559750931969),
#  ('插', 0.093305518057127029),
#  ('贺顿', 0.093053832600442449),
#  ('抄袭', 0.093016586918507366),
#  ('床垫', 0.09285869541982697),
#  ('完毕', 0.092723163234168959),
#  ('事实', 0.092495151885678611),
#  ('三分之一', 0.0923983936029735),
#  ('遥远', 0.092349822065914966),
#  ('商务酒店', 0.092303467451873331),
#  ('夏天', 0.092298607559307327),
#  ('手印', 0.092157215224453387),
#  ('一不小心', 0.091988660163680791),
#  ('取消', 0.091964293732544194),
#  ('15', 0.091938222543354431),
#  ('将近', 0.091886683854021253),
#  ('想象', 0.091856176498960163),
#  ('没良心', 0.091738158756632382),
#  ('国庆', 0.091728434187728081),
#  ('刺耳', 0.09167816218237948),
#  ('媒体', 0.091639648761376702),
#  ('岁', 0.091614039279588264),
#  ('大家', 0.091553194634823087),
#  ('画风', 0.091401828120577969),
#  ('室内', 0.091377079568462971),
#  ('越来越', 0.091371190471762065),
#  ('小朋友', 0.091342417329587602),
#  ('合', 0.091335549222484172),
#  ('送来', 0.09128033386468265),
#  ('时会', 0.09091725280840382),
#  ('天气', 0.090831882720084092),
#  ('形象', 0.090805658011751153),
#  ('毒死', 0.09076340105820413),
#  ('偏低', 0.090745381982506618),
#  ('技术', 0.090725021998554339),
#  ('系统盘', 0.090627996118461548),
#  ('指', 0.090563329314463925),
#  ('太重', 0.090544631210824511),
#  ('拼音', 0.090531159754363821),
#  ('销售', 0.090486334561158829),
#  ('奉劝', 0.090468969043611597),
#  ('呵', 0.09045727394292119),
#  ('天津', 0.090448819485554305),
#  ('返修', 0.090335167540769354),
#  ('快餐', 0.090262472114354841),
#  ('共读', 0.090087476298561439),
#  ('那边', 0.090052920006434042),
#  ('狠', 0.089988455989301608),
#  ('改了', 0.089967838656685048),
#  ('总之', 0.089892575057069171),
#  ('骗人', 0.08988690498683076),
#  ('第一次', 0.089842533086231968),
#  ('汉奸', 0.089794354896011952),
#  ('冷淡', 0.089648382091659984),
#  ('手册', 0.089589580917203454),
#  ('毒奶', 0.08957549212900652),
#  ('快捷酒店', 0.089488523374448958),
#  ('玻璃', 0.089436497301809859),
#  ('故意', 0.089431599383268057),
#  ('更让人', 0.074700356410148744),
#  ('不感兴趣', 0.074680424797666012),
#  ('上盖', 0.074650676090207563),
#  ('盘', 0.074645981435133429),
#  ('出书', 0.074630435817194987),
#  ('个', 0.074601322247952212),
#  ('缺陷', 0.074586977317982417),
#  ('入住', 0.074521512407704896),
#  ('乐于助人', 0.074507567216918286),
#  ('不应', 0.074422841227341996),
#  ('无语', 0.074414186410416805),
#  ('评分', 0.074366172621762844),
#  ('较慢', 0.074356186026491536),
#  ('灯光', 0.074236824670879997),
#  ('绝不', 0.074122713280391606),
#  ('老大', 0.074121070967974129),
#  ('收集器', 0.074083345071389042),
#  ('假日酒店', 0.074071790604710946),
#  ('皮', 0.073990311106363754),
#  ('收发', 0.073911400440829667),
#  ('人品', 0.073848059691734941),
#  ('不断', 0.07375132316975079),
#  ('勇气', 0.073744708488909724),
#  ('妈', 0.073738870761451983),
#  ('宝贝女儿', 0.07372975550830202),
#  ('办理', 0.073722923785175337),
#  ('理想化', 0.073638210009878163),
#  ('极易', 0.073614723450602243),
#  ('只', 0.073592419443573975),
#  ('标房', 0.073575714620955329),
#  ('8', 0.073546260554813267),
#  ('忍受', 0.073544754557909431),
#  ('180', 0.073504361465891954),
#  ('不信', 0.073454979205368989),
#  ('夜', 0.073403557118027291),
#  ('才行', 0.073396579719456317),
#  ...]

# %% [markdown]
# 从上面可以看到通过weight相似度还是能很好的区分出相近的词的
# 最后我们再来看一个图，能更直观的看清楚

# %%
import matplotlib.colors as colors

words_to_visualize = list()
for word, ratio in pos_neg_ratios.most_common(500):
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)
    
for word, ratio in list(reversed(pos_neg_ratios.most_common()))[0:500]:
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)

# %%
# len(words_to_visualize)

# %%
pos = 0
neg = 0

colors_list = list()
vectors_list = list()
for word in words_to_visualize:
    if word in pos_neg_ratios.keys():
        vectors_list.append(mlp_full.weights_0_1[:,mlp_full.word2index[word]])
        if(pos_neg_ratios[word] > 0):
            pos+=1
            colors_list.append("#00ff00")
        else:
            neg+=1
            colors_list.append("#000000")

# %%
# vectors_list

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(vectors_list)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="vector T-SNE for most polarized words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_to_visualize))

p.scatter(x="x1", y="x2", size=8, source=source,color=colors_list)

word_labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
# p.add_layout(word_labels)

show(p)
# Out:
# /Users/zhuanxu/anaconda/envs/linear_regression_demo/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# /Users/zhuanxu/anaconda/envs/linear_regression_demo/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b90deed0-8019-4d5f-9b59-6d3ca8dc9f94"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("b90deed0-8019-4d5f-9b59-6d3ca8dc9f94").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b90deed0-8019-4d5f-9b59-6d3ca8dc9f94");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b90deed0-8019-4d5f-9b59-6d3ca8dc9f94' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4d51a1e4-b66c-403b-a3d3-0da9129edeb7":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x1","x2","names","fill_color","line_color"],"data":{"fill_color":["#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00 ...

# %% [markdown]
# 上面我们将所有的数据放到二维上，绿色是肯定的，黑色是否定的，通过打开p.add_layout(word_labels)这行代码，我们可以看到距离近的其意思就是相近的
#
# ## 总结
# 至此就是本篇情感分析的所有了，回顾下：
# 1. 最开始，我们通过分析在不同意见中词出现的次数不同，我们得出了可以根据一段话分词后不同词出现的次数来判断最终的意见，
# 2. 接着我们通过对分词后的词进行编码，将一段话转换为一个向量
# 3. 接着就是构建神经系统了（老套路）
# 4. 下面我们不断去分析怎么能计算的更快，得出可以去掉某些频度太低的词，以及去除一些在正负观点中都出现的，代表性不是那么强的词
# 5. 最后我们分析了训练出来的神经网络的weights的含义，发现可以根据weighs来对词进行分类，相同意见的词自然而然就聚合到一起了
#
# 分析下上面的问题，其实在对于词输入上，我们只是简单的进行了编码，没有考虑词之间的前后的位置关系，也没有考虑不同词其实其含义是一样的，下一篇将会使用RNN和word2Vec来进行优化。
#
# ## 参考
# [文本情感分类（二）：深度学习模型](http://spaces.ac.cn/archives/3414/comment-page-4)
