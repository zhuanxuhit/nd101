# %%
import tensorflow as tf
# from tensorflow.models.rnn.translate import data_utils
from tensorflow.models.rnn.translate import data_utils
import translation as tr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-a78d6de6e578> in <module>()
#       1 import tensorflow as tf
#       2 # from tensorflow.models.rnn.translate import data_utils
# ----> 3 from tensorflow.models.rnn.translate import data_utils
#       4 import translation as tr
#
# ModuleNotFoundError: No module named 'tensorflow.models'
